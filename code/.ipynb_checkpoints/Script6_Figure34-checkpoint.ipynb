# %% [markdown]
# # Evaluate prediction for ICI response, Figure3

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()
from scipy import stats
import sys,os
from collections import defaultdict, Counter
from matplotlib import patches
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.colors import to_rgba

# %%
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.stats.proportion import proportion_confint

# %%
print(sys.version)
# Out:
# 3.8.8 | packaged by conda-forge | (default, Feb 20 2021, 16:12:38)
# [Clang 11.0.1 ]

# %%
# %pip list | grep -e "numpy" -e "pandas" -e "matplotlib" -e "scipy" -e "seaborn"  -e "statsmodels" -e "sklearn"
# Out:
# matplotlib                    3.4.3
# matplotlib-inline             0.1.3
# matplotlib-venn               0.11.6
# numpy                         1.20.3
# pandas                        1.3.4
# scipy                         1.7.2
# seaborn                       0.11.2
# statsmodels                   0.13.1
# Note: you may need to restart the kernel to use updated packages.

# %%
plt.style.use('seaborn-white')
plt.rcParams['figure.figsize']=4,3
plt.rcParams['figure.dpi']=300
plt.rcParams['axes.linewidth'] =0.5
plt.rcParams['lines.linewidth'] =0.5
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# set font size
SMALL_SIZE = 7
MEDIUM_SIZE = 8
LARGE_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=LARGE_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('axes', linewidth=0.5) 
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)

# %%
store="../results/"

# %%
cluster_order=["SMK","UVL","APB","MRD","POL","HRD","GNS","AGE"]
cluster_order2=["SMK","UVL","APB","MRD","POL","HRD","GNS","AGE","UND"]
cluster_colors=["red","blue","green","purple","brown","hotpink","c","y"]
cluster_colors2=["red","blue","green","purple","brown","hotpink","c","y","grey"]

# %%
# import data
df0=pd.read_csv("../data/ICI_response_cohort_973.tsv"
                ,sep="\t",index_col=0)

# %%
df0["Missense_Mutation_log10"]=np.log10(df0['Missense_Mutation']+1)

# %%
# Single Double therapy
single_therapy=[]
for idx in df0.index:
    if df0.loc[idx,"Treatment"] in ["CTLA4+PD1/PDL1","CTLA4+PD1","CTLA4->PD1"]:
        single_therapy.append(0)
    else:
        single_therapy.append(1)
df0["ICI_single"]=single_therapy

# %% [markdown]
# # TMB cut-off from FM-ONE

# %%
# import Passing Bablok regression results in R
pb_para=pd.read_csv("../analysis_in_R/Passing_Bablok_results.tsv"
                    ,sep="\t",index_col=0)
pb_para
# Out:
#                 EST  SE       LCI       UCI
# Intercept  1.814174 NaN  0.973855  2.791982
# Slope      0.047230 NaN  0.040266  0.052601

# %%
cutoff1=( 10-pb_para.loc["Intercept","EST"]) /pb_para.loc["Slope","EST"]
cutoff1
# Out:
# 173.3166492146599

# %%
# check CI
cutoff1_l=( 10-pb_para.loc["Intercept","LCI"]) /pb_para.loc["Slope","LCI"]
cutoff1_u=( 10-pb_para.loc["Intercept","UCI"]) /pb_para.loc["Slope","UCI"]
print(cutoff1_l,cutoff1_u)
# Out:
# 224.1649670514298 137.03253770579335

# %%
blca2018=pd.read_csv("../analysis_in_R/Nature2018_BLCA_FM1_WES.tsv",sep="\t",index_col=0)

# %%
fig=plt.figure(figsize=(3,3))
ax=fig.add_subplot(111)
tmp_df=blca2018.copy()
val1,val2="Missense_Mutation","FMOne mutation burden per MB"
tmp_df=tmp_df.dropna(subset=[val1,val2])
x=tmp_df[val1]
y=tmp_df[val2]
ax.scatter(x,y,s=10,fc="None",ec="k",lw=0.5)

r,p=stats.pearsonr(x,y)
print("r= {:.3f}, P= {:.2e}".format(r,p))

y2=pb_para.loc["Intercept","EST"]+pb_para.loc["Slope","EST"]*x

ax.plot(x,y2,c="red",lw=1)

y3=pb_para.loc["Intercept","LCI"]+pb_para.loc["Slope","LCI"]*x
y4=pb_para.loc["Intercept","UCI"]+pb_para.loc["Slope","UCI"]*x

ax.plot(x,y3,c="red",ls="dotted",lw=0.75)
ax.plot(x,y4,c="red",ls="dotted",lw=0.75)

ax.axhline(y=10,xmin=0,xmax=0.8,color="blue",ls="dashed")

ax.axvline(x=cutoff1,ymin=0,ymax=0.8,color="blue",ls="dashed")

ax.set_xlabel("Missense mutation",fontsize=10)
ax.set_ylabel(val2,fontsize=10)
ax.set_xticks([0,200,500,1000,1300])
ax.set_yticks([0,10,20,40,60])
ax.tick_params(labelsize=8)

ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
# Out:
# r= 0.820, P= 2.91e-54

# %%
blca2018["FM_high"]=(blca2018["FMOne mutation burden per MB"]>=10).astype(int)
blca2018["MM_high"]=(blca2018["Missense_Mutation"]>=cutoff1).astype(int)
ct=pd.crosstab(blca2018["FM_high"],blca2018["MM_high"])
ct
# Out:
# MM_high    0   1
# FM_high
# 0        118  19
# 1         22  59

# %%
from sklearn.metrics import cohen_kappa_score
cohen_kappa_score(blca2018["FM_high"],blca2018["MM_high"])
# Out:
# 0.5942068464541905

# %% [markdown]
# # TMB cut-off by ROC

# %%
# ROC curve, AUC, explore optimal threshold
from sklearn.metrics import roc_curve,roc_auc_score,auc
flag="Responder"
value="Missense_Mutation"
plt_df=df0.copy()

# %%
fig=plt.figure(figsize=(2,2))
ax=fig.add_subplot(111)
sns_df=plt_df.copy()
cat=flag
val="Missense_Mutation_log10"
ax=sns.swarmplot(x=cat,y=val,data=sns_df,s=1.25,order=[1,0],palette=["red","black"])
ax.set_xlabel("")
ax.set_ylabel("")
ax.legend([])
ax.set_title("",fontsize=10)
ax.tick_params(axis="both",labelsize=6)

ax.set_xticklabels(["Responder","Non-responder"], rotation=0, fontsize=8)
ax.set_yticks([0,1,2,3,4])
ax.set_yticklabels(["1","10","100","1000","10$^{4}$"], rotation=0, fontsize=8)

ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

# %%
# plot ROC curve
plt_df=plt_df.loc[:,[flag,value]].dropna()
y_true=plt_df[flag]
y_score=plt_df[value]
fpr, tpr, thresholds = roc_curve(y_true, y_score)
auc=roc_auc_score(y_true, y_score)

fig=plt.figure(figsize=(2,2))
ax=fig.add_subplot(111)
ax.plot(fpr, tpr, marker='o',ms=0.5,c="k")
ax.set_xlabel('FPR: False positive rate',fontsize=8)
ax.set_ylabel('TPR: True positive rate',fontsize=8)
ax.plot(np.linspace(0,1), np.linspace(0,1), c="r",ls="dotted")
ax.tick_params(labelsize=6)

# Youden index
yd_idx = np.argmax( abs(tpr -fpr) )
yd_threshold = thresholds[yd_idx]
print("Youden index: TPR={:.2f},　FPR={:.2f},　Threshold={:.2f}".format(tpr[yd_idx],fpr[yd_idx],yd_threshold))

# plot with Threshold
arrow_dict = dict(color = "black",arrowstyle = "->")
ax.annotate("Threshold\n= {}".format(thresholds[yd_idx]),xy=(fpr[yd_idx],tpr[yd_idx]),
             size=10,xytext=(fpr[yd_idx]-0.3,tpr[yd_idx]+0.2), arrowprops = arrow_dict )

ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
# Out:
# Youden index: TPR=0.65,　FPR=0.30,　Threshold=165.00

# %%
cutoff2=yd_threshold
df0["TMB_high"]=(df0["Missense_Mutation"]>=cutoff1).astype(float)
df0["TMB_high2"]=(df0["Missense_Mutation"]>=cutoff2).astype(float)

# %%
df0["Age_high"]=df0['Age>=62']

# %% [markdown]
# # Compare response rate

# %% [markdown]
# ## irGS vs non irGS

# %%
df=df0.copy()

# %%
input_df=df.copy()
flag="Responder"
cat1="irGS"
value="Missense_Mutation_log10"
ct=pd.crosstab(input_df[flag],input_df[cat1])
ct=ct.loc[:,[1,0]]
ct
# Out:
# irGS         1    0
# Responder
# 0          419  292
# 1          222   40

# %%
_,p=stats.fisher_exact(ct)
res=stats.chi2_contingency(ct,correction=False)
print("Fisher p= %.2e"%p)
print("Chi-square p= %.2e"%res[1])
# Out:
# Fisher p= 5.89e-15
# Chi-square p= 5.08e-14

# %%
for col in ct.columns:
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    print(count,nobs)
# Out:
# 222 641
# 40 332

# %%
ratios=[]
errors=[]
labels=[]
for col in ct.columns:
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    
    ratios.append(ratio)
    errors.append(np.array(cil-ratio, cih-ratio))
    labels.append(col)
    
    print(str(count)+"/"+str(nobs))
# Out:
# 222/641
# 40/332

# %%
n=len(ratios)
left=range(n)
colors=["red","w"]
colors=[to_rgba(x,0.5) for x in colors]
fig=plt.figure(figsize=((1.3,2)))
ax=fig.add_subplot(111)
ax.bar(x=left,height=ratios,yerr=errors,
       tick_label=labels,color=colors,capsize=5,width=0.6,edgecolor="k",lw=0.5)
ax.tick_params(labelsize=6)

ax.set_xticklabels([], rotation=0, fontsize=8)
ax.set_ylim(0,0.6)
ax.legend([])


ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %% [markdown]
# ## TMB high vs low

# %%
input_df=df.copy()
cat2="TMB_high"
ct=pd.crosstab(input_df[flag],input_df[cat2])
ct=ct.loc[:,[1,0]]
ct
# Out:
# TMB_high     1    0
# Responder
# 0          210  501
# 1          162  100

# %%
_,p=stats.fisher_exact(ct)
res=stats.chi2_contingency(ct,correction=False)
print("Fisher p= %.2e"%p)
print("Chi-square p= %.2e"%res[1])
# Out:
# Fisher p= 1.14e-19
# Chi-square p= 3.73e-20

# %%
ratios=[]
errors=[]
labels=[]
for col in ct.columns:
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    
    ratios.append(ratio)
    errors.append(np.array(cil-ratio, cih-ratio))
    labels.append(col)
    
    print(str(count)+"/"+str(nobs))
# Out:
# 162/372
# 100/601

# %%
n=len(ratios)
left=range(n)
colors=["green","w"]
colors=[to_rgba(x,0.5) for x in colors]
fig=plt.figure(figsize=((1.3,2)))
ax=fig.add_subplot(111)
ax.bar(x=left,height=ratios,yerr=errors,
       tick_label=labels,color=colors,capsize=5,width=0.6,edgecolor="k",lw=0.5)
ax.tick_params(labelsize=6)

ax.set_xticklabels([], rotation=0, fontsize=8)
ax.legend([])
ax.set_ylim(0,0.6)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %% [markdown]
# ## 2D plot

# %%
fig=plt.figure(figsize=(3,3.5))
ax=fig.add_subplot(111)
sns.swarmplot(x=cat1,y=value,data=df,
              s=2,ax=ax,hue=flag,hue_order=[0,1],
              palette=["k","red"],
             order=[1,0])
ax.set_ylabel("",fontsize=8)
ax.set_xlabel("")
ax.axhline(y=np.log10(cutoff1),c="dimgrey",lw=1,ls="dashed")
ax.axvline(x=0.5,c="dimgrey",lw=1,ls="dashed")
ax.tick_params(labelsize=6)
ax.set_xticklabels([])
ax.set_yticks([0,1,2,3,4])
ax.set_ylim(0,4.2)
ax.set_yticklabels(["1","10","100","1000","10$^{4}$"], rotation=0, fontsize=8)
ax.legend([])

   
p1=patches.Rectangle(xy=(-0.5,0),width=1,height=np.log10(cutoff1+1),ec="w",fc="red",alpha=0.2,
                     linewidth=0)
p2=patches.Rectangle(xy=(-0.5,np.log10(cutoff1+1)),width=1,height=4.2-np.log10(cutoff1+1),
                      ec="w",fc="k",alpha=0.2,
                     linewidth=0)
p3=patches.Rectangle(xy=(0.5,np.log10(cutoff1+1)),width=1,height=4.2-np.log10(cutoff1+1),
                      ec="w",fc="green",alpha=0.2,
                     linewidth=0)

ax.add_patch(p1)
ax.add_patch(p2)
ax.add_patch(p3)

# %%
class4=[]
for idx in df.index:
    if df.loc[idx,cat2]==1:
        if df.loc[idx,cat1]==1:
            class4.append("TMB high\nirGS")
        elif df.loc[idx,cat1]==0:
            class4.append("TMB high\nnon-irGS")
        else:
            class4.append("und")
    elif df.loc[idx,cat2]==0:
        if df.loc[idx,cat1]==1:
            class4.append("TMB low\nirGS")
        elif df.loc[idx,cat1]==0:
            class4.append("TMB low\nnon-irGS")
        else:
            class4.append("und")   
df["class4"]=class4

# %%
ct4=pd.crosstab(df["class4"],df[flag]).T
ct4=ct4.reindex(['TMB high\nirGS', 'TMB high\nnon-irGS', 'TMB low\nirGS','TMB low\nnon-irGS'],axis=1)
ct4
# Out:
# class4     TMB high\nirGS  TMB high\nnon-irGS  TMB low\nirGS  \
# Responder
# 0                     204                   6            215
# 1                     158                   4             64
#
# class4     TMB low\nnon-irGS
# Responder
# 0                        286
# 1                         36

# %%
# compare between TMB-low groups
ct=ct4.loc[:, ["TMB low\nirGS","TMB low\nnon-irGS"]]
res=stats.chi2_contingency(ct,correction=False)
display(ct)
print("Chi-square p= %.2e"%res[1])
# Out:
# class4     TMB low\nirGS  TMB low\nnon-irGS
# Responder
# 0                    215                286
# 1                     64                 36
# Chi-square p= 1.13e-04

# %%
ratios=[]
errors=[]
labels=[]
for col in ct4.columns:
    count=ct4.loc[1,col]
    nobs=np.sum( ct4.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    
    ratios.append(ratio)   
    errors.append(np.array(cil-ratio, cih-ratio))
    labels.append(col)
    
    print(str(count)+"/"+str(nobs))
# Out:
# 158/362
# 4/10
# 64/279
# 36/322

# %%
n=len(ratios)
left=range(n)
colors=["dimgrey","lightgrey"]*n
colors=["k","green","red","white"]
colors=[to_rgba(x, 0.5) for x in colors ]

fig=plt.figure(figsize=(3,2.5))
ax=fig.add_subplot(111)
ax.bar(x=left,height=ratios,yerr=errors,
       tick_label=labels,color=colors,capsize=5,width=0.6,edgecolor="k",lw=0.5)
ax.tick_params(labelsize=6)
ax.set_xticklabels(labels, rotation=0, fontsize=8)
ax.legend([])
ax.set_ylim(0,0.8)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %% [markdown]
# ## Logistic regression

# %%
df=df0.copy()

# %%
Counter(df["irGS"])
# Out:
# Counter({1: 641, 0: 332})

# %%
Counter(df["TMB_high"])
# Out:
# Counter({1.0: 372, 0.0: 601})

# %%
Counter(df["CancerType"])
# Out:
# Counter({'Melanoma': 335,
#          'Lung': 162,
#          'Bladder': 263,
#          'HNSCC': 118,
#          'Others': 95})

# %%
df["CancerTypeR"]=df["CancerType"].replace(
        {'Melanoma':"1_Melanoma",
         'Lung': "3_Lung",
         'Bladder': "4_Bladder",
         'HNSCC': "2_Head_neck",
         'Others': "5_Others"})

# %%
Counter(df["Sex"])
# Out:
# Counter({'Female': 342, 'Male': 631})

# %%
df["Sex_male"]=(df["Sex"]=="Male").astype(int)

# %%
Counter(df["Age_high"])
# Out:
# Counter({0.0: 334,
#          1.0: 339,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1})

# %%
Counter(df["ICI_single"])
# Out:
# Counter({1: 896, 0: 77})

# %%
Y="Responder"
categories=["irGS","TMB_high","CancerTypeR","ICI_single","Sex_male","Age_high",]

# %%
# univariate
univ_integrated=pd.DataFrame()

for cat in categories:
    input_df=df.copy()
    formula = Y+" ~ "+cat
    family = sm.families.Binomial()
    model = smf.glm(formula=formula, data=input_df, family=family)
    res = model.fit()
    res_df=pd.concat( [ np.exp(res.params), np.exp(res.conf_int(alpha=0.05)),res.pvalues],axis=1)
    add=res_df.iloc[1:,:]

    univ_integrated=pd.concat([univ_integrated,add])

univ_integrated.columns=["Odds ratio","CI 5%","CI 95%", "P-value"]

res_df=univ_integrated
res_df["95%CI"]=["({:.2f} - {:.2f})".format(x,y) for x,y in zip(res_df["CI 5%"],res_df["CI 95%"])  ]
display( np.round(res_df[["Odds ratio","95%CI","P-value"]],3) )

for i in res_df["P-value"]:
    print("{:.2e}".format(i))
# Out:
#                             Odds ratio          95%CI  P-value
# irGS                             3.868  (2.68 - 5.59)    0.000
# TMB_high                         3.865  (2.87 - 5.20)    0.000
# CancerTypeR[T.2_Head_neck]       0.482  (0.29 - 0.81)    0.006
# CancerTypeR[T.3_Lung]            0.911  (0.61 - 1.37)    0.654
# CancerTypeR[T.4_Bladder]         0.762  (0.53 - 1.09)    0.136
# CancerTypeR[T.5_Others]          0.333  (0.18 - 0.62)    0.001
# ICI_single                       0.799  (0.48 - 1.32)    0.383
# Sex_male                         1.236  (0.91 - 1.67)    0.169
# Age_high                         1.075  (0.76 - 1.52)    0.681
# 6.11e-13
# 4.35e-19
# 5.60e-03
# 6.54e-01
# 1.36e-01
# 6.08e-04
# 3.83e-01
# 1.69e-01
# 6.81e-01

# %%
# multivariate
categories=["irGS","TMB_high","CancerTypeR"]
input_df=df.copy()
res = smf.glm(formula = Y+" ~ "+"+".join(categories),
                  data = input_df,
                  family = sm.families.Binomial()).fit()

res_df=pd.concat( [ np.exp(res.params), np.exp(res.conf_int(alpha=0.05)),res.pvalues],axis=1)
res_df.columns=["Odds ratio","CI 5%","CI 95%", "p-value"]
res_df["95%CI"]=["({:.2f} - {:.2f})".format(x,y) for x,y in zip(res_df["CI 5%"],res_df["CI 95%"])  ]
display( np.round(res_df[["Odds ratio","95%CI","p-value"]],3) )

for i in res_df["p-value"]:
    print("{:.2e}".format(i))
# Out:
#                             Odds ratio          95%CI  p-value
# Intercept                        0.139  (0.09 - 0.21)    0.000
# CancerTypeR[T.2_Head_neck]       0.831  (0.48 - 1.44)    0.511
# CancerTypeR[T.3_Lung]            1.190  (0.77 - 1.84)    0.431
# CancerTypeR[T.4_Bladder]         0.878  (0.60 - 1.28)    0.500
# CancerTypeR[T.5_Others]          0.874  (0.44 - 1.74)    0.701
# irGS                             2.183  (1.40 - 3.40)    0.001
# TMB_high                         2.652  (1.87 - 3.77)    0.000
# 6.95e-20
# 5.11e-01
# 4.31e-01
# 5.00e-01
# 7.01e-01
# 5.55e-04
# 4.95e-08

# %% [markdown]
# ## Forest Plot

# %%
ratios=[]
cils=[]
cihs=[]
labels=[]

# %%
input_df=df.copy()
cat='irGS'
ct=pd.crosstab(input_df[Y],input_df[cat])
ct=ct.loc[[1,0],:]
fig=plt.figure(figsize=(2,0.75))
ax=fig.add_subplot(1,1,1)
for i,col in enumerate(ct.columns):
    print(col)
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    ratios.append(ratio)
    cils.append(cil)
    cihs.append(cih)
    labels.append(cat+'_'+str(col) )
    ax.scatter(x=ratio,y=i,c='k',s=10)
    ax.plot([cil,cih],[i,i],lw=1,c='k')

ax.set_xlim(0,0.5)
ax.set_ylim(-1,2)
ax.set_xticks([])
ax.set_yticks([])
# Out:
# 0
# 1
# []

# %%
input_df=df.copy()
cat='TMB_high'
ct=pd.crosstab(input_df[Y],input_df[cat])
ct=ct.loc[[1,0],:]
fig=plt.figure(figsize=(2,0.75))
ax=fig.add_subplot(1,1,1)
for i,col in enumerate(ct.columns):
    print(col)
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    ratios.append(ratio)
    cils.append(cil)
    cihs.append(cih)
    labels.append(cat+'_'+str(col) )
    ax.scatter(x=ratio,y=i,c='k',s=10)
    ax.plot([cil,cih],[i,i],lw=1,c='k')

ax.set_xlim(0,0.5)
ax.set_ylim(-1,2)
ax.set_xticks([])
ax.set_yticks([])
# Out:
# 0.0
# 1.0
# []

# %%
input_df=df.copy()
cat='CancerTypeR'
ct=pd.crosstab(input_df[Y],input_df[cat])
ct=ct.loc[[1,0],:]
fig=plt.figure(figsize=(2,0.75))
ax=fig.add_subplot(1,1,1)
for i,col in enumerate(ct.columns):
    print(col)
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    ratios.append(ratio)
    cils.append(cil)
    cihs.append(cih)
    labels.append(cat+'_'+str(col) )
    ax.scatter(x=ratio,y=i,c='k',s=10)
    ax.plot([cil,cih],[i,i],lw=1,c='k')

ax.set_xlim(0,0.5)
ax.set_ylim(-1,2)
ax.set_xticks([])
ax.set_yticks([])
# Out:
# 1_Melanoma
# 2_Head_neck
# 3_Lung
# 4_Bladder
# 5_Others
# []

# %%
input_df=df.copy()
cat='ICI_single'
ct=pd.crosstab(input_df[Y],input_df[cat])
ct=ct.loc[[1,0],:]
fig=plt.figure(figsize=(2,0.75))
ax=fig.add_subplot(1,1,1)
for i,col in enumerate(ct.columns):
    print(col)
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    ratios.append(ratio)
    cils.append(cil)
    cihs.append(cih)
    labels.append(cat+'_'+str(col) )
    ax.scatter(x=ratio,y=i,c='k',s=10)
    ax.plot([cil,cih],[i,i],lw=1,c='k')

ax.set_xlim(0,0.5)
ax.set_ylim(-1,2)
ax.set_xticks([])
ax.set_yticks([])
# Out:
# 0
# 1
# []

# %%
input_df=df.copy()
cat="Sex_male"
ct=pd.crosstab(input_df[Y],input_df[cat])
ct=ct.loc[[1,0],:]
fig=plt.figure(figsize=(2,0.75))
ax=fig.add_subplot(1,1,1)
for i,col in enumerate(ct.columns):
    print(col)
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    ratios.append(ratio)
    cils.append(cil)
    cihs.append(cih)
    labels.append(cat+'_'+str(col) )
    ax.scatter(x=ratio,y=i,c='k',s=10)
    ax.plot([cil,cih],[i,i],lw=1,c='k')

ax.set_xlim(0,0.5)
ax.set_ylim(-1,2)
ax.set_xticks([])
ax.set_yticks([])
# Out:
# 0
# 1
# []

# %%
input_df=df.copy()
cat="Age_high"
ct=pd.crosstab(input_df[Y],input_df[cat])
ct=ct.loc[[1,0],:]
fig=plt.figure(figsize=(2,0.75))
ax=fig.add_subplot(1,1,1)
for i,col in enumerate(ct.columns):
    print(col)
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    ratios.append(ratio)
    cils.append(cil)
    cihs.append(cih)
    labels.append(cat+'_'+str(col) )
    ax.scatter(x=ratio,y=i,c='k',s=10)
    ax.plot([cil,cih],[i,i],lw=1,c='k')

ax.set_xlim(0,0.5)
ax.set_ylim(-1,2)
ax.set_xticks([])
ax.set_yticks([])
# Out:
# 0.0
# 1.0
# []

# %%
N=len(ratios)
fig=plt.figure(figsize=(1.75,5.4))
ax=fig.add_subplot(111)

for i in range(N):
    ax.scatter( ratios[i],i,c="k",s=20,marker='d')
    ax.plot([cils[i],cihs[i]],[i,i],lw=1.5,c='k' )
    print(labels[i])


ax.axvline(x=0,ls='dashed',c='grey',lw=1)
ax.axvline(x=0.15,ls='dotted',c='grey')
ax.axvline(x=0.30,ls='dotted',c='grey')
ax.axvline(x=0.45,ls='dotted',c='grey')
ax.set_xlim(0,0.55)
ax.set_ylim(-0.5,N-0.5)   
ax.set_xticks([0,0.15,0.30,0.45])
ax.set_xticklabels(['0','15','30','45'],fontsize=12)
ax.set_yticks([])
ax.invert_yaxis()
ax.spines['top'   ].set_visible(False)# .set_color("w")
ax.spines['bottom'].set_visible(False)
ax.spines['left'  ].set_visible(False)
ax.spines['right' ].set_visible(False)
# Out:
# irGS_0
# irGS_1
# TMB_high_0.0
# TMB_high_1.0
# CancerTypeR_1_Melanoma
# CancerTypeR_2_Head_neck
# CancerTypeR_3_Lung
# CancerTypeR_4_Bladder
# CancerTypeR_5_Others
# ICI_single_0
# ICI_single_1
# Sex_male_0
# Sex_male_1
# Age_high_0.0
# Age_high_1.0

# %%
for i in ratios:
    print( '{:.1f}'.format(i*100) )
# Out:
# 12.0
# 34.6
# 16.6
# 43.5
# 32.2
# 18.6
# 30.2
# 26.6
# 13.7
# 31.2
# 26.6
# 24.3
# 28.4
# 25.4
# 26.8

# %% [markdown]
# ### Using TMB log10 as a continuous value

# %%
categories=["irGS","Missense_Mutation_log10","CancerTypeR","ICI_single","Sex_male","Age_high",]

# %%
# univariate
univ_integrated=pd.DataFrame()

for cat in categories:
    input_df=df.copy()
    formula = Y+" ~ "+cat
    family = sm.families.Binomial()
    model = smf.glm(formula=formula, data=input_df, family=family)
    res = model.fit()
    res_df=pd.concat( [ np.exp(res.params), np.exp(res.conf_int(alpha=0.05)),res.pvalues],axis=1)
    add=res_df.iloc[1:,:]

    univ_integrated=pd.concat([univ_integrated,add])

univ_integrated.columns=["Odds ratio","CI 5%","CI 95%", "P-value"]

res_df=univ_integrated
res_df["95%CI"]=["({:.2f} - {:.2f})".format(x,y) for x,y in zip(res_df["CI 5%"],res_df["CI 95%"])  ]
display( np.round(res_df[["Odds ratio","95%CI","P-value"]],3) )

for i in res_df["P-value"]:
    print("{:.2e}".format(i))
# Out:
#                             Odds ratio          95%CI  P-value
# irGS                             3.868  (2.68 - 5.59)    0.000
# Missense_Mutation_log10          3.923  (2.87 - 5.37)    0.000
# CancerTypeR[T.2_Head_neck]       0.482  (0.29 - 0.81)    0.006
# CancerTypeR[T.3_Lung]            0.911  (0.61 - 1.37)    0.654
# CancerTypeR[T.4_Bladder]         0.762  (0.53 - 1.09)    0.136
# CancerTypeR[T.5_Others]          0.333  (0.18 - 0.62)    0.001
# ICI_single                       0.799  (0.48 - 1.32)    0.383
# Sex_male                         1.236  (0.91 - 1.67)    0.169
# Age_high                         1.075  (0.76 - 1.52)    0.681
# 6.11e-13
# 1.23e-17
# 5.60e-03
# 6.54e-01
# 1.36e-01
# 6.08e-04
# 3.83e-01
# 1.69e-01
# 6.81e-01

# %%
# multivariate　using TMB log10
categories=["irGS","Missense_Mutation_log10","CancerTypeR",]#"TCRA_tcell_fraction"]
input_df=df.copy()
res = smf.glm(formula = Y+" ~ "+"+".join(categories),
                  data = input_df,
                  family = sm.families.Binomial()).fit()

res_df=pd.concat( [ np.exp(res.params), np.exp(res.conf_int(alpha=0.05)),res.pvalues],axis=1)
res_df.columns=["Odds ratio","CI 5%","CI 95%", "p-value"]
res_df["95%CI"]=["({:.2f} - {:.2f})".format(x,y) for x,y in zip(res_df["CI 5%"],res_df["CI 95%"])  ]
display( np.round(res_df[["Odds ratio","95%CI","p-value"]],3) )

for i in res_df["p-value"]:
    print("{:.2e}".format(i))
# Out:
#                             Odds ratio          95%CI  p-value
# Intercept                        0.027  (0.01 - 0.06)    0.000
# CancerTypeR[T.2_Head_neck]       0.837  (0.48 - 1.46)    0.529
# CancerTypeR[T.3_Lung]            1.205  (0.78 - 1.86)    0.397
# CancerTypeR[T.4_Bladder]         0.895  (0.61 - 1.31)    0.570
# CancerTypeR[T.5_Others]          0.891  (0.44 - 1.79)    0.746
# irGS                             1.904  (1.20 - 3.03)    0.006
# Missense_Mutation_log10          2.765  (1.86 - 4.11)    0.000
# 1.22e-16
# 5.29e-01
# 3.97e-01
# 5.70e-01
# 7.46e-01
# 6.48e-03
# 5.09e-07

# %% [markdown]
# # Using optimal TMB cutoff

# %%
df=df0.copy()

# %% [markdown]
# ## TMB high vs low

# %%
input_df=df.copy()
cat2="TMB_high2"
ct=pd.crosstab(input_df[flag],input_df[cat2])
ct=ct.loc[:,[1,0]]
ct
# Out:
# TMB_high2    1    0
# Responder
# 0          216  495
# 1          169   93

# %%
_,p=stats.fisher_exact(ct)
res=stats.chi2_contingency(ct,correction=False)
print("Fisher p= %.2e"%p)
print("Chi-square p= %.2e"%res[1])
# Out:
# Fisher p= 1.18e-21
# Chi-square p= 4.65e-22

# %%
ratios=[]
errors=[]
labels=[]
for col in ct.columns:
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    
    ratios.append(ratio)
    errors.append(np.array(cil-ratio, cih-ratio))
    labels.append(col)
    
    print(str(count)+"/"+str(nobs))
# Out:
# 169/385
# 93/588

# %%
n=len(ratios)
left=range(n)
colors=["blue","w"]
colors=[to_rgba(x,0.5) for x in colors]
fig=plt.figure(figsize=((1.3,2)))
ax=fig.add_subplot(111)
ax.bar(x=left,height=ratios,yerr=errors,
       tick_label=labels,color=colors,capsize=5,width=0.6,edgecolor="k",lw=0.5)
ax.tick_params(labelsize=6)

ax.set_xticklabels([], rotation=0, fontsize=8)
ax.legend([])
ax.set_ylim(0,0.6)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %% [markdown]
# ## 2D plot

# %%
fig=plt.figure(figsize=(3,3.5))
ax=fig.add_subplot(111)
sns.swarmplot(x=cat1,y=value,data=df,
              s=2,ax=ax,hue=flag,hue_order=[0,1],
              palette=["k","red"],
             order=[1,0])
ax.set_ylabel("",fontsize=8)
ax.set_xlabel("")
ax.axhline(y=np.log10(cutoff1),c="dimgrey",lw=1,ls="dashed")
ax.axvline(x=0.5,c="dimgrey",lw=1,ls="dashed")
ax.tick_params(labelsize=6)
ax.set_xticklabels([])
ax.set_yticks([0,1,2,3,4])
ax.set_yticklabels(["1","10","100","1000","10$^{4}$"], rotation=0, fontsize=8)
ax.legend([])

p1=patches.Rectangle(xy=(-0.5,0),width=1,height=np.log10(cutoff1+1),ec="w",fc="red",alpha=0.2,
                 linewidth=0)
p2=patches.Rectangle(xy=(-0.5,np.log10(cutoff1+1)),width=1,height=4.2-np.log10(cutoff1+1),
                      ec="w",fc="k",alpha=0.2,
                     linewidth=0)
p3=patches.Rectangle(xy=(0.5,np.log10(cutoff1+1)),width=1,height=4.2-np.log10(cutoff1+1),
                      ec="w",fc="blue",alpha=0.2,
                     linewidth=0)
ax.add_patch(p1)
ax.add_patch(p2)
ax.add_patch(p3)

# %%
class4=[]
for idx in df.index:
    if df.loc[idx,cat2]==1:
        if df.loc[idx,cat1]==1:
            class4.append("TMB high\nirGS")
        elif df.loc[idx,cat1]==0:
            class4.append("TMB high\nnon-irGS")
        else:
            class4.append("und")
    elif df.loc[idx,cat2]==0:
        if df.loc[idx,cat1]==1:
            class4.append("TMB low\nirGS")
        elif df.loc[idx,cat1]==0:
            class4.append("TMB low\nnon-irGS")
        else:
            class4.append("und")   
df["class4"]=class4

# %%
ct4=pd.crosstab(df["class4"],df[flag]).T
ct4=ct4.reindex(['TMB high\nirGS', 'TMB high\nnon-irGS', 'TMB low\nirGS','TMB low\nnon-irGS'],axis=1)
ct4
# Out:
# class4     TMB high\nirGS  TMB high\nnon-irGS  TMB low\nirGS  \
# Responder
# 0                     210                   6            209
# 1                     164                   5             58
#
# class4     TMB low\nnon-irGS
# Responder
# 0                        286
# 1                         35

# %%
# compare between TMB-low groups
ct=ct4.loc[:, ["TMB low\nirGS","TMB low\nnon-irGS"]]
res=stats.chi2_contingency(ct,correction=False)
display(ct)
print("Chi-square p= %.2e"%res[1])
# Out:
# class4     TMB low\nirGS  TMB low\nnon-irGS
# Responder
# 0                    209                286
# 1                     58                 35
# Chi-square p= 3.44e-04

# %%
ratios=[]
errors=[]
labels=[]
for col in ct4.columns:
    count=ct4.loc[1,col]
    nobs=np.sum( ct4.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    
    ratios.append(ratio)   
    errors.append(np.array(cil-ratio, cih-ratio))
    labels.append(col)
    
    print(str(count)+"/"+str(nobs))
# Out:
# 164/374
# 5/11
# 58/267
# 35/321

# %%
n=len(ratios)
left=range(n)
colors=["dimgrey","lightgrey"]*n
colors=["k","blue","red","white"]
colors=[to_rgba(x, 0.5) for x in colors ]

fig=plt.figure(figsize=(3,2.5))
ax=fig.add_subplot(111)
ax.bar(x=left,height=ratios,yerr=errors,
       tick_label=labels,color=colors,capsize=5,width=0.6,edgecolor="k",lw=0.5)
ax.tick_params(labelsize=6)
ax.set_xticklabels(labels, rotation=0, fontsize=8)
ax.legend([])
ax.set_ylim(0,0.8)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %% [markdown]
# ## Logistic regression

# %%
Counter(df["irGS"])
# Out:
# Counter({1: 641, 0: 332})

# %%
Counter(df["TMB_high2"])
# Out:
# Counter({1.0: 385, 0.0: 588})

# %%
Counter(df["CancerType"])
# Out:
# Counter({'Melanoma': 335,
#          'Lung': 162,
#          'Bladder': 263,
#          'HNSCC': 118,
#          'Others': 95})

# %%
df["CancerTypeR"]=df["CancerType"].replace(
        {'Melanoma':"1_Melanoma",
         'Lung': "3_Lung",
         'Bladder': "4_Bladder",
         'HNSCC': "2_Head_neck",
         'Others': "5_Others"})

# %%
Counter(df["Sex"])
# Out:
# Counter({'Female': 342, 'Male': 631})

# %%
Counter(df["ICI_single"])
# Out:
# Counter({1: 896, 0: 77})

# %%
df["Sex_male"]=(df["Sex"]=="Male").astype(int)

# %%
Y="Responder"
categories=["irGS","TMB_high2","CancerTypeR",'ICI_single',"Sex_male","Age_high"]

# %%
# univariate
univ_integrated=pd.DataFrame()

for cat in categories:
    input_df=df.copy()
    formula = Y+" ~ "+cat
    family = sm.families.Binomial()
    model = smf.glm(formula=formula, data=input_df, family=family)
    res = model.fit()
    res_df=pd.concat( [ np.exp(res.params), np.exp(res.conf_int(alpha=0.05)),res.pvalues],axis=1)
    add=res_df.iloc[1:,:]

    univ_integrated=pd.concat([univ_integrated,add])

univ_integrated.columns=["Odds ratio","CI 5%","CI 95%", "P-value"]

res_df=univ_integrated
res_df["95%CI"]=["({:.2f} - {:.2f})".format(x,y) for x,y in zip(res_df["CI 5%"],res_df["CI 95%"])  ]
display( np.round(res_df[["Odds ratio","95%CI","P-value"]],3) )

for i in res_df["P-value"]:
    print("{:.2e}".format(i))
# Out:
#                             Odds ratio          95%CI  P-value
# irGS                             3.868  (2.68 - 5.59)    0.000
# TMB_high2                        4.164  (3.09 - 5.62)    0.000
# CancerTypeR[T.2_Head_neck]       0.482  (0.29 - 0.81)    0.006
# CancerTypeR[T.3_Lung]            0.911  (0.61 - 1.37)    0.654
# CancerTypeR[T.4_Bladder]         0.762  (0.53 - 1.09)    0.136
# CancerTypeR[T.5_Others]          0.333  (0.18 - 0.62)    0.001
# ICI_single                       0.799  (0.48 - 1.32)    0.383
# Sex_male                         1.236  (0.91 - 1.67)    0.169
# Age_high                         1.075  (0.76 - 1.52)    0.681
# 6.11e-13
# 9.46e-21
# 5.60e-03
# 6.54e-01
# 1.36e-01
# 6.08e-04
# 3.83e-01
# 1.69e-01
# 6.81e-01

# %%
# multivariate
categories=["irGS","TMB_high2","CancerTypeR"]
input_df=df.copy()
res = smf.glm(formula = Y+" ~ "+"+".join(categories),
                  data = input_df,
                  family = sm.families.Binomial()).fit()

res_df=pd.concat( [ np.exp(res.params), np.exp(res.conf_int(alpha=0.05)),res.pvalues],axis=1)
res_df.columns=["Odds ratio","CI 5%","CI 95%", "p-value"]
res_df["95%CI"]=["({:.2f} - {:.2f})".format(x,y) for x,y in zip(res_df["CI 5%"],res_df["CI 95%"])  ]
display( np.round(res_df[["Odds ratio","95%CI","p-value"]],3) )

for i in res_df["p-value"]:
    print("{:.2e}".format(i))
# Out:
#                             Odds ratio          95%CI  p-value
# Intercept                        0.135  (0.09 - 0.21)    0.000
# CancerTypeR[T.2_Head_neck]       0.844  (0.48 - 1.47)    0.548
# CancerTypeR[T.3_Lung]            1.219  (0.79 - 1.88)    0.373
# CancerTypeR[T.4_Bladder]         0.908  (0.62 - 1.33)    0.621
# CancerTypeR[T.5_Others]          0.895  (0.45 - 1.79)    0.754
# irGS                             2.019  (1.29 - 3.17)    0.002
# TMB_high2                        2.948  (2.06 - 4.22)    0.000
# 3.38e-20
# 5.48e-01
# 3.73e-01
# 6.21e-01
# 7.54e-01
# 2.21e-03
# 3.18e-09

# %% [markdown]
# ### Forest Plot

# %%
ratios=[]
cils=[]
cihs=[]
labels=[]

# %%
input_df=df.copy()
cat='irGS'
ct=pd.crosstab(input_df[Y],input_df[cat])
ct=ct.loc[[1,0],:]
for i,col in enumerate(ct.columns):
    print(col)
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    ratios.append(ratio)
    cils.append(cil)
    cihs.append(cih)
    labels.append(cat+'_'+str(col) )
    
input_df=df.copy()
cat='TMB_high2'
ct=pd.crosstab(input_df[Y],input_df[cat])
ct=ct.loc[[1,0],:]
for i,col in enumerate(ct.columns):
    print(col)
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    ratios.append(ratio)
    cils.append(cil)
    cihs.append(cih)
    labels.append(cat+'_'+str(col) )
    
ratios.append(np.nan)
cils.append(np.nan)
cihs.append(np.nan)
labels.append('')

input_df=df.copy()
cat='CancerTypeR'
ct=pd.crosstab(input_df[Y],input_df[cat])
ct=ct.loc[[1,0],:]
for i,col in enumerate(ct.columns):
    print(col)
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    ratios.append(ratio)
    cils.append(cil)
    cihs.append(cih)
    labels.append(cat+'_'+str(col) )
    
input_df=df.copy()
cat='ICI_single'
ct=pd.crosstab(input_df[Y],input_df[cat])
ct=ct.loc[[1,0],:]
for i,col in enumerate(ct.columns):
    print(col)
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    ratios.append(ratio)
    cils.append(cil)
    cihs.append(cih)
    labels.append(cat+'_'+str(col) )
    
input_df=df.copy()
cat="Sex_male"
ct=pd.crosstab(input_df[Y],input_df[cat])
ct=ct.loc[[1,0],:]
for i,col in enumerate(ct.columns):
    print(col)
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    ratios.append(ratio)
    cils.append(cil)
    cihs.append(cih)
    labels.append(cat+'_'+str(col) )
    
input_df=df.copy()
cat="Age_high"
ct=pd.crosstab(input_df[Y],input_df[cat])
ct=ct.loc[[1,0],:]
for i,col in enumerate(ct.columns):
    print(col)
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    ratios.append(ratio)
    cils.append(cil)
    cihs.append(cih)
    labels.append(cat+'_'+str(col) )
# Out:
# 0
# 1
# 0.0
# 1.0
# 1_Melanoma
# 2_Head_neck
# 3_Lung
# 4_Bladder
# 5_Others
# 0
# 1
# 0
# 1
# 0.0
# 1.0

# %%
N=len(ratios)
fig=plt.figure(figsize=(1.5,4.35))
ax=fig.add_subplot(111)

for i in range(N):
    ax.scatter( ratios[i],i,c="k",s=15,marker='d' )
    ax.plot([cils[i],cihs[i]],[i,i],lw=1,c='k' )
    print(labels[i])


ax.axvline(x=0,ls='dashed',c='grey',lw=1)
ax.axvline(x=0.15,ls='dotted',c='grey')
ax.axvline(x=0.30,ls='dotted',c='grey')
ax.axvline(x=0.45,ls='dotted',c='grey')
ax.set_xlim(0,0.55)
ax.set_ylim(-0.5,N-0.5)   
ax.set_xticks([0,0.15,0.30,0.45])
ax.set_xticklabels(['0','15','30','45'],fontsize=10)
ax.set_yticks([])
ax.invert_yaxis()
ax.spines['top'   ].set_visible(False)# .set_color("w")
ax.spines['bottom'].set_visible(False)
ax.spines['left'  ].set_visible(False)
ax.spines['right' ].set_visible(False)
# Out:
# irGS_0
# irGS_1
# TMB_high2_0.0
# TMB_high2_1.0
#
# CancerTypeR_1_Melanoma
# CancerTypeR_2_Head_neck
# CancerTypeR_3_Lung
# CancerTypeR_4_Bladder
# CancerTypeR_5_Others
# ICI_single_0
# ICI_single_1
# Sex_male_0
# Sex_male_1
# Age_high_0.0
# Age_high_1.0

# %%
for i in ratios:
    print( '{:.1f}'.format(i*100) )
# Out:
# 12.0
# 34.6
# 15.8
# 43.9
# nan
# 32.2
# 18.6
# 30.2
# 26.6
# 13.7
# 31.2
# 26.6
# 24.3
# 28.4
# 25.4
# 26.8

# %% [markdown]
# # TcellExTRECT

# %%
df=df0.copy()

# %%
plt_df=df
cat='Responder'
val='TCRA_tcell_fraction_qcFit<=4'
order=[1,0]
fig=plt.figure(figsize=[2,2])
ax=fig.add_subplot(1,1,1)
sns.swarmplot(x=cat,y=val,data=plt_df,s=1,order=order,palette=['k'])#,,hue=hue,dodge=True,palette=palette)
sns.violinplot(x=cat,y=val,data=plt_df,s=1,order=order,palette=['red','grey'],cut=0)#,,hue=hue,dodge=True,palette=palette)

ax.set_xlabel('')
ax.set_ylabel('')
ax.set_yticks([0,0.2,0.4,0.6])
ax.set_xticklabels(['Responder','Non-responder'])

ax.tick_params(labelsize=8)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
# Out:
# /Users/tshiro/.pyenv/versions/miniforge3-4.10/envs/gsp_env_p376/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning: 14.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/tshiro/.pyenv/versions/miniforge3-4.10/envs/gsp_env_p376/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning: 29.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# plot ROC curve
flag='Responder'
value='TCRA_tcell_fraction_qcFit<=4'
plt_df=df.loc[:,[flag,value]].dropna()
y_true=plt_df[flag]
y_score=plt_df[value]
fpr, tpr, thresholds = roc_curve(y_true, y_score)
auc=roc_auc_score(y_true, y_score)

fig=plt.figure(figsize=(2,1.5))
ax=fig.add_subplot(111)
ax.plot(fpr, tpr, marker='o',ms=0.5,c="k")
ax.set_xlabel('FPR: False positive rate',fontsize=8)
ax.set_ylabel('TPR: True positive rate',fontsize=8)
ax.plot(np.linspace(0,1), np.linspace(0,1), c="r",ls="dotted")
ax.tick_params(labelsize=6)

# Youden index
yd_idx = np.argmax( abs(tpr -fpr) )
yd_threshold = thresholds[yd_idx]
print("Youden index: TPR={:.2f},　FPR={:.2f},　Threshold={:.2f}".format(tpr[yd_idx],fpr[yd_idx],yd_threshold))

# plot with Threshold
arrow_dict = dict(color = "black",arrowstyle = "->")
ax.annotate("Threshold\n= {:.3f}".format(thresholds[yd_idx]),xy=(fpr[yd_idx],tpr[yd_idx]),
             size=8,xytext=(fpr[yd_idx]-0.2,tpr[yd_idx]+0.2), arrowprops = arrow_dict )

ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
# Out:
# Youden index: TPR=0.28,　FPR=0.17,　Threshold=0.17

# %%
plt_df=df.copy()
#plt_df=plt_df[plt_df[cat]=='']
val1,val2,val3='Missense_Mutation_log10','TCRA_tcell_fraction_qcFit<=4','Responder'
plt_df=plt_df[[val1,val2,val3]].dropna()
fig=plt.figure(figsize=(3,3))
ax=fig.add_subplot(111)

plt_df1=plt_df[plt_df['Responder']==0]
x,y=plt_df1[val1],plt_df1[val2]
ax.scatter(x,y,s=3,ec='k',fc="None",linewidth=0.5)

plt_df2=plt_df[plt_df['Responder']==1]
x,y=plt_df2[val1],plt_df2[val2]
ax.scatter(x,y,s=3,ec='red',fc="None",linewidth=0.5)
ax.set_xlabel('')
ax.set_ylabel('')
ax.set_yticks([0,0.2,0.4,0.6])
ax.set_ylim([-0.25,0.7])
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(["1","10","100","1000","10$^{4}$"], rotation=0, fontsize=8)

ax.axhline(thresholds[yd_idx],color='blue',ls='dashed')
ax.axvline(np.log10(cutoff1),color='blue',ls='dashed')

# %%
thresholds[yd_idx]
# Out:
# 0.169236414

# %%
class4=[]
cat1,cat2='Missense_Mutation_log10','TCRA_tcell_fraction_qcFit<=4'
for idx in df.index:
    if df.loc[idx,cat1]>=np.log10(cutoff1):
        if df.loc[idx,cat2]>=thresholds[yd_idx]:
            class4.append("TMB high\nTCRA high")
        elif df.loc[idx,cat2]<thresholds[yd_idx]:
            class4.append("TMB high\nTCRA low")
        else:
            class4.append("und")
    else:
        if df.loc[idx,cat2]>=thresholds[yd_idx]:
            class4.append("TMB low\nTCRA high")
        elif df.loc[idx,cat2]<thresholds[yd_idx]:
            class4.append("TMB low\nTCRA low")
        else:
            class4.append("und")   
df["class4"]=class4

# %%
ct4=pd.crosstab(df["class4"],df[flag]).T
#ct4=ct4.reindex(['TMB high\nnTCRA high', 'TMB high\nnTCRA low', 'TMB low\nnTCRA high','TMB low\nnTCRA low'],axis=1)
ct4
# Out:
# class4     TMB high\nTCRA high  TMB high\nTCRA low  TMB low\nTCRA high  \
# Responder
# 0                           41                 143                  70
# 1                           38                  98                  26
#
# class4     TMB low\nTCRA low  und
# Responder
# 0                        383   74
# 1                         63   37

# %%
import matplotlib.patches as patches
counts=[ct4['TMB high\nTCRA high'][i] for i in [1,0] ]
labels=['','']
colors=['red','dimgrey']
from matplotlib.colors import to_rgba
colors=[to_rgba(x, 0.5) for x in colors]
fig=plt.figure(figsize=(0.7,0.7))
ax=fig.add_subplot(111)
ax.pie(x=counts,
       labels=labels, 
       colors=colors,
       wedgeprops={'linewidth': 0.5,'edgecolor':"w",},
       textprops={"fontsize":6,'color':"k",'weight':'bold'},
       pctdistance=0.5,
       startangle=90,
       counterclock=False, 
       autopct=lambda p:'{:.1f}%'.format(p) if p >= 2.5 else ''
      )
ax.axis('equal')
# Out:
# (-1.1073373723312532,
#  1.11440020696058,
#  -1.1095748556708966,
#  1.1004559722538139)

# %%
import matplotlib.patches as patches
counts=[ct4['TMB high\nTCRA low'][i] for i in [1,0] ]
labels=['','']
colors=['red','dimgrey']
from matplotlib.colors import to_rgba
colors=[to_rgba(x, 0.5) for x in colors]
fig=plt.figure(figsize=(0.7,0.7))
ax=fig.add_subplot(111)
ax.pie(x=counts,
       labels=labels, 
       colors=colors,
       wedgeprops={'linewidth': 0.5,'edgecolor':"w",},
       textprops={"fontsize":6,'color':"k",'weight':'bold'},
       pctdistance=0.5,
       startangle=90,
       counterclock=False, 
       autopct=lambda p:'{:.1f}%'.format(p) if p >= 2.5 else ''
      )
ax.axis('equal')
# Out:
# (-1.1135039078994073,
#  1.1209352277424742,
#  -1.1120843317978173,
#  1.100575474981918)

# %%
import matplotlib.patches as patches
counts=[ct4['TMB low\nTCRA high'][i] for i in [1,0] ]
labels=['','']
colors=['red','dimgrey']
from matplotlib.colors import to_rgba
colors=[to_rgba(x, 0.5) for x in colors]
fig=plt.figure(figsize=(0.7,0.7))
ax=fig.add_subplot(111)
ax.pie(x=counts,
       labels=labels, 
       colors=colors,
       wedgeprops={'linewidth': 0.5,'edgecolor':"w",},
       textprops={"fontsize":6,'color':"k",'weight':'bold'},
       pctdistance=0.5,
       startangle=90,
       counterclock=False, 
       autopct=lambda p:'{:.1f}%'.format(p) if p >= 2.5 else ''
      )
ax.axis('equal')
# Out:
# (-1.1187466625028581,
#  1.1113940627568522,
#  -1.1150517166287983,
#  1.1007167861128504)

# %%
import matplotlib.patches as patches
counts=[ct4['TMB low\nTCRA low'][i] for i in [1,0] ]
labels=['','']
colors=['red','dimgrey']
from matplotlib.colors import to_rgba
colors=[to_rgba(x, 0.5) for x in colors]
fig=plt.figure(figsize=(0.7,0.7))
ax=fig.add_subplot(111)
ax.pie(x=counts,
       labels=labels, 
       colors=colors,
       wedgeprops={'linewidth': 0.5,'edgecolor':"w",},
       textprops={"fontsize":6,'color':"k",'weight':'bold'},
       pctdistance=0.5,
       startangle=90,
       counterclock=False, 
       autopct=lambda p:'{:.1f}%'.format(p) if p >= 2.5 else ''
      )
ax.axis('equal')
# Out:
# (-1.106686649184057, 1.1013171290230592, -1.10662726136203, 1.1003155838743823)

# %% [markdown]
# ## Logistic regression

# %%
df["CancerTypeR"]=df["CancerType"].replace(
        {'Melanoma':"1_Melanoma",
         'Lung': "3_Lung",
         'Bladder': "4_Bladder",
         'HNSCC': "2_Head_neck",
         'Others': "5_Others"})

# %%
df["Sex_male"]=(df["Sex"]=="Male").astype(int)

# %%
np.sum(~df['TCRA_tcell_fraction_qcFit<=4'].isna())
# Out:
# 862

# %%
df['TCRA_tcell_fraction']=df['TCRA_tcell_fraction_qcFit<=4']

# %%
Y="Responder"
categories=["irGS","TMB_high",'TCRA_tcell_fraction',"CancerTypeR","ICI_single","Sex_male","Age_high",]

# %%
# univariate
univ_integrated=pd.DataFrame()

for cat in categories:
    input_df=df.copy()
    formula = Y+" ~ "+cat
    family = sm.families.Binomial()
    model = smf.glm(formula=formula, data=input_df, family=family)
    res = model.fit()
    res_df=pd.concat( [ np.exp(res.params), np.exp(res.conf_int(alpha=0.05)),res.pvalues],axis=1)
    add=res_df.iloc[1:,:]

    univ_integrated=pd.concat([univ_integrated,add])

univ_integrated.columns=["Odds ratio","CI 5%","CI 95%", "P-value"]

res_df=univ_integrated
res_df["95%CI"]=["({:.2f} - {:.2f})".format(x,y) for x,y in zip(res_df["CI 5%"],res_df["CI 95%"])  ]
display( np.round(res_df[["Odds ratio","95%CI","P-value"]],3) )

for i in res_df["P-value"]:
    print("{:.2e}".format(i))
# Out:
#                             Odds ratio           95%CI  P-value
# irGS                             3.868   (2.68 - 5.59)    0.000
# TMB_high                         3.865   (2.87 - 5.20)    0.000
# TCRA_tcell_fraction              5.528  (1.42 - 21.51)    0.014
# CancerTypeR[T.2_Head_neck]       0.482   (0.29 - 0.81)    0.006
# CancerTypeR[T.3_Lung]            0.911   (0.61 - 1.37)    0.654
# CancerTypeR[T.4_Bladder]         0.762   (0.53 - 1.09)    0.136
# CancerTypeR[T.5_Others]          0.333   (0.18 - 0.62)    0.001
# ICI_single                       0.799   (0.48 - 1.32)    0.383
# Sex_male                         1.236   (0.91 - 1.67)    0.169
# Age_high                         1.075   (0.76 - 1.52)    0.681
# 6.11e-13
# 4.35e-19
# 1.37e-02
# 5.60e-03
# 6.54e-01
# 1.36e-01
# 6.08e-04
# 3.83e-01
# 1.69e-01
# 6.81e-01

# %%
# multivariate
categories=["irGS","TMB_high","TCRA_tcell_fraction","CancerTypeR",]
input_df=df.copy()
res = smf.glm(formula = Y+" ~ "+"+".join(categories),
                  data = input_df,
                  family = sm.families.Binomial()).fit()

res_df=pd.concat( [ np.exp(res.params), np.exp(res.conf_int(alpha=0.05)),res.pvalues],axis=1)
res_df.columns=["Odds ratio","CI 5%","CI 95%", "p-value"]
res_df["95%CI"]=["({:.2f} - {:.2f})".format(x,y) for x,y in zip(res_df["CI 5%"],res_df["CI 95%"])  ]
display( np.round(res_df[["Odds ratio","95%CI","p-value"]],3) )

for i in res_df["p-value"]:
    print("{:.2e}".format(i))
# Out:
#                             Odds ratio           95%CI  p-value
# Intercept                        0.116   (0.07 - 0.19)    0.000
# CancerTypeR[T.2_Head_neck]       0.785   (0.44 - 1.41)    0.420
# CancerTypeR[T.3_Lung]            1.176   (0.71 - 1.95)    0.531
# CancerTypeR[T.4_Bladder]         0.941   (0.62 - 1.43)    0.775
# CancerTypeR[T.5_Others]          1.019   (0.50 - 2.08)    0.958
# irGS                             2.350   (1.47 - 3.76)    0.000
# TMB_high                         2.408   (1.66 - 3.49)    0.000
# TCRA_tcell_fraction              4.235  (0.93 - 19.19)    0.061
# 1.75e-17
# 4.20e-01
# 5.31e-01
# 7.75e-01
# 9.58e-01
# 3.75e-04
# 3.60e-06
# 6.12e-02

# %% [markdown]
# ## Forest Plot

# %%
ratios=[]
cils=[]
cihs=[]
labels=[]

# %%
input_df=df.copy()
cat='irGS'
ct=pd.crosstab(input_df[Y],input_df[cat])
ct=ct.loc[[1,0],:]
for i,col in enumerate(ct.columns):
    print(col)
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    ratios.append(ratio)
    cils.append(cil)
    cihs.append(cih)
    labels.append(cat+'_'+str(col) )
# Out:
# 0
# 1

# %%
input_df=df.copy()
cat='TMB_high'
ct=pd.crosstab(input_df[Y],input_df[cat])
ct=ct.loc[[1,0],:]
for i,col in enumerate(ct.columns):
    print(col)
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    ratios.append(ratio)
    cils.append(cil)
    cihs.append(cih)
    labels.append(cat+'_'+str(col) )
    ax.scatter(x=ratio,y=i,c='k',s=10)
    ax.plot([cil,cih],[i,i],lw=1,c='k')
# Out:
# 0.0
# 1.0

# %%
ratios.append(np.nan)
labels.append('TCRA tcell fraction')
cils.append(np.nan)
cihs.append(np.nan)

# %%
input_df=df.copy()
cat='CancerTypeR'
ct=pd.crosstab(input_df[Y],input_df[cat])
ct=ct.loc[[1,0],:]
for i,col in enumerate(ct.columns):
    print(col)
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    ratios.append(ratio)
    cils.append(cil)
    cihs.append(cih)
    labels.append(cat+'_'+str(col) )
# Out:
# 1_Melanoma
# 2_Head_neck
# 3_Lung
# 4_Bladder
# 5_Others

# %%
input_df=df.copy()
cat='ICI_single'
ct=pd.crosstab(input_df[Y],input_df[cat])
ct=ct.loc[[1,0],:]
for i,col in enumerate(ct.columns):
    print(col)
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    ratios.append(ratio)
    cils.append(cil)
    cihs.append(cih)
    labels.append(cat+'_'+str(col) )
# Out:
# 0
# 1

# %%
input_df=df.copy()
cat="Sex_male"
ct=pd.crosstab(input_df[Y],input_df[cat])
ct=ct.loc[[1,0],:]
for i,col in enumerate(ct.columns):
    print(col)
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    ratios.append(ratio)
    cils.append(cil)
    cihs.append(cih)
    labels.append(cat+'_'+str(col) )
# Out:
# 0
# 1

# %%
input_df=df.copy()
cat="Age_high"
ct=pd.crosstab(input_df[Y],input_df[cat])
ct=ct.loc[[1,0],:]
for i,col in enumerate(ct.columns):
    print(col)
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    ratios.append(ratio)
    cils.append(cil)
    cihs.append(cih)
    labels.append(cat+'_'+str(col) )
# Out:
# 0.0
# 1.0

# %%
N=len(ratios)
fig=plt.figure(figsize=(1.3,5.7))
ax=fig.add_subplot(111)

for i in range(N):
    ax.scatter( ratios[i],i,c="k",s=20,marker='d')
    ax.plot([cils[i],cihs[i]],[i,i],lw=1.5,c='k' )
    print(labels[i])

ax.axvline(x=0,ls='dashed',c='grey',lw=1)
ax.axvline(x=0.15,ls='dotted',c='grey')
ax.axvline(x=0.30,ls='dotted',c='grey')
ax.axvline(x=0.45,ls='dotted',c='grey')
ax.set_xlim(0,0.55)
ax.set_ylim(-0.5,N-0.5)   
ax.set_xticks([0,0.15,0.30,0.45])
ax.set_xticklabels(['0','15','30','45'],fontsize=12)
ax.set_yticks([])
ax.invert_yaxis()
ax.spines['top'   ].set_visible(False)# .set_color("w")
ax.spines['bottom'].set_visible(False)
ax.spines['left'  ].set_visible(False)
ax.spines['right' ].set_visible(False)
# Out:
# irGS_0
# irGS_1
# TMB_high_0.0
# TMB_high_1.0
# TCRA tcell fraction
# CancerTypeR_1_Melanoma
# CancerTypeR_2_Head_neck
# CancerTypeR_3_Lung
# CancerTypeR_4_Bladder
# CancerTypeR_5_Others
# ICI_single_0
# ICI_single_1
# Sex_male_0
# Sex_male_1
# Age_high_0.0
# Age_high_1.0

# %%
for i in ratios:
    print( '{:.1f}'.format(i*100) )
# Out:
# 12.0
# 34.6
# 16.6
# 43.5
# nan
# 32.2
# 18.6
# 30.2
# 26.6
# 13.7
# 31.2
# 26.6
# 24.3
# 28.4
# 25.4
# 26.8

# %% [markdown]
# # Response per subtype

# %%
df=df0.copy()

# %%
ct=pd.crosstab(df["Responder"],df["Tumor genomic subtype"])
ct=ct.loc[:,cluster_order2]
ct
# Out:
# Tumor genomic subtype  SMK  UVL  APB  MRD  POL  HRD  GNS  AGE  UND
# Responder
# 0                       70  155  185    0    0   94   23  148   36
# 1                       44   94   75    6    1   16    3   16    7

# %%
# bar plot with binomial confidence interval
ratios,errors,labels=[],[],[]
for col in ct.columns:
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)    
    ratios.append(ratio)
    errors.append(np.array(cil-ratio, cih-ratio))
    labels.append(col)
    print(str(count)+"/"+str(nobs))

n=len(ratios)
left=range(n)
colors=cluster_colors2

fig=plt.figure(figsize=(n*0.75,2.5))
ax=fig.add_subplot(111)
ax.bar(x=left,height=ratios,yerr=errors,
       tick_label=labels,color=colors,capsize=5,width=0.6,edgecolor="k",lw=0.5)
ax.tick_params(labelsize=6)  
ax.set_xticklabels(labels, rotation=0, fontsize=10)
ax.legend([])
ax.set_ylim(0,1)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
# Out:
# 44/114
# 94/249
# 75/260
# 6/6
# 1/1
# 16/110
# 3/26
# 16/164
# 7/43

# %%
ct=pd.crosstab(df["CancerType"],df["Tumor genomic subtype"])
ct.loc[["Melanoma","HNSCC","Lung","Bladder","Others"],cluster_order2]
# Out:
# Tumor genomic subtype  SMK  UVL  APB  MRD  POL  HRD  GNS  AGE  UND
# CancerType
# Melanoma                 2  247    0    0    0   33   12   24   17
# HNSCC                   14    2   38    0    0   15    0   43    6
# Lung                    89    0   18    0    0   18    6   26    5
# Bladder                  8    0  191    4    0   17    0   31   12
# Others                   1    0   13    2    1   27    8   40    3

# %% [markdown]
# # Per Drug type

# %%
df=df0.copy()

# %%
cat1="irGS"
cat2="TMB_high"

class4=[]
for idx in df.index:
    if df.loc[idx,cat2]==1:
        if df.loc[idx,cat1]==1:
            class4.append("TMB high\nirGS")
        elif df.loc[idx,cat1]==0:
            class4.append("TMB high\nnon-irGS")
        else:
            class4.append("und")
    elif df.loc[idx,cat2]==0:
        if df.loc[idx,cat1]==1:
            class4.append("TMB low\nirGS")
        elif df.loc[idx,cat1]==0:
            class4.append("TMB low\nnon-irGS")
        else:
            class4.append("und")   
df["class4"]=class4

# %%
Counter(df["Treatment"])
# Out:
# Counter({'CTLA4': 117,
#          'PD1': 498,
#          'CTLA4->PD1': 18,
#          'CTLA4+PD1': 49,
#          'PDL1': 220,
#          'PD1/PDL1': 61,
#          'CTLA4+PD1/PDL1': 10})

# %%
df1=df[df["Treatment"]=="PD1"]
df2=df[df["Treatment"]=="PDL1"]
df3=df[df["Treatment"].isin(["CTLA4",'CTLA4->PD1',"CTLA4+PDL1","CTLA4+PD1","CTLA4+PD1/PDL1"])]
dfs=[df1,df2,df3]

# %%
flag="Responder"
cat1="irGS"
cat2="TMB_high"
value="Missense_Mutation_log10"
for plt_df in dfs:
    fig=plt.figure(figsize=(2.25,2.5))
    ax=fig.add_subplot(111)
    sns.swarmplot(x=cat1,y=value,data=plt_df,
                  s=2,ax=ax,hue=flag,hue_order=[0,1],
                  palette=["k","red"],
                 order=[1,0])
    ax.set_ylabel("",fontsize=8)
    ax.set_xlabel("")
    ax.axhline(y=np.log10(173),c="dimgrey",lw=1,ls="dashed")
    ax.axvline(x=0.5,c="dimgrey",lw=1,ls="dashed")
    ax.tick_params(labelsize=6)
    ax.set_xticklabels(["irGS","Non-irGS"], rotation=0, fontsize=8)
    ax.set_yticks([0,1,2,3,4])
    ax.set_yticklabels(["1","10","100","1000","10$^{4}$"], rotation=0, fontsize=8)
    ax.legend([])
    p1=patches.Rectangle(xy=(-0.5,0),width=1,height=np.log10(cutoff1+1),ec="w",fc="red",alpha=0.2,
                     linewidth=0)
    p2=patches.Rectangle(xy=(-0.5,np.log10(cutoff1+1)),width=1,height=4.2-np.log10(cutoff1+1),
                          ec="w",fc="k",alpha=0.2,
                         linewidth=0)
    p3=patches.Rectangle(xy=(0.5,np.log10(cutoff1+1)),width=1,height=4.2-np.log10(cutoff1+1),
                          ec="w",fc="green",alpha=0.2,
                         linewidth=0)
    ax.add_patch(p1)
    ax.add_patch(p2)
    ax.add_patch(p3)

# %%
for i,plt_df in enumerate(dfs):
    print(plt_df["Treatment"].unique()[0],"n=", plt_df.shape[0])
    ct4=pd.crosstab(plt_df["class4"],plt_df[flag]).T
    ratios=[]
    errors=[]
    labels=[]
    for col in ct4.columns:
        count=ct4.loc[1,col]
        nobs=np.sum( ct4.loc[:,col])
        ratio=count/nobs
        cil,cih=proportion_confint(count,nobs,alpha=0.05)

        ratios.append(ratio)   
        errors.append(np.array(cil-ratio, cih-ratio))
        labels.append(col)
        print(str(count)+"/"+str(nobs))
    else:
        print()
    
    n=len(ratios)
    left=range(n)
    colors=["k","green","red","white"]
    colors=[to_rgba(x, 0.5) for x in colors ]

    fig=plt.figure(figsize=(3,1.75))
    ax=fig.add_subplot(111)
    ax.bar(x=left,height=ratios,yerr=errors,
           tick_label=labels,color=colors,capsize=5,width=0.6,edgecolor="k",lw=0.5)
    ax.tick_params(labelsize=6)            
    ax.set_xticklabels(labels, rotation=0, fontsize=8)
    ax.legend([])
    ax.set_ylim(0,1)
    if i==0:
        ax.set_ylim(0,1.2)
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    
    ct=ct4.reindex(["TMB low\nirGS","TMB low\nnon-irGS"],axis=1)
    res=stats.chi2_contingency(ct,correction=False)
    res2=stats.fisher_exact(ct)
    display(ct)
    print("chisquare p= %.3g"%res[1])
    print("Fisher p= %.3g"%res2[1],end="\n\n")
# Out:
# PD1 n= 498
# 85/179
# 2/3
# 30/117
# 24/199
# class4     TMB low\nirGS  TMB low\nnon-irGS
# Responder
# 0                     87                175
# 1                     30                 24
# chisquare p= 0.00196
# Fisher p= 0.00302
#
# PDL1 n= 220
# 37/81
# 0/1
# 15/93
# 3/45
# class4     TMB low\nirGS  TMB low\nnon-irGS
# Responder
# 0                     78                 42
# 1                     15                  3
# chisquare p= 0.122
# Fisher p= 0.178
#
# CTLA4 n= 194
# 25/83
# 2/6
# 13/43
# 6/62
# class4     TMB low\nirGS  TMB low\nnon-irGS
# Responder
# 0                     30                 56
# 1                     13                  6
# chisquare p= 0.00714
# Fisher p= 0.00982

# %% [markdown]
# # KEYNOTEs only

# %%
df=df0[df0["Reference"]=='Cristescu, Science 2018']
df.shape
# Out:
# (311, 19)

# %%
input_df=df.copy()
flag="Responder"
cat1="irGS"
value="Missense_Mutation_log10"
ct=pd.crosstab(input_df[flag],input_df[cat1])
ct=ct.loc[:,[1,0]]
ct
# Out:
# irGS         1    0
# Responder
# 0          102  135
# 1           56   18

# %%
_,p=stats.fisher_exact(ct)
res=stats.chi2_contingency(ct,correction=False)
print("Fisher p= %.2e"%p)
print("Chi-square p= %.2e"%res[1])
# Out:
# Fisher p= 1.11e-06
# Chi-square p= 9.46e-07

# %%
ratios=[]
errors=[]
labels=[]
for col in ct.columns:
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    
    ratios.append(ratio)
    errors.append(np.array(cil-ratio, cih-ratio))
    labels.append(col)
    
    print(str(count)+"/"+str(nobs))
# Out:
# 56/158
# 18/153

# %%
n=len(ratios)
left=range(n)
colors=["red","w"]
colors=[to_rgba(x,0.5) for x in colors]
fig=plt.figure(figsize=((1.3,2)))
ax=fig.add_subplot(111)
ax.bar(x=left,height=ratios,yerr=errors,
       tick_label=labels,color=colors,capsize=5,width=0.6,edgecolor="k",lw=0.5)
ax.tick_params(labelsize=6)

ax.set_xticklabels([], rotation=0, fontsize=8)
ax.set_ylim(0,0.6)
ax.legend([])


ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %%
input_df=df.copy()
cat2="TMB_high"
ct=pd.crosstab(input_df[flag],input_df[cat2])
ct=ct.loc[:,[1,0]]
ct
# Out:
# TMB_high    1    0
# Responder
# 0          49  188
# 1          40   34

# %%
_,p=stats.fisher_exact(ct)
res=stats.chi2_contingency(ct,correction=False)
print("Fisher p= %.2e"%p)
print("Chi-square p= %.2e"%res[1])
# Out:
# Fisher p= 1.15e-07
# Chi-square p= 2.92e-08

# %%
ratios=[]
errors=[]
labels=[]
for col in ct.columns:
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    
    ratios.append(ratio)
    errors.append(np.array(cil-ratio, cih-ratio))
    labels.append(col)
    
    print(str(count)+"/"+str(nobs))
# Out:
# 40/89
# 34/222

# %%
n=len(ratios)
left=range(n)
colors=["green","w"]
colors=[to_rgba(x,0.5) for x in colors]
fig=plt.figure(figsize=((1.3,2)))
ax=fig.add_subplot(111)
ax.bar(x=left,height=ratios,yerr=errors,
       tick_label=labels,color=colors,capsize=5,width=0.6,edgecolor="k",lw=0.5)
ax.tick_params(labelsize=6)

ax.set_xticklabels([], rotation=0, fontsize=8)
ax.legend([])
ax.set_ylim(0,0.6)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %% [markdown]
# ## 2D plot

# %%
fig=plt.figure(figsize=(3,3.5))
ax=fig.add_subplot(111)
sns.swarmplot(x=cat1,y=value,data=df,
              s=2,ax=ax,hue=flag,hue_order=[0,1],
              palette=["k","red"],
             order=[1,0])
ax.set_ylabel("",fontsize=8)
ax.set_xlabel("")
ax.axvline(x=0.5,c="dimgrey",lw=1,ls="dashed")
ax.tick_params(labelsize=6)
ax.set_xticklabels(["irGS","Non-irGS"], rotation=0, fontsize=8)
ax.set_yticks([0,1,2,3,4])
ax.set_yticklabels(["1","10","100","1000","10$^{4}$"], rotation=0, fontsize=8)
ax.legend([])

ax.axhline(y=np.log10(173),c="dimgrey",lw=1,ls="dashed")
p1=patches.Rectangle(xy=(-0.5,0),width=1,height=np.log10(cutoff1+1),ec="w",fc="red",alpha=0.2,
                 linewidth=0)
p2=patches.Rectangle(xy=(-0.5,np.log10(cutoff1+1)),width=1,height=4.2-np.log10(cutoff1+1),
                      ec="w",fc="k",alpha=0.2,
                     linewidth=0)
p3=patches.Rectangle(xy=(0.5,np.log10(cutoff1+1)),width=1,height=4.2-np.log10(cutoff1+1),
                      ec="w",fc="green",alpha=0.2,
                     linewidth=0)
ax.add_patch(p1)
ax.add_patch(p2)
ax.add_patch(p3)

# %%
class4=[]
for idx in df.index:
    if df.loc[idx,cat2]==1:
        if df.loc[idx,cat1]==1:
            class4.append("TMB high\nirGS")
        elif df.loc[idx,cat1]==0:
            class4.append("TMB high\nnon-irGS")
        else:
            class4.append("und")
    elif df.loc[idx,cat2]==0:
        if df.loc[idx,cat1]==1:
            class4.append("TMB low\nirGS")
        elif df.loc[idx,cat1]==0:
            class4.append("TMB low\nnon-irGS")
        else:
            class4.append("und")   
df["class4"]=class4
# Out:
# /Users/tshiro/.pyenv/versions/miniforge3-4.10/envs/gsp_env_p376/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ct4=pd.crosstab(df["class4"],df[flag]).T
ct4=ct4.reindex(['TMB high\nirGS', 'TMB high\nnon-irGS', 'TMB low\nirGS','TMB low\nnon-irGS'],axis=1)
ct4
# Out:
# class4     TMB high\nirGS  TMB high\nnon-irGS  TMB low\nirGS  \
# Responder
# 0                      48                   1             54
# 1                      38                   2             18
#
# class4     TMB low\nnon-irGS
# Responder
# 0                        134
# 1                         16

# %%
ct=ct4.loc[:, ["TMB low\nirGS","TMB low\nnon-irGS"]]
res=stats.chi2_contingency(ct,correction=False)
display(ct)
print("Chi-square p= %.2e"%res[1])
# Out:
# class4     TMB low\nirGS  TMB low\nnon-irGS
# Responder
# 0                     54                134
# 1                     18                 16
# Chi-square p= 5.50e-03

# %%
ratios=[]
errors=[]
labels=[]
for col in ct4.columns:
    count=ct4.loc[1,col]
    nobs=np.sum( ct4.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    
    ratios.append(ratio)   
    errors.append(np.array(cil-ratio, cih-ratio))
    labels.append(col)
    
    print(str(count)+"/"+str(nobs))
# Out:
# 38/86
# 2/3
# 18/72
# 16/150

# %%
n=len(ratios)
left=range(n)
colors=["dimgrey","lightgrey"]*n
colors=["k","green","red","white"]
colors=[to_rgba(x, 0.5) for x in colors ]

fig=plt.figure(figsize=(3,2.5))
ax=fig.add_subplot(111)
ax.bar(x=left,height=ratios,yerr=errors,
       tick_label=labels,color=colors,capsize=5,width=0.6,edgecolor="k",lw=0.5)
ax.tick_params(labelsize=6)
ax.set_xticklabels(labels, rotation=0, fontsize=8)
ax.legend([])
ax.set_ylim(0,1.2)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %% [markdown]
# ## Logistic regression

# %%
Counter(df["irGS"])
# Out:
# Counter({1: 158, 0: 153})

# %%
Counter(df["TMB_high"])
# Out:
# Counter({1.0: 89, 0.0: 222})

# %%
Counter(df["CancerType"])
# Out:
# Counter({'Bladder': 17, 'Others': 95, 'Lung': 4, 'HNSCC': 106, 'Melanoma': 89})

# %%
df["CancerTypeR"]=df["CancerType"].replace(
        {'Melanoma':"1_Melanoma",
         'Lung': "4_Others",
         'Bladder': "3_Bladder",
         'HNSCC': "2_Head_neck",
         'Others': "4_Others"})
# Out:
# /Users/tshiro/.pyenv/versions/miniforge3-4.10/envs/gsp_env_p376/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
Counter(df["Sex"])
# Out:
# Counter({'Male': 194, 'Female': 117})

# %%
df["Sex_male"]=(df["Sex"]=="Male").astype(int)
# Out:
# /Users/tshiro/.pyenv/versions/miniforge3-4.10/envs/gsp_env_p376/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
Counter(df["Age_high"])
# Out:
# Counter({1.0: 151, 0.0: 160})

# %%
Y="Responder"
categories=["irGS","Missense_Mutation_log10","CancerTypeR","Sex_male","Age_high"]

# %%
# univariate
univ_integrated=pd.DataFrame()

for cat in categories:
    input_df=df.copy()
    formula = Y+" ~ "+cat
    family = sm.families.Binomial()
    model = smf.glm(formula=formula, data=input_df, family=family)
    res = model.fit()
    res_df=pd.concat( [ np.exp(res.params), np.exp(res.conf_int(alpha=0.05)),res.pvalues],axis=1)
    add=res_df.iloc[1:,:]

    univ_integrated=pd.concat([univ_integrated,add])

univ_integrated.columns=["Odds ratio","CI 5%","CI 95%", "P-value"]

res_df=univ_integrated
res_df["95%CI"]=["({:.2f} - {:.2f})".format(x,y) for x,y in zip(res_df["CI 5%"],res_df["CI 95%"])  ]
display( np.round(res_df[["Odds ratio","95%CI","P-value"]],3) )

for i in res_df["P-value"]:
    print("{:.2e}".format(i))
# Out:
#                             Odds ratio          95%CI  P-value
# irGS                             4.118  (2.28 - 7.43)    0.000
# Missense_Mutation_log10          4.379  (2.55 - 7.52)    0.000
# CancerTypeR[T.2_Head_neck]       0.312  (0.16 - 0.59)    0.000
# CancerTypeR[T.3_Bladder]         0.288  (0.08 - 1.07)    0.063
# CancerTypeR[T.4_Others]          0.203  (0.10 - 0.42)    0.000
# Sex_male                         1.581  (0.90 - 2.77)    0.110
# Age_high                         0.812  (0.48 - 1.37)    0.435
# 2.58e-06
# 8.99e-08
# 3.85e-04
# 6.34e-02
# 1.36e-05
# 1.10e-01
# 4.35e-01

# %%
# multivariate
categories=["irGS","Missense_Mutation_log10","CancerTypeR"]
input_df=df.copy()
res = smf.glm(formula = Y+" ~ "+"+".join(categories),
                  data = input_df,
                  family = sm.families.Binomial()).fit()

res_df=pd.concat( [ np.exp(res.params), np.exp(res.conf_int(alpha=0.05)),res.pvalues],axis=1)
res_df.columns=["Odds ratio","CI 5%","CI 95%", "p-value"]
res_df["95%CI"]=["({:.2f} - {:.2f})".format(x,y) for x,y in zip(res_df["CI 5%"],res_df["CI 95%"])  ]
display( np.round(res_df[["Odds ratio","95%CI","p-value"]],3) )

for i in res_df["p-value"]:
    print("{:.2g}".format(i))
# Out:
#                             Odds ratio          95%CI  p-value
# Intercept                        0.064  (0.01 - 0.29)    0.000
# CancerTypeR[T.2_Head_neck]       0.518  (0.26 - 1.04)    0.066
# CancerTypeR[T.3_Bladder]         0.340  (0.09 - 1.31)    0.118
# CancerTypeR[T.4_Others]          0.473  (0.20 - 1.09)    0.079
# irGS                             1.746  (0.77 - 3.96)    0.182
# Missense_Mutation_log10          2.336  (1.12 - 4.85)    0.023
# 0.00038
# 0.066
# 0.12
# 0.079
# 0.18
# 0.023

# %%
 df["CancerType details2"]=df["CancerType details"].replace({"BR_ER+HER-":"BR","BR_TNBC":"BR","HNSCC_Exp":"HNSCC"})
# Out:
# /Users/tshiro/.pyenv/versions/miniforge3-4.10/envs/gsp_env_p376/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
tmp=pd.crosstab(df["CancerType details2"],df["Tumor genomic subtype"]).loc[:,cluster_order2]
tmp["Total"]=np.sum(tmp,axis=1)
tmp.sort_values("Total",ascending=False)
# Out:
# Tumor genomic subtype  SMK  UVL  APB  MRD  POL  HRD  GNS  AGE  UND  Total
# CancerType details2
# HNSCC                   13    2   35    0    0   14    0   36    6    106
# Melanoma                 0   72    0    0    0   10    0    4    3     89
# Urothelial               1    0   14    0    0    0    0    2    0     17
# BR                       0    0    2    0    0    6    0    4    2     14
# Gastric                  0    0    0    1    0    1    0    8    0     10
# SalivaryGland            0    0    1    0    0    7    0    2    0     10
# ThyroidCancer            0    0    0    0    0    3    2    4    0      9
# Analcanal_SCC            0    0    6    0    0    0    0    2    0      8
# Mesothelioma             0    0    0    0    0    2    3    1    1      7
# BiliaryTract             0    0    0    1    0    2    1    2    0      6
# Carcinoid                1    0    0    0    0    2    0    3    0      6
# ColrectalAdeno           0    0    0    0    0    1    0    4    0      5
# Endometrial              0    0    0    0    1    0    0    3    0      4
# Others                   3    0    0    0    0    0    0    1    0      4
# ProstateAdeno            0    0    0    0    0    1    1    1    0      3
# Vulvar_SCC               0    0    2    0    0    0    0    1    0      3
# Esophageal_SCC/Adeno     0    0    1    0    0    1    0    1    0      3
# Cervical_SCC             0    0    1    0    0    0    1    1    0      3
# PancreasAdeno            0    0    0    0    0    0    0    2    0      2
# Leiomyosarcoma           0    0    0    0    0    1    0    1    0      2

# %% [markdown]
# ## Forest plot

# %%
ratios=[]
cils=[]
cihs=[]
labels=[]

# %%
input_df=df.copy()
cat='irGS'
ct=pd.crosstab(input_df[Y],input_df[cat])
ct=ct.loc[[1,0],:]
for i,col in enumerate(ct.columns):
    print(col)
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    ratios.append(ratio)
    cils.append(cil)
    cihs.append(cih)
    labels.append(cat+'_'+str(col) )
    
input_df=df.copy()
cat='TMB_high'
ct=pd.crosstab(input_df[Y],input_df[cat])
ct=ct.loc[[1,0],:]
for i,col in enumerate(ct.columns):
    print(col)
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    ratios.append(ratio)
    cils.append(cil)
    cihs.append(cih)
    labels.append(cat+'_'+str(col) )
    
input_df=df.copy()
cat='CancerTypeR'
ct=pd.crosstab(input_df[Y],input_df[cat])
ct=ct.loc[[1,0],:]
for i,col in enumerate(ct.columns):
    print(col)
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    ratios.append(ratio)
    cils.append(cil)
    cihs.append(cih)
    labels.append(cat+'_'+str(col) )
    
input_df=df.copy()
cat="Sex_male"
ct=pd.crosstab(input_df[Y],input_df[cat])
ct=ct.loc[[1,0],:]
for i,col in enumerate(ct.columns):
    print(col)
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    ratios.append(ratio)
    cils.append(cil)
    cihs.append(cih)
    labels.append(cat+'_'+str(col) )
    
input_df=df.copy()
cat="Age_high"
ct=pd.crosstab(input_df[Y],input_df[cat])
ct=ct.loc[[1,0],:]
for i,col in enumerate(ct.columns):
    print(col)
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    ratios.append(ratio)
    cils.append(cil)
    cihs.append(cih)
    labels.append(cat+'_'+str(col) )
# Out:
# 0
# 1
# 0.0
# 1.0
# 1_Melanoma
# 2_Head_neck
# 3_Bladder
# 4_Others
# 0
# 1
# 0.0
# 1.0

# %%
N=len(ratios)
fig=plt.figure(figsize=(1.5,3.5))
ax=fig.add_subplot(111)

for i in range(N):
    ax.scatter( ratios[i],i,c="k",s=15,marker='d' )
    ax.plot([cils[i],cihs[i]],[i,i],lw=1,c='k' )
    print(labels[i])


ax.axvline(x=0,ls='dashed',c='grey',lw=1)
ax.axvline(x=0.15,ls='dotted',c='grey')
ax.axvline(x=0.30,ls='dotted',c='grey')
ax.axvline(x=0.45,ls='dotted',c='grey')
ax.set_xlim(0,0.55)
ax.set_ylim(-0.5,N-0.5)   
ax.set_xticks([0,0.15,0.30,0.45])
ax.set_xticklabels(['0','15','30','45'],fontsize=10)
ax.set_yticks([])
ax.invert_yaxis()
ax.spines['top'   ].set_visible(False)# .set_color("w")
ax.spines['bottom'].set_visible(False)
ax.spines['left'  ].set_visible(False)
ax.spines['right' ].set_visible(False)
# Out:
# irGS_0
# irGS_1
# TMB_high_0.0
# TMB_high_1.0
# CancerTypeR_1_Melanoma
# CancerTypeR_2_Head_neck
# CancerTypeR_3_Bladder
# CancerTypeR_4_Others
# Sex_male_0
# Sex_male_1
# Age_high_0.0
# Age_high_1.0

# %%
for i in ratios:
    print( '{:.1f}'.format(i*100) )
# Out:
# 11.8
# 35.4
# 15.3
# 44.9
# 42.7
# 18.9
# 17.6
# 13.1
# 18.8
# 26.8
# 25.6
# 21.9

# %% [markdown]
# # Excluding Anagostou

# %%
df=df0[df0['Reference']!='Anagnostou, NatCan 2020']
df.shape
# Out:
# (919, 19)

# %%
input_df=df.copy()
flag="Responder"
cat1="irGS"
value="Missense_Mutation_log10"
ct=pd.crosstab(input_df[flag],input_df[cat1])
ct=ct.loc[:,[1,0]]
ct
# Out:
# irGS         1    0
# Responder
# 0          396  277
# 1          209   37

# %%
_,p=stats.fisher_exact(ct)
res=stats.chi2_contingency(ct,correction=False)
print("Fisher p= %.2e"%p)
print("Chi-square p= %.2e"%res[1])
# Out:
# Fisher p= 1.26e-14
# Chi-square p= 1.45e-13

# %%
for col in ct.columns:
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    print(count,nobs)
# Out:
# 209 605
# 37 314

# %%
ratios=[]
errors=[]
labels=[]
for col in ct.columns:
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    
    ratios.append(ratio)
    errors.append(np.array(cil-ratio, cih-ratio))
    labels.append(col)
    
    print(str(count)+"/"+str(nobs))
# Out:
# 209/605
# 37/314

# %%
n=len(ratios)
left=range(n)
colors=["red","w"]
colors=[to_rgba(x,0.5) for x in colors]
fig=plt.figure(figsize=((1.3,2)))
ax=fig.add_subplot(111)
ax.bar(x=left,height=ratios,yerr=errors,
       tick_label=labels,color=colors,capsize=5,width=0.6,edgecolor="k",lw=0.5)
ax.tick_params(labelsize=6)

ax.set_xticklabels([], rotation=0, fontsize=8)
ax.set_ylim(0,0.6)
ax.legend([])


ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %%
input_df=df.copy()
cat2="TMB_high"
ct=pd.crosstab(input_df[flag],input_df[cat2])
ct=ct.loc[:,[1,0]]
ct
# Out:
# TMB_high     1    0
# Responder
# 0          200  473
# 1          153   93

# %%
_,p=stats.fisher_exact(ct)
res=stats.chi2_contingency(ct,correction=False)
print("Fisher p= %.2e"%p)
print("Chi-square p= %.2e"%res[1])
# Out:
# Fisher p= 7.64e-19
# Chi-square p= 3.18e-19

# %%
ratios=[]
errors=[]
labels=[]
for col in ct.columns:
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    
    ratios.append(ratio)
    errors.append(np.array(cil-ratio, cih-ratio))
    labels.append(col)
    
    print(str(count)+"/"+str(nobs))
# Out:
# 153/353
# 93/566

# %%
n=len(ratios)
left=range(n)
colors=["green","w"]
colors=[to_rgba(x,0.5) for x in colors]
fig=plt.figure(figsize=((1.3,2)))
ax=fig.add_subplot(111)
ax.bar(x=left,height=ratios,yerr=errors,
       tick_label=labels,color=colors,capsize=5,width=0.6,edgecolor="k",lw=0.5)
ax.tick_params(labelsize=6)

ax.set_xticklabels([], rotation=0, fontsize=8)
ax.legend([])
ax.set_ylim(0,0.6)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %%
fig=plt.figure(figsize=(3,3.5))
ax=fig.add_subplot(111)
sns.swarmplot(x=cat1,y=value,data=df,
              s=2,ax=ax,hue=flag,hue_order=[0,1],
              palette=["k","red"],
             order=[1,0])
ax.set_ylabel("",fontsize=8)
ax.set_xlabel("")
ax.axhline(y=np.log10(cutoff1),c="dimgrey",lw=1,ls="dashed")
ax.axvline(x=0.5,c="dimgrey",lw=1,ls="dashed")
ax.tick_params(labelsize=6)
ax.set_xticklabels([])
ax.set_yticks([0,1,2,3,4])
ax.set_ylim(0,4.2)
ax.set_yticklabels(["1","10","100","1000","10$^{4}$"], rotation=0, fontsize=8)
ax.legend([])

   
p1=patches.Rectangle(xy=(-0.5,0),width=1,height=np.log10(cutoff1+1),ec="w",fc="red",alpha=0.2,
                     linewidth=0)
p2=patches.Rectangle(xy=(-0.5,np.log10(cutoff1+1)),width=1,height=4.2-np.log10(cutoff1+1),
                      ec="w",fc="k",alpha=0.2,
                     linewidth=0)
p3=patches.Rectangle(xy=(0.5,np.log10(cutoff1+1)),width=1,height=4.2-np.log10(cutoff1+1),
                      ec="w",fc="green",alpha=0.2,
                     linewidth=0)

ax.add_patch(p1)
ax.add_patch(p2)
ax.add_patch(p3)

# %%
class4=[]
for idx in df.index:
    if df.loc[idx,cat2]==1:
        if df.loc[idx,cat1]==1:
            class4.append("TMB high\nirGS")
        elif df.loc[idx,cat1]==0:
            class4.append("TMB high\nnon-irGS")
        else:
            class4.append("und")
    elif df.loc[idx,cat2]==0:
        if df.loc[idx,cat1]==1:
            class4.append("TMB low\nirGS")
        elif df.loc[idx,cat1]==0:
            class4.append("TMB low\nnon-irGS")
        else:
            class4.append("und")   
df["class4"]=class4
# Out:
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_49973/751823333.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["class4"]=class4

# %%
ct4=pd.crosstab(df["class4"],df[flag]).T
ct4=ct4.reindex(['TMB high\nirGS', 'TMB high\nnon-irGS', 'TMB low\nirGS','TMB low\nnon-irGS'],axis=1)
ct4
# Out:
# class4     TMB high\nirGS  TMB high\nnon-irGS  TMB low\nirGS  \
# Responder
# 0                     194                   6            202
# 1                     149                   4             60
#
# class4     TMB low\nnon-irGS
# Responder
# 0                        271
# 1                         33

# %%
# compare between TMB-low groups
ct=ct4.loc[:, ["TMB low\nirGS","TMB low\nnon-irGS"]]
res=stats.chi2_contingency(ct,correction=False)
display(ct)
print("Chi-square p= %.2e"%res[1])
# Out:
# class4     TMB low\nirGS  TMB low\nnon-irGS
# Responder
# 0                    202                271
# 1                     60                 33
# Chi-square p= 1.15e-04

# %%
ratios=[]
errors=[]
labels=[]
for col in ct4.columns:
    count=ct4.loc[1,col]
    nobs=np.sum( ct4.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    
    ratios.append(ratio)   
    errors.append(np.array(cil-ratio, cih-ratio))
    labels.append(col)
    
    print(str(count)+"/"+str(nobs))
# Out:
# 149/343
# 4/10
# 60/262
# 33/304

# %%
n=len(ratios)
left=range(n)
colors=["dimgrey","lightgrey"]*n
colors=["k","green","red","white"]
colors=[to_rgba(x, 0.5) for x in colors ]

fig=plt.figure(figsize=(3,2.5))
ax=fig.add_subplot(111)
ax.bar(x=left,height=ratios,yerr=errors,
       tick_label=labels,color=colors,capsize=5,width=0.6,edgecolor="k",lw=0.5)
ax.tick_params(labelsize=6)
ax.set_xticklabels(labels, rotation=0, fontsize=8)
ax.legend([])
ax.set_ylim(0,0.8)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %%
Counter(df["irGS"])
# Out:
# Counter({1: 605, 0: 314})

# %%
Counter(df["TMB_high"])
# Out:
# Counter({1.0: 353, 0.0: 566})

# %%
Counter(df["CancerType"])
# Out:
# Counter({'Melanoma': 335,
#          'Lung': 108,
#          'Bladder': 263,
#          'HNSCC': 118,
#          'Others': 95})

# %%
df["CancerTypeR"]=df["CancerType"].replace(
        {'Melanoma':"1_Melanoma",
         'Lung': "3_Lung",
         'Bladder': "4_Bladder",
         'HNSCC': "2_Head_neck",
         'Others': "5_Others"})
# Out:
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_49973/4040197753.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["CancerTypeR"]=df["CancerType"].replace(

# %%
Counter(df["Sex"])
# Out:
# Counter({'Female': 317, 'Male': 602})

# %%
df["Sex_male"]=(df["Sex"]=="Male").astype(int)
# Out:
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_49973/693836955.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sex_male"]=(df["Sex"]=="Male").astype(int)

# %%
Counter(df["ICI_single"])
# Out:
# Counter({1: 848, 0: 71})

# %%
Y="Responder"
categories=["irGS","TMB_high","CancerTypeR","ICI_single","Sex_male","Age_high",]

# %%
# univariate
univ_integrated=pd.DataFrame()

for cat in categories:
    input_df=df.copy()
    formula = Y+" ~ "+cat
    family = sm.families.Binomial()
    model = smf.glm(formula=formula, data=input_df, family=family)
    res = model.fit()
    res_df=pd.concat( [ np.exp(res.params), np.exp(res.conf_int(alpha=0.05)),res.pvalues],axis=1)
    add=res_df.iloc[1:,:]

    univ_integrated=pd.concat([univ_integrated,add])

univ_integrated.columns=["Odds ratio","CI 5%","CI 95%", "P-value"]

res_df=univ_integrated
res_df["95%CI"]=["({:.2f} - {:.2f})".format(x,y) for x,y in zip(res_df["CI 5%"],res_df["CI 95%"])  ]
display( np.round(res_df[["Odds ratio","95%CI","P-value"]],3) )

for i in res_df["P-value"]:
    print("{:.2e}".format(i))
# Out:
#                             Odds ratio          95%CI  P-value
# irGS                             3.951  (2.70 - 5.79)    0.000
# TMB_high                         3.891  (2.86 - 5.28)    0.000
# CancerTypeR[T.2_Head_neck]       0.482  (0.29 - 0.81)    0.006
# CancerTypeR[T.3_Lung]            0.925  (0.58 - 1.48)    0.744
# CancerTypeR[T.4_Bladder]         0.762  (0.53 - 1.09)    0.136
# CancerTypeR[T.5_Others]          0.333  (0.18 - 0.62)    0.001
# ICI_single                       0.800  (0.47 - 1.35)    0.404
# Sex_male                         1.217  (0.89 - 1.66)    0.219
# Age_high                         1.066  (0.74 - 1.53)    0.727
# 1.74e-12
# 3.40e-18
# 5.60e-03
# 7.44e-01
# 1.36e-01
# 6.08e-04
# 4.04e-01
# 2.19e-01
# 7.27e-01

# %%
# multivariate
categories=["irGS","TMB_high","CancerTypeR"]
input_df=df.copy()
res = smf.glm(formula = Y+" ~ "+"+".join(categories),
                  data = input_df,
                  family = sm.families.Binomial()).fit()

res_df=pd.concat( [ np.exp(res.params), np.exp(res.conf_int(alpha=0.05)),res.pvalues],axis=1)
res_df.columns=["Odds ratio","CI 5%","CI 95%", "p-value"]
res_df["95%CI"]=["({:.2f} - {:.2f})".format(x,y) for x,y in zip(res_df["CI 5%"],res_df["CI 95%"])  ]
display( np.round(res_df[["Odds ratio","95%CI","p-value"]],3) )

for i in res_df["p-value"]:
    print("{:.2e}".format(i))
# Out:
#                             Odds ratio          95%CI  p-value
# Intercept                        0.136  (0.09 - 0.21)    0.000
# CancerTypeR[T.2_Head_neck]       0.834  (0.48 - 1.45)    0.520
# CancerTypeR[T.3_Lung]            1.210  (0.73 - 2.00)    0.454
# CancerTypeR[T.4_Bladder]         0.876  (0.60 - 1.28)    0.495
# CancerTypeR[T.5_Others]          0.884  (0.44 - 1.77)    0.727
# irGS                             2.241  (1.41 - 3.55)    0.001
# TMB_high                         2.638  (1.84 - 3.79)    0.000
# 3.82e-19
# 5.20e-01
# 4.54e-01
# 4.95e-01
# 7.27e-01
# 5.87e-04
# 1.46e-07

# %%
ratios=[]
cils=[]
cihs=[]
labels=[]

# %%
input_df=df.copy()
cat='irGS'
ct=pd.crosstab(input_df[Y],input_df[cat])
ct=ct.loc[[1,0],:]
fig=plt.figure(figsize=(2,0.75))
ax=fig.add_subplot(1,1,1)
for i,col in enumerate(ct.columns):
    print(col)
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    ratios.append(ratio)
    cils.append(cil)
    cihs.append(cih)
    labels.append(cat+'_'+str(col) )
    ax.scatter(x=ratio,y=i,c='k',s=10)
    ax.plot([cil,cih],[i,i],lw=1,c='k')

ax.set_xlim(0,0.5)
ax.set_ylim(-1,2)
ax.set_xticks([])
ax.set_yticks([])
# Out:
# 0
# 1
# []

# %%
input_df=df.copy()
cat='TMB_high'
ct=pd.crosstab(input_df[Y],input_df[cat])
ct=ct.loc[[1,0],:]
fig=plt.figure(figsize=(2,0.75))
ax=fig.add_subplot(1,1,1)
for i,col in enumerate(ct.columns):
    print(col)
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    ratios.append(ratio)
    cils.append(cil)
    cihs.append(cih)
    labels.append(cat+'_'+str(col) )
    ax.scatter(x=ratio,y=i,c='k',s=10)
    ax.plot([cil,cih],[i,i],lw=1,c='k')

ax.set_xlim(0,0.5)
ax.set_ylim(-1,2)
ax.set_xticks([])
ax.set_yticks([])
# Out:
# 0.0
# 1.0
# []

# %%
input_df=df.copy()
cat='CancerTypeR'
ct=pd.crosstab(input_df[Y],input_df[cat])
ct=ct.loc[[1,0],:]
fig=plt.figure(figsize=(2,0.75))
ax=fig.add_subplot(1,1,1)
for i,col in enumerate(ct.columns):
    print(col)
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    ratios.append(ratio)
    cils.append(cil)
    cihs.append(cih)
    labels.append(cat+'_'+str(col) )
    ax.scatter(x=ratio,y=i,c='k',s=10)
    ax.plot([cil,cih],[i,i],lw=1,c='k')

ax.set_xlim(0,0.5)
ax.set_ylim(-1,2)
ax.set_xticks([])
ax.set_yticks([])
# Out:
# 1_Melanoma
# 2_Head_neck
# 3_Lung
# 4_Bladder
# 5_Others
# []

# %%
input_df=df.copy()
cat='ICI_single'
ct=pd.crosstab(input_df[Y],input_df[cat])
ct=ct.loc[[1,0],:]
fig=plt.figure(figsize=(2,0.75))
ax=fig.add_subplot(1,1,1)
for i,col in enumerate(ct.columns):
    print(col)
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    ratios.append(ratio)
    cils.append(cil)
    cihs.append(cih)
    labels.append(cat+'_'+str(col) )
    ax.scatter(x=ratio,y=i,c='k',s=10)
    ax.plot([cil,cih],[i,i],lw=1,c='k')

ax.set_xlim(0,0.5)
ax.set_ylim(-1,2)
ax.set_xticks([])
ax.set_yticks([])
# Out:
# 0
# 1
# []

# %%
input_df=df.copy()
cat="Sex_male"
ct=pd.crosstab(input_df[Y],input_df[cat])
ct=ct.loc[[1,0],:]
fig=plt.figure(figsize=(2,0.75))
ax=fig.add_subplot(1,1,1)
for i,col in enumerate(ct.columns):
    print(col)
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    ratios.append(ratio)
    cils.append(cil)
    cihs.append(cih)
    labels.append(cat+'_'+str(col) )
    ax.scatter(x=ratio,y=i,c='k',s=10)
    ax.plot([cil,cih],[i,i],lw=1,c='k')

ax.set_xlim(0,0.5)
ax.set_ylim(-1,2)
ax.set_xticks([])
ax.set_yticks([])
# Out:
# 0
# 1
# []

# %%
input_df=df.copy()
cat="Age_high"
ct=pd.crosstab(input_df[Y],input_df[cat])
ct=ct.loc[[1,0],:]
fig=plt.figure(figsize=(2,0.75))
ax=fig.add_subplot(1,1,1)
for i,col in enumerate(ct.columns):
    print(col)
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,alpha=0.05)
    ratios.append(ratio)
    cils.append(cil)
    cihs.append(cih)
    labels.append(cat+'_'+str(col) )
    ax.scatter(x=ratio,y=i,c='k',s=10)
    ax.plot([cil,cih],[i,i],lw=1,c='k')

ax.set_xlim(0,0.5)
ax.set_ylim(-1,2)
ax.set_xticks([])
ax.set_yticks([])
# Out:
# 0.0
# 1.0
# []

# %%
N=len(ratios)
fig=plt.figure(figsize=(1.75,5.4))
ax=fig.add_subplot(111)

for i in range(N):
    ax.scatter( ratios[i],i,c="k",s=20,marker='d')
    ax.plot([cils[i],cihs[i]],[i,i],lw=1.5,c='k' )
    print(labels[i])


ax.axvline(x=0,ls='dashed',c='grey',lw=1)
ax.axvline(x=0.15,ls='dotted',c='grey')
ax.axvline(x=0.30,ls='dotted',c='grey')
ax.axvline(x=0.45,ls='dotted',c='grey')
ax.set_xlim(0,0.55)
ax.set_ylim(-0.5,N-0.5)   
ax.set_xticks([0,0.15,0.30,0.45])
ax.set_xticklabels(['0','15','30','45'],fontsize=12)
ax.set_yticks([])
ax.invert_yaxis()
ax.spines['top'   ].set_visible(False)# .set_color("w")
ax.spines['bottom'].set_visible(False)
ax.spines['left'  ].set_visible(False)
ax.spines['right' ].set_visible(False)
# Out:
# irGS_0
# irGS_1
# TMB_high_0.0
# TMB_high_1.0
# CancerTypeR_1_Melanoma
# CancerTypeR_2_Head_neck
# CancerTypeR_3_Lung
# CancerTypeR_4_Bladder
# CancerTypeR_5_Others
# ICI_single_0
# ICI_single_1
# Sex_male_0
# Sex_male_1
# Age_high_0.0
# Age_high_1.0

# %%
for i in ratios:
    print( '{:.1f}'.format(i*100) )
# Out:
# 11.8
# 34.5
# 16.4
# 43.3
# 32.2
# 18.6
# 30.6
# 26.6
# 13.7
# 31.0
# 26.4
# 24.3
# 28.1
# 25.2
# 26.5

# %% [markdown]
# # Each dataset

# %%
df=df0.copy()

# %%
cat1="irGS"
cat2="TMB_high"

# %%
class4=[]
for idx in df.index:
    if df.loc[idx,cat2]==1:
        if df.loc[idx,cat1]==1:
            class4.append("TMB high\nirGS")
        elif df.loc[idx,cat1]==0:
            class4.append("TMB high\nnon-irGS")
        else:
            class4.append("und")
    elif df.loc[idx,cat2]==0:
        if df.loc[idx,cat1]==1:
            class4.append("TMB low\nirGS")
        elif df.loc[idx,cat1]==0:
            class4.append("TMB low\nnon-irGS")
        else:
            class4.append("und")   
df["class4"]=class4

# %%
refs=list(df["Reference"].unique())
refs
# Out:
# ['Snyder, NEJM 2014',
#  'Van Allen, Science 2015',
#  'Hugo, Cell 2016',
#  'Riaz, Cell 2017',
#  'Roh, SciTraMed 2017',
#  'Liu, NatMed 2019',
#  'Rizvi, Science 2015',
#  'Hellmann, CanCel 2018',
#  'Anagnostou, NatCan 2020',
#  'Snyder, PlosMed 2017',
#  'Mariathasan, Nature 2018',
#  'Miao, NatGen 2018',
#  'Cristescu, Science 2018']

# %%
refs.insert(9,'')

# %%
fig=plt.figure(figsize=(12,7.5))

for i,ref in enumerate(refs):
    if ref =="":
        continue
    input_df=df[df["Reference"]==ref]
    ax=fig.add_subplot(3,5,i+1)
    sns_df=input_df.copy()
    ax.axhline(y=np.log10(174),color="k",ls="dashed")
    ax.axvline(x=0.5,color="k",ls="dashed")
    ax.set_ylim(0,4)
    ax.tick_params(labelsize=6)
    s=3
    if len(input_df)>=100:
        s=2.5
    ax=sns.swarmplot(x="irGS",y="Missense_Mutation_log10",order=[1,0],data=sns_df,
                     hue="Responder",palette=["k","red"],s=s)
    ax.legend([])
    ax.set_title(ref,fontsize=10)
    ax.set_xlabel("")#'TMB log10',fontsize=8)
    ax.set_ylabel("")
    ax.set_xticklabels(["irGS","Non-irGS"],fontsize=10)
    
    if i in [0,5,10]:
        ax.set_yticks([0,1,2,3,4])
        ax.set_yticklabels(["1","10","100","1000","10$^{4}$"], rotation=0, fontsize=8) 
    else:
        ax.set_yticklabels([])

plt.subplots_adjust(hspace=0.3,wspace=0.2)
#plt.savefig(path_to_res+"SciTra2017_MEL_OR_2dplot.png",dpi=300,bbox_inches="tight")

# %%
refs.remove('')
refs
# Out:
# ['Snyder, NEJM 2014',
#  'Van Allen, Science 2015',
#  'Hugo, Cell 2016',
#  'Riaz, Cell 2017',
#  'Roh, SciTraMed 2017',
#  'Liu, NatMed 2019',
#  'Rizvi, Science 2015',
#  'Hellmann, CanCel 2018',
#  'Anagnostou, NatCan 2020',
#  'Snyder, PlosMed 2017',
#  'Mariathasan, Nature 2018',
#  'Miao, NatGen 2018',
#  'Cristescu, Science 2018']

# %%
ct=pd.crosstab(df["Reference"],df["Tumor genomic subtype"])
ct.loc[refs,cluster_order2]
# Out:
# Tumor genomic subtype     SMK  UVL  APB  MRD  POL  HRD  GNS  AGE  UND
# Reference
# Snyder, NEJM 2014           0   20    0    0    0    1    0    1    0
# Van Allen, Science 2015     0   54    0    0    0    9    7   10   12
# Hugo, Cell 2016             0   20    0    0    0    1    0    0    1
# Riaz, Cell 2017             1   20    0    0    0    3    1    3    0
# Roh, SciTraMed 2017         1   11    0    0    0    4    0    4    1
# Liu, NatMed 2019            0   45    0    0    0    4    4    2    0
# Rizvi, Science 2015        17    0    2    0    0    6    1    5    3
# Hellmann, CanCel 2018      27    0    2    0    0    2    4    8    0
# Anagnostou, NatCan 2020    31    0    5    0    0    6    1   10    1
# Snyder, PlosMed 2017        0    0   12    1    0    1    0    7    1
# Mariathasan, Nature 2018    6    0  144    3    0   15    0   20   10
# Miao, NatGen 2018          13    5   33    0    0    7    0   11    2
# Cristescu, Science 2018    18   74   62    2    1   51    8   83   12
