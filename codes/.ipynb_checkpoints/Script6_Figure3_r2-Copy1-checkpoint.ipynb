# %% [markdown]
# # Evaluate prediction for ICI response, Figure3

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()
from scipy import stats
import sys,os
from collections import defaultdict, Counter
from matplotlib import patches
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.colors import to_rgba

# %%
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.stats.proportion import proportion_confint

# %%
print(sys.version)
# Out:
# 3.8.8 | packaged by conda-forge | (default, Feb 20 2021, 16:12:38)
# [Clang 11.0.1 ]

# %%
# %pip list | grep -e "numpy" -e "pandas" -e "matplotlib" -e "scipy" -e "seaborn"  -e "statsmodels" -e "sklearn"
# Out:
# matplotlib                    3.4.3
# matplotlib-inline             0.1.3
# numpy                         1.20.3
# pandas                        1.3.4
# scipy                         1.7.2
# seaborn                       0.11.2
# statsmodels                   0.13.1
# Note: you may need to restart the kernel to use updated packages.

# %%
plt.style.use('seaborn-white')
plt.rcParams['figure.figsize']=4,3
plt.rcParams['figure.dpi']=300
plt.rcParams['axes.linewidth'] =0.5
plt.rcParams['lines.linewidth'] =0.5
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# set font size
SMALL_SIZE = 7
MEDIUM_SIZE = 8
LARGE_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=LARGE_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('axes', linewidth=0.5) 
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)

# %%
store="../results/"

# %%
cluster_order=["SMK","UVL","APB","MRD","POL","HRD","GNS","AGE"]
cluster_order2=["SMK","UVL","APB","MRD","POL","HRD","GNS","AGE","UND"]
cluster_colors=["red","blue","green","purple","brown","hotpink","c","y"]
cluster_colors2=["red","blue","green","purple","brown","hotpink","c","y","grey"]

# %%
# import data
df0=pd.read_csv("/Users/tshiro/Desktop/Projects/pancancer_TMB_MSI_IRS/paper_preparation1/jupyter_notes/ICI_response_cohort_938_curated_20211106.tsv"
                ,sep="\t",index_col=0)

# %%
np.nanmedian(df0["Age"])
# Out:
# 61.5

# %%
ageh=[]
for idx in df0.index:
    if  df0.loc[idx,"Age"]>=62:
        ageh.append(1)
    elif df0.loc[idx,"Age"]<62:
        ageh.append(0)
    else:
        ageh.append(np.nan)
df0["Age_high"]=ageh

# %% [markdown]
# # TCRA score

# %%
tcex=pd.read_csv("/Users/tshiro/Desktop/Projects/pancancer_TMB_MSI_IRS/Data/Validation/TcellEXTRECT/second_results/ICI_cohort_TCRA_score_adjusted.tsv"
                ,sep="\t",index_col=0)
tcex
# Out:
#           purity  TCRA.cn  TCRA.tcell.fraction  TCRA.tcell.fraction.lwr  \
# sample
# 10006   0.360972      4.5         8.760993e-02                 0.053772
# 10007   0.318888      2.0         1.110223e-16                -0.053841
# 10008   0.454033      2.0         2.220446e-16                -0.053250
# 10010   0.540883      6.0         1.047337e-01                 0.069923
# 10012   0.412913      2.0         0.000000e+00                -0.052954
# ...          ...      ...                  ...                      ...
# TU0428  0.494996      2.0         2.276458e-02                -0.027972
# WA7899  0.584933      2.0         4.995573e-02                 0.001604
# Y2087   0.490697      2.0         1.536697e-01                 0.104344
# ZA6505  0.383018      3.5         1.755491e-02                -0.033354
# ZA6965  0.343820      2.5         2.367367e-01                 0.197223
#
#         TCRA.tcell.fraction.upr  TCRA.tcell.fraction.adj  \
# sample
# 10006                  0.120238             1.271409e-01
# 10007                  0.051090             1.110223e-16
# 10008                  0.050558             2.220446e-16
# 10010                  0.138242             2.180310e-01
# 10012                  0.050291             0.000000e+00
# ...                         ...                      ...
# TU0428                 0.070997             2.276458e-02
# WA7899                 0.095966             4.995573e-02
# Y2087                  0.200279             1.536697e-01
# ZA6505                 0.065956             2.259779e-02
# ZA6965                 0.274305             2.570854e-01
#
#         TCRA.tcell.fraction.adj.lwr  TCRA.tcell.fraction.adj.upr  \
# sample
# 10006                      0.078034                     0.174491
# 10007                     -0.053841                     0.051090
# 10008                     -0.053250                     0.050558
# 10010                      0.145563                     0.287787
# 10012                     -0.052954                     0.050291
# ...                             ...                          ...
# TU0428                    -0.027972                     0.070997
# WA7899                     0.001604                     0.095966
# Y2087                      0.104344                     0.200279
# ZA6505                    -0.042935                     0.084902
# ZA6965                     0.214176                     0.297883
#
#         highTcellFlag
# sample
# 10006           False
# 10007           False
# 10008           False
# 10010           False
# 10012           False
# ...               ...
# TU0428          False
# WA7899          False
# Y2087           False
# ZA6505          False
# ZA6965          False
#
# [1076 rows x 9 columns]

# %%
tcex=tcex.rename(columns={"TCRA.tcell.fraction.adj":"TCRA_T_cell_fraction"})

# %%
df0=pd.merge(df0,tcex,left_index=True,right_index=True,how="left")

# %%
clonaltmb=pd.read_csv("/Users/takamatsushiro/Desktop/pancancer_TMB_MSI_IRS/Data/Validation/Pyclone-vi/results2/ICI_cohort_pyclone_r2.tsv"
                      ,sep="\t",index_col=0)
clonaltmb#["MM_subclonal"]=clonaltmb["MM_total"]-clonaltmb["MM_clonal"]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_79139/507891173.py in <module>
# ----> 1 clonaltmb=pd.read_csv("/Users/takamatsushiro/Desktop/pancancer_TMB_MSI_IRS/Data/Validation/Pyclone-vi/results2/ICI_cohort_pyclone_r2.tsv"
#       2                       ,sep="\t",index_col=0)
#       3 clonaltmb#["MM_subclonal"]=clonaltmb["MM_total"]-clonaltmb["MM_clonal"]
#
# ~/.pyenv/versions/miniforge3-4.10/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.pyenv/versions/miniforge3-4.10/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/.pyenv/versions/miniforge3-4.10/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/.pyenv/versions/miniforge3-4.10/lib/python3.8/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/.pyenv/versions/miniforge3-4.10/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/.pyenv/versions/miniforge3-4.10/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/.pyenv/versions/miniforge3-4.10/lib/python3.8/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~/.pyenv/versions/miniforge3-4.10/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/takamatsushiro/Desktop/pancancer_TMB_MSI_IRS/Data/Validation/Pyclone-vi/results2/ICI_cohort_pyclone_r2.tsv'

# %% [markdown]
# clonaltmb=pd.read_csv("/Users/takamatsushiro/Desktop/pancancer_TMB_MSI_IRS/Data/Validation/Pyclone-vi/results2/ICI_cohort_pyclone_r2.tsv"
#                       ,sep="\t",index_col=0)
# clonaltmb#["MM_subclonal"]=clonaltmb["MM_total"]-clonaltmb["MM_clonal"]

# %%
clonaltmb=pd.read_csv("/Users/takamatsushiro/Desktop/pancancer_TMB_MSI_IRS/Data/Validation/Pyclone/ICI_res3_MM_clonal.tsv"
                      ,sep="\t",index_col=0)
clonaltmb.index=[x.replace("_pyc.tsv","") for x in clonaltmb.index]
clonaltmb.columns=["MM_"+x for x in clonaltmb.columns]
clonaltmb
# Out:
#            MM_total  MM_clonal  MM_subclonal
# 12A             172         11           161
# 15C             338        291            47
# 18A              52         42            10
# 18C              49         43             6
# 1D               75         75             0
# ...             ...        ...           ...
# SU2C-1024       248         24           224
# SU2C-1029       250        246             4
# VA1330            0          0             0
# Y2087           169         16           153
# ZA6965           88          4            84
#
# [399 rows x 3 columns]

# %%
a=set(df0.index)
b=set(clonaltmb.index)
len(a&b)
# Out:
# 307

# %%
df0=pd.merge(df0,clonaltmb[["MM_clonal","MM_subclonal","MM_total"]],left_index=True,right_index=True,how="left")

# %%
df0["clonalTMB_log10"]=np.log10(df0["MM_clonal"]+1)
df0["subclonalTMB_log10"]=np.log10(df0["MM_subclonal"]+1)
df0["totalcloneTMB_log10"]=np.log10(df0["MM_total"]+1)

# %%
sum(~df0["clonalTMB_log10"].isna())
# Out:
# 307

# %%
fig=plt.figure(figsize=(2,2))
ax=fig.add_subplot(111)
tmp_df=df0.copy()
val1,val2="Missense_Mutation_log10","subclonalTMB_log10"
tmp_df=tmp_df.dropna(subset=[val1,val2])
x=tmp_df[val1]
y=tmp_df[val2]
ax.scatter(x,y,s=0.5,c=["k"])
ax.set_xlabel("subclonal TMB")
ax.set_ylabel("TMB")
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(["1","10","100","1000","10$^{4}$"], rotation=0, fontsize=8) 
ax.set_yticks([0,1,2,3,4])
ax.set_yticklabels(["1","10","100","1000","10$^{4}$"], rotation=0, fontsize=8) 
r,p=stats.pearsonr(x,y)
print(r,p)
# Out:
# 0.2167938794718076 0.00012883663743950332

# %%
fig=plt.figure(figsize=(2,2))
ax=fig.add_subplot(111)
tmp_df=df0.copy()
val1,val2="Missense_Mutation_log10","clonalTMB_log10"
tmp_df=tmp_df.dropna(subset=[val1,val2])
x=tmp_df[val1]
y=tmp_df[val2]
ax.scatter(x,y,s=0.5,c=["k"])
ax.set_xlabel("clonal TMB")
ax.set_ylabel("TMB")
ax.set_xlim(0.5,4)
ax.set_ylim(0.5,4)
ax.set_xticks([1,2,3,4])
ax.set_xticklabels(["10","100","1000","10$^{4}$"], rotation=0, fontsize=8) 
ax.set_yticks([1,2,3,4])
ax.set_yticklabels(["10","100","1000","10$^{4}$"], rotation=0, fontsize=8) 
r,p=stats.pearsonr(x,y)
print(r,p)
# Out:
# 0.6448111308829338 1.7814843617714458e-37

# %%
fig=plt.figure(figsize=(2,2))
ax=fig.add_subplot(111)
tmp_df=df0.copy()
val1,val2="Missense_Mutation_log10","subclonalTMB_log10"
tmp_df=tmp_df.dropna(subset=[val1,val2])
x=tmp_df[val1]
y=tmp_df[val2]
ax.scatter(x,y,s=0.5,c=["k"])
ax.set_xlabel("subclonal TMB")
ax.set_ylabel("TMB")
ax.set_xlim(0.5,4)
ax.set_ylim(0.5,4)
ax.set_xticks([1,2,3,4])
ax.set_xticklabels(["10","100","1000","10$^{4}$"], rotation=0, fontsize=8) 
ax.set_yticks([1,2,3,4])
ax.set_yticklabels(["10","100","1000","10$^{4}$"], rotation=0, fontsize=8) 
r,p=stats.pearsonr(x,y)
print(r,p)
# Out:
# 0.2167938794718076 0.00012883663743950332

# %% [markdown]
# # Single Double therapy

# %%
single_therapy=[]
for idx in df0.index:
    if df0.loc[idx,"Treatment"] in ["CTLA4+PD1/PDL1","CTLA4+PD1","CTLA4->PD1"]:
        single_therapy.append(0)
    else:
        single_therapy.append(1)
df0["ICI_single"]=single_therapy

# %%
fig=plt.figure(figsize=(2.5,2.5))
ax=fig.add_subplot(111)
sns_df=df0.copy()
cat="Responder"
val="TCRA_T_cell_fraction"
hue=""
ax=sns.violinplot(x=cat,y=val,data=sns_df,sym="",alpha=0.5,palette=["red","grey"],order=[1,0])#,hue=hue)
ax=sns.swarmplot(x=cat,y=val,data=sns_df,s=1,palette=["k"],order=[1,0])#, hue=hue,dodge=True,)
ax.set_xlabel("")
ax.set_ylabel("TCRA T cell fraction")
ax.legend([])
ax.set_ylim(-0.1,0.7)
ax.set_yticks([0,0.2,0.4,0.6])
ax.set_xticklabels(['responder','non-responder'],fontsize=10)
ax.tick_params(axis="x",labelsize=10)
# Out:
# /Users/tshiro/.pyenv/versions/miniforge3-4.10/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 9.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/tshiro/.pyenv/versions/miniforge3-4.10/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 24.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
m3
# Out:
# 0.0532337988463895

# %%
fig=plt.figure(figsize=(2.5,2.5))
ax=fig.add_subplot(111)
val1,val2="Missense_Mutation_log10","TCRA_T_cell_fraction"
tmp_df=df0.copy()

m1=np.median( tmp_df[val1] )
m2=np.nanmean( tmp_df[val2] )
m3=np.nanmedian( tmp_df[val2] )

tmp_df=tmp_df[tmp_df["Responder"]==0]
tmp_df=tmp_df.dropna(subset=[val1,val2])
x=tmp_df[val1]
y=tmp_df[val2]
ax.scatter(x,y,s=1,c="grey")

tmp_df=df0.copy()
tmp_df=tmp_df[tmp_df["Responder"]==1]
tmp_df=tmp_df.dropna(subset=[val1,val2])
x=tmp_df[val1]
y=tmp_df[val2]
ax.scatter(x,y,s=1,c="red")

ax.axvline(m1,c="k",ls='dashed')
ax.axhline(m3,c="k",ls='dashed')

ax.set_ylabel('TCRA T cell fraction',fontsize=10)
ax.set_xlabel('Missense mutation',fontsize=10)

ax.set_xlim(0.5,4)
ax.set_ylim(-0.03,0.7)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(["1","10","100","1000","10$^{4}$"], rotation=0, fontsize=8) 
ax.set_yticks([0,0.2,0.4,0.6])
#ax.set_yticklabels(["10","100","1000","10$^{4}$"], rotation=0, fontsize=8) 

r,p=stats.pearsonr(x,y)
rS,pS=stats.spearmanr(x,y)

print(r,p,rS,pS)
# Out:
# -0.0066029705561217785 0.9233178973863507 0.036379500078564386 0.5957693424929992

# %%
df0["TMB-mh"]=df0['Missense_Mutation_log10']>=m1
df0["TCR-mh"]=df0['TCRA_T_cell_fraction']>=m3-0.03
pd.crosstab(df0["TMB-mh"],df0["TCR-mh"])
# Out:
# TCR-mh  False  True
# TMB-mh
# False     239   230
# True      229   240

# %%
c4=[]
for idx in df0.index:
    if df0.loc[idx,"TMB-mh"]==1:
        if df0.loc[idx,"TCR-mh"]==1:
            c4.append('TMBh_TCRh')
        elif df0.loc[idx,"TCR-mh"]==0:
            c4.append('TMBh_TCRl')
        else:
            c4.append(np.nan)
    elif df0.loc[idx,"TMB-mh"]==0:
        if df0.loc[idx,"TCR-mh"]==1:
            c4.append('TMBl_TCRh')
        elif df0.loc[idx,"TCR-mh"]==0:
            c4.append('TMBl_TCRl')
        else:
            c4.append(np.nan)
    else:
        c4.append(np.nan)
    
df0["TMB-TCR"]=c4

# %%
df0.groupby('TMB-TCR').mean()['Responder']
# Out:
# TMB-TCR
# TMBh_TCRh    0.379167
# TMBh_TCRl    0.406114
# TMBl_TCRh    0.160870
# TMBl_TCRl    0.138075
# Name: Responder, dtype: float64

# %%
ct4=pd.crosstab(df0["TMB-TCR"],df0['Responder']).T
ct4
# Out:
# TMB-TCR    TMBh_TCRh  TMBh_TCRl  TMBl_TCRh  TMBl_TCRl
# Responder
# 0.0              104        193         98        289
# 1.0               58        129         23         44

# %%
ratios=[]
errors=[]
labels=[]
for col in ct4.columns:
    count=ct4.loc[1,col]
    nobs=np.sum( ct4.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,method="binom_test",alpha=0.05)
    
    ratios.append(ratio)   
    errors.append(np.array(cil-ratio, cih-ratio))
    labels.append(col)
    
    print(str(count)+"/"+str(nobs))

# %%
fig=plt.figure(figsize=(2.5,2.5))
ax=fig.add_subplot(111)
tmp_df=df0.copy()
tmp_df=tmp_df[tmp_df["qualified"]==1]
tmp_df=tmp_df[tmp_df["Responder"]==0]
val1,val2="Missense_Mutation_log10","TCRA_tcell_fraction2_scaled"
tmp_df=tmp_df.dropna(subset=[val1,val2])
x=tmp_df[val1]
y=tmp_df[val2]
ax.scatter(x,y,s=1,c="grey")

tmp_df=df0.copy()
tmp_df=tmp_df[tmp_df["qualified"]==1]
tmp_df=tmp_df[tmp_df["Responder"]==1]
val1,val2="Missense_Mutation_log10","TCRA_tcell_fraction2_scaled"
tmp_df=tmp_df.dropna(subset=[val1,val2])
x=tmp_df[val1]
y=tmp_df[val2]
ax.scatter(x,y,s=1,c="red")



ax.set_xlabel(val1)
ax.set_ylabel(val2)


ax.set_xlim(0.5,4)
ax.set_ylim(-0.03,1)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(["1","10","100","1000","10$^{4}$"], rotation=0, fontsize=8) 
#ax.set_yticks([1,2,3,4])
#ax.set_yticklabels(["10","100","1000","10$^{4}$"], rotation=0, fontsize=8) 

r,p=stats.pearsonr(x,y)
rS,pS=stats.spearmanr(x,y)

print(r,p,rS,pS)
# Out:
# -0.02667308375632358 0.7014499805573504 -0.0081249365186953 0.9070515791121175

# %%
fig=plt.figure(figsize=(2.5,2.5))
ax=fig.add_subplot(111)
tmp_df=df0.copy()
tmp_df=tmp_df[tmp_df["qualified"]==1]
tmp_df=tmp_df[tmp_df["Responder"]==0]
val1,val2="Missense_Mutation_log10","TCRA_tcell_fraction2_scaled"
tmp_df=tmp_df.dropna(subset=[val1,val2])
x=tmp_df[val1]
y=tmp_df[val2]
ax.scatter(x,y,s=1,c="grey")

tmp_df=df0.copy()
tmp_df=tmp_df[tmp_df["qualified"]==1]
tmp_df=tmp_df[tmp_df["Responder"]==1]
val1,val2="Missense_Mutation_log10","TCRA_tcell_fraction2_scaled"
tmp_df=tmp_df.dropna(subset=[val1,val2])
x=tmp_df[val1]
y=tmp_df[val2]
ax.scatter(x,y,s=1,c="red")



ax.set_xlabel(val1)
ax.set_ylabel(val2)


ax.set_xlim(0.5,4)
ax.set_ylim(-0.03,1)
ax.set_xticks([0,1,2,3,4])
ax.set_xticklabels(["1","10","100","1000","10$^{4}$"], rotation=0, fontsize=8) 
#ax.set_yticks([1,2,3,4])
#ax.set_yticklabels(["10","100","1000","10$^{4}$"], rotation=0, fontsize=8) 

r,p=stats.pearsonr(x,y)
rS,pS=stats.spearmanr(x,y)

print(r,p,rS,pS)
# Out:
# -0.02667308375632358 0.7014499805573504 -0.0081249365186953 0.9070515791121175

# %% [markdown]
# # TMB cut-off from FM-ONE

# %%
# import Passing Bablok regression results in R
pb_para=pd.read_csv("../analysis_in_R/Passing_Bablok_results.tsv"
                    ,sep="\t",index_col=0)
pb_para
# Out:
#                 EST  SE       LCI       UCI
# Intercept  1.814174 NaN  0.973855  2.791982
# Slope      0.047230 NaN  0.040266  0.052601

# %%
cutoff1=( 10-pb_para.loc["Intercept","EST"]) /pb_para.loc["Slope","EST"]
cutoff1
# Out:
# 173.3166492146599

# %%
# check CI
cutoff1_l=( 10-pb_para.loc["Intercept","LCI"]) /pb_para.loc["Slope","LCI"]
cutoff1_u=( 10-pb_para.loc["Intercept","UCI"]) /pb_para.loc["Slope","UCI"]
print(cutoff1_l,cutoff1_u)
# Out:
# 224.1649670514298 137.03253770579335

# %%
blca2018=pd.read_csv("../analysis_in_R/Nature2018_BLCA_FM1_WES.tsv",sep="\t",index_col=0)

# %%
fig=plt.figure(figsize=(3,3))
ax=fig.add_subplot(111)
tmp_df=blca2018.copy()
val1,val2="Missense_Mutation","FMOne mutation burden per MB"
tmp_df=tmp_df.dropna(subset=[val1,val2])
x=tmp_df[val1]
y=tmp_df[val2]
ax.scatter(x,y,s=10,fc="None",ec="k",lw=0.5)

r,p=stats.pearsonr(x,y)
print("r= {:.3f}, P= {:.2e}".format(r,p))

y2=pb_para.loc["Intercept","EST"]+pb_para.loc["Slope","EST"]*x

ax.plot(x,y2,c="red",lw=1)

y3=pb_para.loc["Intercept","LCI"]+pb_para.loc["Slope","LCI"]*x
y4=pb_para.loc["Intercept","UCI"]+pb_para.loc["Slope","UCI"]*x

ax.plot(x,y3,c="red",ls="dotted",lw=0.75)
ax.plot(x,y4,c="red",ls="dotted",lw=0.75)

ax.axhline(y=10,xmin=0,xmax=0.8,color="blue",ls="dashed")

ax.axvline(x=cutoff1,ymin=0,ymax=0.8,color="blue",ls="dashed")

ax.set_xlabel("Missense mutation",fontsize=10)
ax.set_ylabel(val2,fontsize=10)
ax.set_xticks([0,200,500,1000,1300])
ax.set_yticks([0,10,20,40,60])
ax.tick_params(labelsize=8)

ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
# Out:
# r= 0.820, P= 2.91e-54

# %%
blca2018["FM_high"]=(blca2018["FMOne mutation burden per MB"]>=10).astype(int)
blca2018["MM_high"]=(blca2018["Missense_Mutation"]>=cutoff1).astype(int)
ct=pd.crosstab(blca2018["FM_high"],blca2018["MM_high"])
ct
# Out:
# MM_high    0   1
# FM_high
# 0        118  19
# 1         22  59

# %%
from sklearn.metrics import cohen_kappa_score
cohen_kappa_score(blca2018["FM_high"],blca2018["MM_high"])
# Out:
# 0.5942068464541905

# %% [markdown]
# # TMB cut-off by ROC

# %%
# ROC curve, AUC, explore optimal threshold
from sklearn.metrics import roc_curve,roc_auc_score,auc
flag="Responder"
value="Missense_Mutation"
plt_df=df0.copy()

# %%
fig=plt.figure(figsize=(2,2))
ax=fig.add_subplot(111)
sns_df=plt_df.copy()
cat=flag
val="Missense_Mutation_log10"
ax=sns.swarmplot(x=cat,y=val,data=sns_df,s=1.25,order=[1,0],palette=["red","black"])
ax.set_xlabel("")
ax.set_ylabel("")
ax.legend([])
ax.set_title("",fontsize=10)
ax.tick_params(axis="both",labelsize=6)

ax.set_xticklabels(["Responder","Non-responder"], rotation=0, fontsize=8)
ax.set_yticks([0,1,2,3,4])
ax.set_yticklabels(["1","10","100","1000","10$^{4}$"], rotation=0, fontsize=8)

ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

# %%
# plot ROC curve
plt_df=plt_df.loc[:,[flag,value]].dropna()
y_true=plt_df[flag]
y_score=plt_df[value]
fpr, tpr, thresholds = roc_curve(y_true, y_score)
auc=roc_auc_score(y_true, y_score)

fig=plt.figure(figsize=(2,2))
ax=fig.add_subplot(111)
ax.plot(fpr, tpr, marker='o',ms=0.5,c="k")
ax.set_xlabel('FPR: False positive rate',fontsize=8)
ax.set_ylabel('TPR: True positive rate',fontsize=8)
ax.plot(np.linspace(0,1), np.linspace(0,1), c="r",ls="dotted")
ax.tick_params(labelsize=6)

# Youden index
yd_idx = np.argmax( abs(tpr -fpr) )
yd_threshold = thresholds[yd_idx]
print("Youden index: TPR={:.2f},　FPR={:.2f},　Threshold={:.2f}".format(tpr[yd_idx],fpr[yd_idx],yd_threshold))

# plot with Threshold
arrow_dict = dict(color = "black",arrowstyle = "->")
ax.annotate("Threshold\n= {}".format(thresholds[yd_idx]),xy=(fpr[yd_idx],tpr[yd_idx]),
             size=10,xytext=(fpr[yd_idx]-0.3,tpr[yd_idx]+0.2), arrowprops = arrow_dict )

ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
# Out:
# Youden index: TPR=0.65,　FPR=0.30,　Threshold=165.00

# %%
df0["TMB_high"]=(df0["Missense_Mutation"]>cutoff1).astype(float)
df0["TMB_high2"]=(df0["Missense_Mutation"]>yd_threshold).astype(float)

# %% [markdown]
# # Compare response rate

# %% [markdown]
# ## irGS vs non irGS

# %%
df=df0.copy()

# %%
input_df=df.copy()
flag="Responder"
cat1="irGS"
value="Missense_Mutation_log10"
ct=pd.crosstab(input_df[flag],input_df[cat1])
ct=ct.loc[:,[1,0]]
ct
# Out:
# irGS         1    0
# Responder
# 0.0        404  280
# 1.0        216   38

# %%
_,p=stats.fisher_exact(ct)
res=stats.chi2_contingency(ct,correction=False)
print("Fisher p= %.2e"%p)
print("Chi-square p= %.2e"%res[1])
# Out:
# Fisher p= 7.16e-15
# Chi-square p= 8.15e-14

# %%
ratios=[]
errors=[]
labels=[]
for col in ct.columns:
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,method="binom_test",alpha=0.05)
    
    ratios.append(ratio)
    errors.append(np.array(cil-ratio, cih-ratio))
    labels.append(col)
    
    print(str(count)+"/"+str(nobs))

# %%
n=len(ratios)
left=range(n)
colors=["red","w"]
colors=[to_rgba(x,0.5) for x in colors]
fig=plt.figure(figsize=((1.3,2)))
ax=fig.add_subplot(111)
ax.bar(x=left,height=ratios,yerr=errors,
       tick_label=labels,color=colors,capsize=5,width=0.6,edgecolor="k",lw=0.5)
ax.tick_params(labelsize=6)

ax.set_xticklabels([], rotation=0, fontsize=8)
ax.set_ylim(0,0.6)
ax.legend([])


ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %% [markdown]
# ## TMB high vs low

# %%
input_df=df.copy()
cat2="TMB_high"
ct=pd.crosstab(input_df[flag],input_df[cat2])
ct=ct.loc[:,[1,0]]
ct
# Out:
# TMB_high     1    0
# Responder
# 0.0        201  483
# 1.0        157   97

# %%
_,p=stats.fisher_exact(ct)
res=stats.chi2_contingency(ct,correction=False)
print("Fisher p= %.2e"%p)
print("Chi-square p= %.2e"%res[1])
# Out:
# Fisher p= 2.62e-19
# Chi-square p= 1.05e-19

# %%
ratios=[]
errors=[]
labels=[]
for col in ct.columns:
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,method="binom_test",alpha=0.05)
    
    ratios.append(ratio)
    errors.append(np.array(cil-ratio, cih-ratio))
    labels.append(col)
    
    print(str(count)+"/"+str(nobs))
# Out:
# 157/358
# 97/580

# %%
n=len(ratios)
left=range(n)
colors=["green","w"]
colors=[to_rgba(x,0.5) for x in colors]
fig=plt.figure(figsize=((1.3,2)))
ax=fig.add_subplot(111)
ax.bar(x=left,height=ratios,yerr=errors,
       tick_label=labels,color=colors,capsize=5,width=0.6,edgecolor="k",lw=0.5)
ax.tick_params(labelsize=6)

ax.set_xticklabels([], rotation=0, fontsize=8)
ax.legend([])
ax.set_ylim(0,0.6)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %% [markdown]
# ## 2D plot

# %%
fig=plt.figure(figsize=(3,3.5))
ax=fig.add_subplot(111)
sns.swarmplot(x=cat1,y=value,data=df,
              s=2,ax=ax,hue=flag,hue_order=[0,1],
              palette=["k","red"],
             order=[1,0])
ax.set_ylabel("",fontsize=8)
ax.set_xlabel("")
ax.axhline(y=np.log10(cutoff1),c="dimgrey",lw=1,ls="dashed")
ax.axvline(x=0.5,c="dimgrey",lw=1,ls="dashed")
ax.tick_params(labelsize=6)
ax.set_xticklabels([])
ax.set_yticks([0,1,2,3,4])
ax.set_ylim(0,4.2)
ax.set_yticklabels(["1","10","100","1000","10$^{4}$"], rotation=0, fontsize=8)
ax.legend([])

   
p1=patches.Rectangle(xy=(-0.5,0),width=1,height=np.log10(cutoff1+1),ec="w",fc="red",alpha=0.2,
                     linewidth=0)
p2=patches.Rectangle(xy=(-0.5,np.log10(cutoff1+1)),width=1,height=4.2-np.log10(cutoff1+1),
                      ec="w",fc="k",alpha=0.2,
                     linewidth=0)
p3=patches.Rectangle(xy=(0.5,np.log10(cutoff1+1)),width=1,height=4.2-np.log10(cutoff1+1),
                      ec="w",fc="green",alpha=0.2,
                     linewidth=0)

ax.add_patch(p1)
ax.add_patch(p2)
ax.add_patch(p3)

# %%
class4=[]
for idx in df.index:
    if df.loc[idx,cat2]==1:
        if df.loc[idx,cat1]==1:
            class4.append("TMB high\nirGS")
        elif df.loc[idx,cat1]==0:
            class4.append("TMB high\nnon-irGS")
        else:
            class4.append("und")
    elif df.loc[idx,cat2]==0:
        if df.loc[idx,cat1]==1:
            class4.append("TMB low\nirGS")
        elif df.loc[idx,cat1]==0:
            class4.append("TMB low\nnon-irGS")
        else:
            class4.append("und")   
df["class4"]=class4

# %%
ct4=pd.crosstab(df["class4"],df[flag]).T
ct4=ct4.reindex(['TMB high\nirGS', 'TMB high\nnon-irGS', 'TMB low\nirGS','TMB low\nnon-irGS'],axis=1)
ct4
# Out:
# class4     TMB high\nirGS  TMB high\nnon-irGS  TMB low\nirGS  \
# Responder
# 0.0                   195                   6            209
# 1.0                   153                   4             63
#
# class4     TMB low\nnon-irGS
# Responder
# 0.0                      274
# 1.0                       34

# %%
# compare between TMB-low groups
ct=ct4.loc[:, ["TMB low\nirGS","TMB low\nnon-irGS"]]
res=stats.chi2_contingency(ct,correction=False)
display(ct)
print("Chi-square p= %.2e"%res[1])
# Out:
# class4     TMB low\nirGS  TMB low\nnon-irGS
# Responder
# 0.0                  209                274
# 1.0                   63                 34
# Chi-square p= 9.46e-05

# %%
ratios=[]
errors=[]
labels=[]
for col in ct4.columns:
    count=ct4.loc[1,col]
    nobs=np.sum( ct4.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,method="binom_test",alpha=0.05)
    
    ratios.append(ratio)   
    errors.append(np.array(cil-ratio, cih-ratio))
    labels.append(col)
    
    print(str(count)+"/"+str(nobs))
# Out:
# 153/348
# 4/10
# 63/272
# 34/308

# %%
n=len(ratios)
left=range(n)
colors=["dimgrey","lightgrey"]*n
colors=["k","green","red","white"]
colors=[to_rgba(x, 0.5) for x in colors ]

fig=plt.figure(figsize=(3,2.5))
ax=fig.add_subplot(111)
ax.bar(x=left,height=ratios,yerr=errors,
       tick_label=labels,color=colors,capsize=5,width=0.6,edgecolor="k",lw=0.5)
ax.tick_params(labelsize=6)
ax.set_xticklabels(labels, rotation=0, fontsize=8)
ax.legend([])
ax.set_ylim(0,0.8)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %% [markdown]
# ## Logistic regression

# %%
df=df0.copy()

# %%
Counter(df["irGS"])
# Out:
# Counter({1: 620, 0: 318})

# %%
Counter(df["TMB_high"])
# Out:
# Counter({1.0: 358, 0.0: 580})

# %%
Counter(df["CancerType"])
# Out:
# Counter({'Melanoma': 335,
#          'Lung': 127,
#          'Bladder': 263,
#          'HNSCC': 118,
#          'Others': 95})

# %%
df["CancerTypeR"]=df["CancerType"].replace(
        {'Melanoma':"1_Melanoma",
         'Lung': "3_Lung",
         'Bladder': "4_Bladder",
         'HNSCC': "2_Head_neck",
         'Others': "5_Others"})

# %%
Counter(df["Sex"])
# Out:
# Counter({'Female': 326, 'Male': 612})

# %%
df["Sex_male"]=(df["Sex"]=="Male").astype(int)

# %%
Counter(df["Age_high"])
# Out:
# Counter({0.0: 319,
#          1.0: 319,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1})

# %%
df["Double"]=(df["ICI_single"]==1).astype(float)

# %%
Counter(df["Double"])
# Out:
# Counter({1.0: 862, 0.0: 76})

# %%
Y="Responder"
categories=["irGS","Missense_Mutation_log10",#"nsSNV_log10",
            #"clonalTMB_log10",
           # "subclonalTMB_log10","totalcloneTMB_log10",
            "TCRA_T_cell_fraction","CancerTypeR","Sex_male","Age_high","Double"]

# %%
# univariate
univ_integrated=pd.DataFrame()

for cat in categories:
    input_df=df.copy()
    formula = Y+" ~ "+cat
    family = sm.families.Binomial()
    model = smf.glm(formula=formula, data=input_df, family=family)
    res = model.fit()
    res_df=pd.concat( [ np.exp(res.params), np.exp(res.conf_int(alpha=0.05)),res.pvalues],axis=1)
    add=res_df.iloc[1:,:]

    univ_integrated=pd.concat([univ_integrated,add])

univ_integrated.columns=["Odds ratio","CI 5%","CI 95%", "P-value"]

res_df=univ_integrated
res_df["95%CI"]=["({:.2f} - {:.2f})".format(x,y) for x,y in zip(res_df["CI 5%"],res_df["CI 95%"])  ]
display( np.round(res_df[["Odds ratio","95%CI","P-value"]],3) )

for i in res_df["P-value"]:
    print("{:.2e}".format(i))
# Out:
#                             Odds ratio           95%CI  P-value
# irGS                             3.940   (2.70 - 5.74)    0.000
# Missense_Mutation_log10          4.006   (2.91 - 5.52)    0.000
# TCRA_T_cell_fraction             4.067  (1.10 - 15.06)    0.036
# CancerTypeR[T.2_Head_neck]       0.482   (0.29 - 0.81)    0.006
# CancerTypeR[T.3_Lung]            1.002   (0.65 - 1.55)    0.993
# CancerTypeR[T.4_Bladder]         0.762   (0.53 - 1.09)    0.136
# CancerTypeR[T.5_Others]          0.333   (0.18 - 0.62)    0.001
# Sex_male                         1.192   (0.88 - 1.62)    0.262
# Age_high                         1.067   (0.75 - 1.52)    0.719
# Double                           0.844   (0.51 - 1.41)    0.515
# 1.01e-12
# 1.79e-17
# 3.57e-02
# 5.60e-03
# 9.93e-01
# 1.36e-01
# 6.08e-04
# 2.62e-01
# 7.19e-01
# 5.15e-01

# %%
# multivariate
categories=["irGS","TMB_high","CancerTypeR",]#"TCRA_tcell_fraction"]
input_df=df.copy()
res = smf.glm(formula = Y+" ~ "+"+".join(categories),
                  data = input_df,
                  family = sm.families.Binomial()).fit()

res_df=pd.concat( [ np.exp(res.params), np.exp(res.conf_int(alpha=0.05)),res.pvalues],axis=1)
res_df.columns=["Odds ratio","CI 5%","CI 95%", "p-value"]
res_df["95%CI"]=["({:.2f} - {:.2f})".format(x,y) for x,y in zip(res_df["CI 5%"],res_df["CI 95%"])  ]
display( np.round(res_df[["Odds ratio","95%CI","p-value"]],3) )

for i in res_df["p-value"]:
    print("{:.2e}".format(i))
# Out:
#                             Odds ratio          95%CI  p-value
# Intercept                        0.135  (0.09 - 0.21)    0.000
# CancerTypeR[T.2_Head_neck]       0.838  (0.48 - 1.46)    0.531
# CancerTypeR[T.3_Lung]            1.333  (0.83 - 2.13)    0.229
# CancerTypeR[T.4_Bladder]         0.879  (0.60 - 1.29)    0.506
# CancerTypeR[T.5_Others]          0.889  (0.44 - 1.78)    0.739
# irGS                             2.223  (1.41 - 3.50)    0.001
# TMB_high                         2.684  (1.88 - 3.83)    0.000
# 1.55e-19
# 5.31e-01
# 2.29e-01
# 5.06e-01
# 7.39e-01
# 5.44e-04
# 5.59e-08

# %%
# multivariate
categories=["irGS","Missense_Mutation_log10","CancerTypeR",]#"TCRA_tcell_fraction"]
input_df=df.copy()
res = smf.glm(formula = Y+" ~ "+"+".join(categories),
                  data = input_df,
                  family = sm.families.Binomial()).fit()

res_df=pd.concat( [ np.exp(res.params), np.exp(res.conf_int(alpha=0.05)),res.pvalues],axis=1)
res_df.columns=["Odds ratio","CI 5%","CI 95%", "p-value"]
res_df["95%CI"]=["({:.2f} - {:.2f})".format(x,y) for x,y in zip(res_df["CI 5%"],res_df["CI 95%"])  ]
display( np.round(res_df[["Odds ratio","95%CI","p-value"]],3) )

for i in res_df["p-value"]:
    print("{:.2e}".format(i))
# Out:
#                             Odds ratio          95%CI  p-value
# Intercept                        0.025  (0.01 - 0.06)    0.000
# CancerTypeR[T.2_Head_neck]       0.848  (0.49 - 1.48)    0.561
# CancerTypeR[T.3_Lung]            1.330  (0.84 - 2.12)    0.230
# CancerTypeR[T.4_Bladder]         0.901  (0.61 - 1.32)    0.591
# CancerTypeR[T.5_Others]          0.912  (0.45 - 1.84)    0.796
# irGS                             1.924  (1.20 - 3.08)    0.007
# Missense_Mutation_log10          2.843  (1.90 - 4.26)    0.000
# 1.44e-16
# 5.61e-01
# 2.30e-01
# 5.91e-01
# 7.96e-01
# 6.57e-03
# 3.86e-07

# %%
# multivariate
categories=["irGS","clonalTMB_log10","CancerTypeR",]#"TCRA_tcell_fraction"]
input_df=df.copy()
res = smf.glm(formula = Y+" ~ "+"+".join(categories),
                  data = input_df,
                  family = sm.families.Binomial()).fit()

res_df=pd.concat( [ np.exp(res.params), np.exp(res.conf_int(alpha=0.05)),res.pvalues],axis=1)
res_df.columns=["Odds ratio","CI 5%","CI 95%", "p-value"]
res_df["95%CI"]=["({:.2f} - {:.2f})".format(x,y) for x,y in zip(res_df["CI 5%"],res_df["CI 95%"])  ]
display( np.round(res_df[["Odds ratio","95%CI","p-value"]],3) )

for i in res_df["p-value"]:
    print("{:.2e}".format(i))
# Out:
#                             Odds ratio          95%CI  p-value
# Intercept                        0.201  (0.09 - 0.46)    0.000
# CancerTypeR[T.2_Head_neck]       0.692  (0.32 - 1.49)    0.346
# CancerTypeR[T.3_Lung]            1.245  (0.55 - 2.84)    0.603
# CancerTypeR[T.4_Bladder]         1.188  (0.55 - 2.58)    0.663
# CancerTypeR[T.5_Others]          0.418  (0.13 - 1.32)    0.138
# irGS                             1.986  (1.01 - 3.90)    0.046
# clonalTMB_log10                  1.181  (0.77 - 1.80)    0.440
# 1.30e-04
# 3.46e-01
# 6.03e-01
# 6.63e-01
# 1.38e-01
# 4.60e-02
# 4.40e-01

# %%
sum(~df["TCRA_tcell_fraction2"].isna())
# Out:
# 815

# %%
# multivariate
categories=["irGS","TMB_high","TCRA_tcell_fraction2","CancerTypeR"]
input_df=df.copy()
res = smf.glm(formula = Y+" ~ "+"+".join(categories),
                  data = input_df,
                  family = sm.families.Binomial()).fit()

res_df=pd.concat( [ np.exp(res.params), np.exp(res.conf_int(alpha=0.05)),res.pvalues],axis=1)
res_df.columns=["Odds ratio","CI 5%","CI 95%", "p-value"]
res_df["95%CI"]=["({:.2f} - {:.2f})".format(x,y) for x,y in zip(res_df["CI 5%"],res_df["CI 95%"])  ]
display( np.round(res_df[["Odds ratio","95%CI","p-value"]],3) )

for i in res_df["p-value"]:
    print("{:.2e}".format(i))
# Out:
#                             Odds ratio           95%CI  p-value
# Intercept                        0.113   (0.07 - 0.19)    0.000
# CancerTypeR[T.2_Head_neck]       0.797   (0.44 - 1.44)    0.450
# CancerTypeR[T.3_Lung]            1.261   (0.71 - 2.23)    0.426
# CancerTypeR[T.4_Bladder]         0.890   (0.58 - 1.37)    0.597
# CancerTypeR[T.5_Others]          1.040   (0.51 - 2.14)    0.915
# irGS                             2.510   (1.54 - 4.09)    0.000
# TMB_high                         2.284   (1.56 - 3.35)    0.000
# TCRA_tcell_fraction2             3.703  (0.77 - 17.77)    0.102
# 1.32e-16
# 4.50e-01
# 4.26e-01
# 5.97e-01
# 9.15e-01
# 2.26e-04
# 2.45e-05
# 1.02e-01

# %%
fig=plt.figure(figsize=(3,3.5))
ax=fig.add_subplot(111)
sns.swarmplot(x=cat1,y="clonalTMB_log10",data=df,
              s=2,ax=ax,hue=flag,hue_order=[0,1],
              palette=["k","red"],
             order=[1,0])
ax.set_ylabel("",fontsize=8)
ax.set_xlabel("")
ax.axhline(y=np.log10(cutoff1),c="dimgrey",lw=1,ls="dashed")
ax.axvline(x=0.5,c="dimgrey",lw=1,ls="dashed")
ax.tick_params(labelsize=6)
ax.set_xticklabels([])
ax.set_yticks([0,1,2,3,4])
ax.set_ylim(0,4.2)
ax.set_yticklabels(["1","10","100","1000","10$^{4}$"], rotation=0, fontsize=8)
ax.legend([])

   
p1=patches.Rectangle(xy=(-0.5,0),width=1,height=np.log10(cutoff1+1),ec="w",fc="red",alpha=0.2,
                     linewidth=0)
p2=patches.Rectangle(xy=(-0.5,np.log10(cutoff1+1)),width=1,height=4.2-np.log10(cutoff1+1),
                      ec="w",fc="k",alpha=0.2,
                     linewidth=0)
p3=patches.Rectangle(xy=(0.5,np.log10(cutoff1+1)),width=1,height=4.2-np.log10(cutoff1+1),
                      ec="w",fc="green",alpha=0.2,
                     linewidth=0)

ax.add_patch(p1)
ax.add_patch(p2)
ax.add_patch(p3)

# %% [markdown]
# ## Precision-recall curve
# ** https://scikit-learn.org/stable/auto_examples/model_selection/plot_precision_recall.html#sphx-glr-auto-examples-model-selection-plot-precision-recall-py

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
dummy=pd.get_dummies( df["CancerTypeR"],drop_first=True)

# %%
df=pd.merge(df,dummy,left_index=True,right_index=True,how="inner")

# %%
categories=["irGS", "Missense_Mutation_log10","TCRA.tcell.fraction",]

# %%
plt_dfs=[]
aucs=[]

# %%
cat1=["Missense_Mutation_log10"]
cat2=["Missense_Mutation_log10","irGS"]
cat3=["Missense_Mutation_log10","irGS","TCRA.tcell.fraction"]
cat4=["TCRA.tcell.fraction"]
cat5=["Missense_Mutation_log10","TCRA.tcell.fraction"]

# %%
cats=[cat1,cat2,cat3,cat4,cat5]

# %%
for cat in cats:
    tmp_df=df[["Responder","2_Head_neck","3_Lung","4_Bladder","5_Others"]+cat].dropna()
    y=tmp_df["Responder"]
    X=tmp_df[cat]
    lr = LogisticRegression(max_iter=1000, penalty='none')
    lr.fit(X, y)
    probs = lr.predict_proba(X)[:,1]
    preds = lr.predict(X)
    precision, recall, thresholds = metrics.precision_recall_curve(y, probs)
    auc = metrics.auc(recall, precision)

    plt_df = pd.DataFrame({"Recall":recall, "Precision":precision} )
    fig=plt.figure(figsize=(4,3))
    ax=fig.add_subplot(111)
    tmp_df=plt_df.copy()
    val1,val2="Recall","Precision"
    tmp_df=tmp_df.dropna(subset=[val1,val2])
    x=tmp_df[val1]
    y=tmp_df[val2]
    ax.plot(x,y)
    ax.set_xlabel(val1)
    ax.set_ylabel(val2)

    plt_dfs.append(plt_df)
    aucs.append(auc)

# %%
fig=plt.figure(figsize=(4,3))
ax=fig.add_subplot(111)
for plt_df,cat,auc in zip(plt_dfs,cats,aucs):
    tmp_df=plt_df.copy()
    val1,val2="Recall","Precision"
    tmp_df=tmp_df.dropna(subset=[val1,val2])
    x=tmp_df[val1]
    y=tmp_df[val2]
    ax.plot(x,y,label=",".join(cat)+" AUC:{:1f}".format(auc),lw=1)
    ax.set_xlabel(val1)
    ax.set_ylabel(val2)
    ax.legend(bbox_to_anchor=(1,1))

# %% [markdown]
# # ROC

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
plt_dfs=[]
aucs=[]
cat1=["Missense_Mutation_log10"]
cat2=["Missense_Mutation_log10","irGS"]
cat3=["Missense_Mutation_log10","irGS","TCRA.tcell.fraction"]
cat4=["TCRA.tcell.fraction"]
cat5=["Missense_Mutation_log10","TCRA.tcell.fraction"]
cats=[cat1,cat2,cat3,cat4,cat5]

# %%
for cat in cats:
    tmp_df=df[["Responder","2_Head_neck","3_Lung","4_Bladder","5_Others"]+cat].dropna()
    y=tmp_df["Responder"]
    X=tmp_df[cat]
    lr = LogisticRegression(max_iter=1000, penalty='none')
    lr.fit(X, y)
    probs = lr.predict_proba(X)[:,1]
    preds = lr.predict(X)
    fpr, tpr, _ = roc_curve(y, probs)
    auc = roc_auc_score(y,probs)

    plt_df = pd.DataFrame({"False Positive Rate":fpr, "True Positive Rate":tpr} )
    
    fig=plt.figure(figsize=(4,3))
    ax=fig.add_subplot(111)
    tmp_df=plt_df.copy()
    val1,val2="False Positive Rate","True Positive Rate"
    tmp_df=tmp_df.dropna(subset=[val1,val2])
    x=tmp_df[val1]
    y=tmp_df[val2]
    ax.plot(x,y)
    ax.set_xlabel(val1)
    ax.set_ylabel(val2)

    plt_dfs.append(plt_df)
    aucs.append(auc)

# %%
fig=plt.figure(figsize=(4,3))
ax=fig.add_subplot(111)
for plt_df,cat,auc in zip(plt_dfs,cats,aucs):
    tmp_df=plt_df.copy()
    val1,val2="False Positive Rate","True Positive Rate"
    tmp_df=tmp_df.dropna(subset=[val1,val2])
    x=tmp_df[val1]
    y=tmp_df[val2]
    ax.plot(x,y,label=",".join(cat)+" AUC:{:1f}".format(auc),lw=1)
    ax.set_xlabel(val1)
    ax.set_ylabel(val2)
    ax.legend(bbox_to_anchor=(1,1))

# %% [markdown]
# # Response per subtype

# %%
df=df0.copy()

# %%
ct=pd.crosstab(df["Responder"],df["TGS"])
ct=ct.loc[:,cluster_order2]
ct

# %%
# bar plot with binomial confidence interval
ratios,errors,labels=[],[],[]
for col in ct.columns:
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,method="binom_test",alpha=0.05)    
    ratios.append(ratio)
    errors.append(np.array(cil-ratio, cih-ratio))
    labels.append(col)
    print(str(count)+"/"+str(nobs))

n=len(ratios)
left=range(n)
colors=cluster_colors2

fig=plt.figure(figsize=(n*0.75,2.5))
ax=fig.add_subplot(111)
ax.bar(x=left,height=ratios,yerr=errors,
       tick_label=labels,color=colors,capsize=5,width=0.6,edgecolor="k",lw=0.5)
ax.tick_params(labelsize=6)  
ax.set_xticklabels(labels, rotation=0, fontsize=10)
ax.legend([])
ax.set_ylim(0,1)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %%
ct=pd.crosstab(df["CancerType"],df["TGS"])
ct.loc[["Melanoma","HNSCC","Lung","Bladder","Others"],cluster_order2]

# %% [markdown]
# # Per Drug type

# %%
df=df0.copy()

# %%
cat1="irGS"
cat2="TMB_high"

class4=[]
for idx in df.index:
    if df.loc[idx,cat2]==1:
        if df.loc[idx,cat1]==1:
            class4.append("TMB high\nirGS")
        elif df.loc[idx,cat1]==0:
            class4.append("TMB high\nnon-irGS")
        else:
            class4.append("und")
    elif df.loc[idx,cat2]==0:
        if df.loc[idx,cat1]==1:
            class4.append("TMB low\nirGS")
        elif df.loc[idx,cat1]==0:
            class4.append("TMB low\nnon-irGS")
        else:
            class4.append("und")   
df["class4"]=class4

# %%
Counter(df["Treatment"])

# %%
df1=df[df["Treatment"]=="PD1"]
df2=df[df["Treatment"]=="PDL1"]
df3=df[df["Treatment"].isin(["CTLA4",'CTLA4->PD1',"CTLA4+PDL1","CTLA4+PD1","CTLA4+PD1/PDL1"])]
dfs=[df1,df2,df3]

# %%
flag="Responder"
cat1="irGS"
cat2="TMB_high"
value="Missense_Mutation_log10"
for plt_df in dfs:
    fig=plt.figure(figsize=(2.25,2.5))
    ax=fig.add_subplot(111)
    sns.swarmplot(x=cat1,y=value,data=plt_df,
                  s=2,ax=ax,hue=flag,hue_order=[0,1],
                  palette=["k","red"],
                 order=[1,0])
    ax.set_ylabel("",fontsize=8)
    ax.set_xlabel("")
    ax.axhline(y=np.log10(173),c="dimgrey",lw=1,ls="dashed")
    ax.axvline(x=0.5,c="dimgrey",lw=1,ls="dashed")
    ax.tick_params(labelsize=6)
    ax.set_xticklabels(["irGS","Non-irGS"], rotation=0, fontsize=8)
    ax.set_yticks([0,1,2,3,4])
    ax.set_yticklabels(["1","10","100","1000","10$^{4}$"], rotation=0, fontsize=8)
    ax.legend([])
    p1=patches.Rectangle(xy=(-0.5,0),width=1,height=np.log10(cutoff1+1),ec="w",fc="red",alpha=0.2,
                     linewidth=0)
    p2=patches.Rectangle(xy=(-0.5,np.log10(cutoff1+1)),width=1,height=4.2-np.log10(cutoff1+1),
                          ec="w",fc="k",alpha=0.2,
                         linewidth=0)
    p3=patches.Rectangle(xy=(0.5,np.log10(cutoff1+1)),width=1,height=4.2-np.log10(cutoff1+1),
                          ec="w",fc="green",alpha=0.2,
                         linewidth=0)
    ax.add_patch(p1)
    ax.add_patch(p2)
    ax.add_patch(p3)

# %%
for i,plt_df in enumerate(dfs):
    print(plt_df["Treatment"].unique()[0],"n=", plt_df.shape[0])
    ct4=pd.crosstab(plt_df["class4"],plt_df[flag]).T
    ratios=[]
    errors=[]
    labels=[]
    for col in ct4.columns:
        count=ct4.loc[1,col]
        nobs=np.sum( ct4.loc[:,col])
        ratio=count/nobs
        cil,cih=proportion_confint(count,nobs,method="binom_test",alpha=0.05)

        ratios.append(ratio)   
        errors.append(np.array(cil-ratio, cih-ratio))
        labels.append(col)
        print(str(count)+"/"+str(nobs))
    else:
        print()
    
    n=len(ratios)
    left=range(n)
    colors=["k","green","red","white"]
    colors=[to_rgba(x, 0.5) for x in colors ]

    fig=plt.figure(figsize=(3,1.75))
    ax=fig.add_subplot(111)
    ax.bar(x=left,height=ratios,yerr=errors,
           tick_label=labels,color=colors,capsize=5,width=0.6,edgecolor="k",lw=0.5)
    ax.tick_params(labelsize=6)            
    ax.set_xticklabels(labels, rotation=0, fontsize=8)
    ax.legend([])
    ax.set_ylim(0,1)
    if i==0:
        ax.set_ylim(0,1.2)
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    
    ct=ct4.reindex(["TMB low\nirGS","TMB low\nnon-irGS"],axis=1)
    res=stats.chi2_contingency(ct,correction=False)
    res2=stats.fisher_exact(ct)
    display(ct)
    print("chisquare p= %.3g"%res[1])
    print("Fisher p= %.3g"%res2[1],end="\n\n")

# %% [markdown]
# # KEYNOTEs only

# %%
df=df0[df0["Reference"]=='Cristescu, Science 2018']
df.shape

# %%
input_df=df.copy()
flag="Responder"
cat1="irGS"
value="Missense_Mutation_log10"
ct=pd.crosstab(input_df[flag],input_df[cat1])
ct=ct.loc[:,[1,0]]
ct

# %%
_,p=stats.fisher_exact(ct)
res=stats.chi2_contingency(ct,correction=False)
print("Fisher p= %.2e"%p)
print("Chi-square p= %.2e"%res[1])

# %%
ratios=[]
errors=[]
labels=[]
for col in ct.columns:
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,method="binom_test",alpha=0.05)
    
    ratios.append(ratio)
    errors.append(np.array(cil-ratio, cih-ratio))
    labels.append(col)
    
    print(str(count)+"/"+str(nobs))

# %%
n=len(ratios)
left=range(n)
colors=["red","w"]
colors=[to_rgba(x,0.5) for x in colors]
fig=plt.figure(figsize=((1.3,2)))
ax=fig.add_subplot(111)
ax.bar(x=left,height=ratios,yerr=errors,
       tick_label=labels,color=colors,capsize=5,width=0.6,edgecolor="k",lw=0.5)
ax.tick_params(labelsize=6)

ax.set_xticklabels([], rotation=0, fontsize=8)
ax.set_ylim(0,0.6)
ax.legend([])


ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %%
input_df=df.copy()
cat2="TMB_high"
ct=pd.crosstab(input_df[flag],input_df[cat2])
ct=ct.loc[:,[1,0]]
ct

# %%
_,p=stats.fisher_exact(ct)
res=stats.chi2_contingency(ct,correction=False)
print("Fisher p= %.2e"%p)
print("Chi-square p= %.2e"%res[1])

# %%
ratios=[]
errors=[]
labels=[]
for col in ct.columns:
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,method="binom_test",alpha=0.05)
    
    ratios.append(ratio)
    errors.append(np.array(cil-ratio, cih-ratio))
    labels.append(col)
    
    print(str(count)+"/"+str(nobs))

# %%
n=len(ratios)
left=range(n)
colors=["green","w"]
colors=[to_rgba(x,0.5) for x in colors]
fig=plt.figure(figsize=((1.3,2)))
ax=fig.add_subplot(111)
ax.bar(x=left,height=ratios,yerr=errors,
       tick_label=labels,color=colors,capsize=5,width=0.6,edgecolor="k",lw=0.5)
ax.tick_params(labelsize=6)

ax.set_xticklabels([], rotation=0, fontsize=8)
ax.legend([])
ax.set_ylim(0,0.6)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %% [markdown]
# ## 2D plot

# %%
fig=plt.figure(figsize=(3,3.5))
ax=fig.add_subplot(111)
sns.swarmplot(x=cat1,y=value,data=df,
              s=2,ax=ax,hue=flag,hue_order=[0,1],
              palette=["k","red"],
             order=[1,0])
ax.set_ylabel("",fontsize=8)
ax.set_xlabel("")
ax.axvline(x=0.5,c="dimgrey",lw=1,ls="dashed")
ax.tick_params(labelsize=6)
ax.set_xticklabels(["irGS","Non-irGS"], rotation=0, fontsize=8)
ax.set_yticks([0,1,2,3,4])
ax.set_yticklabels(["1","10","100","1000","10$^{4}$"], rotation=0, fontsize=8)
ax.legend([])

ax.axhline(y=np.log10(173),c="dimgrey",lw=1,ls="dashed")
p1=patches.Rectangle(xy=(-0.5,0),width=1,height=np.log10(cutoff1+1),ec="w",fc="red",alpha=0.2,
                 linewidth=0)
p2=patches.Rectangle(xy=(-0.5,np.log10(cutoff1+1)),width=1,height=4.2-np.log10(cutoff1+1),
                      ec="w",fc="k",alpha=0.2,
                     linewidth=0)
p3=patches.Rectangle(xy=(0.5,np.log10(cutoff1+1)),width=1,height=4.2-np.log10(cutoff1+1),
                      ec="w",fc="green",alpha=0.2,
                     linewidth=0)
ax.add_patch(p1)
ax.add_patch(p2)
ax.add_patch(p3)

# %%
class4=[]
for idx in df.index:
    if df.loc[idx,cat2]==1:
        if df.loc[idx,cat1]==1:
            class4.append("TMB high\nirGS")
        elif df.loc[idx,cat1]==0:
            class4.append("TMB high\nnon-irGS")
        else:
            class4.append("und")
    elif df.loc[idx,cat2]==0:
        if df.loc[idx,cat1]==1:
            class4.append("TMB low\nirGS")
        elif df.loc[idx,cat1]==0:
            class4.append("TMB low\nnon-irGS")
        else:
            class4.append("und")   
df["class4"]=class4

# %%
ct4=pd.crosstab(df["class4"],df[flag]).T
ct4=ct4.reindex(['TMB high\nirGS', 'TMB high\nnon-irGS', 'TMB low\nirGS','TMB low\nnon-irGS'],axis=1)
ct4

# %%
ct=ct4.loc[:, ["TMB low\nirGS","TMB low\nnon-irGS"]]
res=stats.chi2_contingency(ct,correction=False)
display(ct)
print("Chi-square p= %.2e"%res[1])

# %%
ratios=[]
errors=[]
labels=[]
for col in ct4.columns:
    count=ct4.loc[1,col]
    nobs=np.sum( ct4.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,method="binom_test",alpha=0.05)
    
    ratios.append(ratio)   
    errors.append(np.array(cil-ratio, cih-ratio))
    labels.append(col)
    
    print(str(count)+"/"+str(nobs))

# %%
n=len(ratios)
left=range(n)
colors=["dimgrey","lightgrey"]*n
colors=["k","green","red","white"]
colors=[to_rgba(x, 0.5) for x in colors ]

fig=plt.figure(figsize=(3,2.5))
ax=fig.add_subplot(111)
ax.bar(x=left,height=ratios,yerr=errors,
       tick_label=labels,color=colors,capsize=5,width=0.6,edgecolor="k",lw=0.5)
ax.tick_params(labelsize=6)
ax.set_xticklabels(labels, rotation=0, fontsize=8)
ax.legend([])
ax.set_ylim(0,1.2)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %% [markdown]
# ## Logistic regression

# %%
Counter(df["irGS"])

# %%
Counter(df["TMB_high"])

# %%
Counter(df["CancerType"])

# %%
df["CancerTypeR"]=df["CancerType"].replace(
        {'Melanoma':"1_Melanoma",
         'Lung': "4_Others",
         'Bladder': "3_Bladder",
         'HNSCC': "2_Head_neck",
         'Others': "4_Others"})

# %%
Counter(df["Sex"])

# %%
df["Sex_male"]=(df["Sex"]=="Male").astype(int)

# %%
Counter(df["Age_high"])

# %%
Y="Responder"
categories=["irGS","Missense_Mutation_log10","CancerTypeR","Sex_male","Age_high"]

# %%
# univariate
univ_integrated=pd.DataFrame()

for cat in categories:
    input_df=df.copy()
    formula = Y+" ~ "+cat
    family = sm.families.Binomial()
    model = smf.glm(formula=formula, data=input_df, family=family)
    res = model.fit()
    res_df=pd.concat( [ np.exp(res.params), np.exp(res.conf_int(alpha=0.05)),res.pvalues],axis=1)
    add=res_df.iloc[1:,:]

    univ_integrated=pd.concat([univ_integrated,add])

univ_integrated.columns=["Odds ratio","CI 5%","CI 95%", "P-value"]

res_df=univ_integrated
res_df["95%CI"]=["({:.2f} - {:.2f})".format(x,y) for x,y in zip(res_df["CI 5%"],res_df["CI 95%"])  ]
display( np.round(res_df[["Odds ratio","95%CI","P-value"]],3) )

for i in res_df["P-value"]:
    print("{:.2e}".format(i))

# %%
# multivariate
categories=["irGS","Missense_Mutation_log10","CancerTypeR"]
input_df=df.copy()
res = smf.glm(formula = Y+" ~ "+"+".join(categories),
                  data = input_df,
                  family = sm.families.Binomial()).fit()

res_df=pd.concat( [ np.exp(res.params), np.exp(res.conf_int(alpha=0.05)),res.pvalues],axis=1)
res_df.columns=["Odds ratio","CI 5%","CI 95%", "p-value"]
res_df["95%CI"]=["({:.2f} - {:.2f})".format(x,y) for x,y in zip(res_df["CI 5%"],res_df["CI 95%"])  ]
display( np.round(res_df[["Odds ratio","95%CI","p-value"]],3) )

for i in res_df["p-value"]:
    print("{:.2g}".format(i))

# %%
 df["CancerType details2"]=df["CancerType details"].replace({"BR_ER+HER-":"BR","BR_TNBC":"BR","HNSCC_Exp":"HNSCC"})

# %%
tmp=pd.crosstab(df["CancerType details2"],df["TGS"]).loc[:,cluster_order2]
tmp["Total"]=np.sum(tmp,axis=1)
tmp.sort_values("Total",ascending=False)

# %% [markdown]
# # Using optimal TMB cutoff

# %%
df=df0.copy()

# %% [markdown]
# ## TMB high vs low

# %%
input_df=df.copy()
cat2="TMB_high2"
ct=pd.crosstab(input_df[flag],input_df[cat2])
ct=ct.loc[:,[1,0]]
ct

# %%
_,p=stats.fisher_exact(ct)
res=stats.chi2_contingency(ct,correction=False)
print("Fisher p= %.2e"%p)
print("Chi-square p= %.2e"%res[1])

# %%
ratios=[]
errors=[]
labels=[]
for col in ct.columns:
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,method="binom_test",alpha=0.05)
    
    ratios.append(ratio)
    errors.append(np.array(cil-ratio, cih-ratio))
    labels.append(col)
    
    print(str(count)+"/"+str(nobs))

# %%
n=len(ratios)
left=range(n)
colors=["blue","w"]
colors=[to_rgba(x,0.5) for x in colors]
fig=plt.figure(figsize=((1.3,2)))
ax=fig.add_subplot(111)
ax.bar(x=left,height=ratios,yerr=errors,
       tick_label=labels,color=colors,capsize=5,width=0.6,edgecolor="k",lw=0.5)
ax.tick_params(labelsize=6)

ax.set_xticklabels([], rotation=0, fontsize=8)
ax.legend([])
ax.set_ylim(0,0.6)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %% [markdown]
# ## 2D plot

# %%
fig=plt.figure(figsize=(3,3.5))
ax=fig.add_subplot(111)
sns.swarmplot(x=cat1,y=value,data=df,
              s=2,ax=ax,hue=flag,hue_order=[0,1],
              palette=["k","red"],
             order=[1,0])
ax.set_ylabel("",fontsize=8)
ax.set_xlabel("")
ax.axhline(y=np.log10(cutoff1),c="dimgrey",lw=1,ls="dashed")
ax.axvline(x=0.5,c="dimgrey",lw=1,ls="dashed")
ax.tick_params(labelsize=6)
ax.set_xticklabels([])
ax.set_yticks([0,1,2,3,4])
ax.set_yticklabels(["1","10","100","1000","10$^{4}$"], rotation=0, fontsize=8)
ax.legend([])

p1=patches.Rectangle(xy=(-0.5,0),width=1,height=np.log10(cutoff1+1),ec="w",fc="red",alpha=0.2,
                 linewidth=0)
p2=patches.Rectangle(xy=(-0.5,np.log10(cutoff1+1)),width=1,height=4.2-np.log10(cutoff1+1),
                      ec="w",fc="k",alpha=0.2,
                     linewidth=0)
p3=patches.Rectangle(xy=(0.5,np.log10(cutoff1+1)),width=1,height=4.2-np.log10(cutoff1+1),
                      ec="w",fc="blue",alpha=0.2,
                     linewidth=0)
ax.add_patch(p1)
ax.add_patch(p2)
ax.add_patch(p3)

# %%
class4=[]
for idx in df.index:
    if df.loc[idx,cat2]==1:
        if df.loc[idx,cat1]==1:
            class4.append("TMB high\nirGS")
        elif df.loc[idx,cat1]==0:
            class4.append("TMB high\nnon-irGS")
        else:
            class4.append("und")
    elif df.loc[idx,cat2]==0:
        if df.loc[idx,cat1]==1:
            class4.append("TMB low\nirGS")
        elif df.loc[idx,cat1]==0:
            class4.append("TMB low\nnon-irGS")
        else:
            class4.append("und")   
df["class4"]=class4

# %%
ct4=pd.crosstab(df["class4"],df[flag]).T
ct4=ct4.reindex(['TMB high\nirGS', 'TMB high\nnon-irGS', 'TMB low\nirGS','TMB low\nnon-irGS'],axis=1)
ct4

# %%
# compare between TMB-low groups
ct=ct4.loc[:, ["TMB low\nirGS","TMB low\nnon-irGS"]]
res=stats.chi2_contingency(ct,correction=False)
display(ct)
print("Chi-square p= %.2e"%res[1])

# %%
ratios=[]
errors=[]
labels=[]
for col in ct4.columns:
    count=ct4.loc[1,col]
    nobs=np.sum( ct4.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,method="binom_test",alpha=0.05)
    
    ratios.append(ratio)   
    errors.append(np.array(cil-ratio, cih-ratio))
    labels.append(col)
    
    print(str(count)+"/"+str(nobs))

# %%
n=len(ratios)
left=range(n)
colors=["dimgrey","lightgrey"]*n
colors=["k","blue","red","white"]
colors=[to_rgba(x, 0.5) for x in colors ]

fig=plt.figure(figsize=(3,2.5))
ax=fig.add_subplot(111)
ax.bar(x=left,height=ratios,yerr=errors,
       tick_label=labels,color=colors,capsize=5,width=0.6,edgecolor="k",lw=0.5)
ax.tick_params(labelsize=6)
ax.set_xticklabels(labels, rotation=0, fontsize=8)
ax.legend([])
ax.set_ylim(0,0.8)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %% [markdown]
# ## Logistic regression

# %%
Counter(df["irGS"])
# Out:
# Counter({1: 620, 0: 318})

# %%
Counter(df["TMB_high2"])
# Out:
# Counter({1.0: 370, 0.0: 568})

# %%
Counter(df["CancerType"])
# Out:
# Counter({'Melanoma': 335,
#          'Lung': 127,
#          'Bladder': 263,
#          'HNSCC': 118,
#          'Others': 95})

# %%
df["CancerTypeR"]=df["CancerType"].replace(
        {'Melanoma':"1_Melanoma",
         'Lung': "3_Lung",
         'Bladder': "4_Bladder",
         'HNSCC': "2_Head_neck",
         'Others': "5_Others"})

# %%
Counter(df["Sex"])
# Out:
# Counter({'Female': 326, 'Male': 612})

# %%
df["Sex_male"]=(df["Sex"]=="Male").astype(int)

# %%
Y="Responder"
categories=["irGS","TMB_high2","CancerTypeR","Sex_male","Age_high"]

# %%
# univariate
univ_integrated=pd.DataFrame()

for cat in categories:
    input_df=df.copy()
    formula = Y+" ~ "+cat
    family = sm.families.Binomial()
    model = smf.glm(formula=formula, data=input_df, family=family)
    res = model.fit()
    res_df=pd.concat( [ np.exp(res.params), np.exp(res.conf_int(alpha=0.05)),res.pvalues],axis=1)
    add=res_df.iloc[1:,:]

    univ_integrated=pd.concat([univ_integrated,add])

univ_integrated.columns=["Odds ratio","CI 5%","CI 95%", "P-value"]

res_df=univ_integrated
res_df["95%CI"]=["({:.2f} - {:.2f})".format(x,y) for x,y in zip(res_df["CI 5%"],res_df["CI 95%"])  ]
display( np.round(res_df[["Odds ratio","95%CI","P-value"]],3) )

for i in res_df["P-value"]:
    print("{:.2e}".format(i))
# Out:
#                             Odds ratio          95%CI  P-value
# irGS                             3.940  (2.70 - 5.74)    0.000
# TMB_high2                        4.128  (3.05 - 5.59)    0.000
# CancerTypeR[T.2_Head_neck]       0.482  (0.29 - 0.81)    0.006
# CancerTypeR[T.3_Lung]            1.002  (0.65 - 1.55)    0.993
# CancerTypeR[T.4_Bladder]         0.762  (0.53 - 1.09)    0.136
# CancerTypeR[T.5_Others]          0.333  (0.18 - 0.62)    0.001
# Sex_male                         1.192  (0.88 - 1.62)    0.262
# Age_high                         1.067  (0.75 - 1.52)    0.719
# 1.01e-12
# 6.17e-20
# 5.60e-03
# 9.93e-01
# 1.36e-01
# 6.08e-04
# 2.62e-01
# 7.19e-01

# %%
# multivariate
categories=["irGS","TMB_high2","CancerTypeR"]
input_df=df.copy()
res = smf.glm(formula = Y+" ~ "+"+".join(categories),
                  data = input_df,
                  family = sm.families.Binomial()).fit()

res_df=pd.concat( [ np.exp(res.params), np.exp(res.conf_int(alpha=0.05)),res.pvalues],axis=1)
res_df.columns=["Odds ratio","CI 5%","CI 95%", "p-value"]
res_df["95%CI"]=["({:.2f} - {:.2f})".format(x,y) for x,y in zip(res_df["CI 5%"],res_df["CI 95%"])  ]
display( np.round(res_df[["Odds ratio","95%CI","p-value"]],3) )

for i in res_df["p-value"]:
    print("{:.2e}".format(i))
# Out:
#                             Odds ratio          95%CI  p-value
# Intercept                        0.133  (0.09 - 0.20)    0.000
# CancerTypeR[T.2_Head_neck]       0.844  (0.48 - 1.47)    0.548
# CancerTypeR[T.3_Lung]            1.352  (0.85 - 2.16)    0.208
# CancerTypeR[T.4_Bladder]         0.902  (0.62 - 1.32)    0.596
# CancerTypeR[T.5_Others]          0.903  (0.45 - 1.81)    0.773
# irGS                             2.087  (1.32 - 3.30)    0.002
# TMB_high2                        2.913  (2.03 - 4.18)    0.000
# 9.36e-20
# 5.48e-01
# 2.08e-01
# 5.96e-01
# 7.73e-01
# 1.66e-03
# 7.13e-09

# %% [markdown]
# # Each dataset

# %%
df=df0.copy()

# %%
cat1="irGS"
cat2="TMB_high"

# %%
class4=[]
for idx in df.index:
    if df.loc[idx,cat2]==1:
        if df.loc[idx,cat1]==1:
            class4.append("TMB high\nirGS")
        elif df.loc[idx,cat1]==0:
            class4.append("TMB high\nnon-irGS")
        else:
            class4.append("und")
    elif df.loc[idx,cat2]==0:
        if df.loc[idx,cat1]==1:
            class4.append("TMB low\nirGS")
        elif df.loc[idx,cat1]==0:
            class4.append("TMB low\nnon-irGS")
        else:
            class4.append("und")   
df["class4"]=class4

# %%
refs=list(df["Reference"].unique())
refs

# %%
fig=plt.figure(figsize=(12,7.5))

for i,ref in enumerate(refs):
    if ref =="":
        continue
    input_df=df[df["Reference"]==ref]
    ax=fig.add_subplot(3,5,i+1)
    sns_df=input_df.copy()
    ax.axhline(y=np.log10(174),color="k",ls="dashed")
    ax.axvline(x=0.5,color="k",ls="dashed")
    ax.set_ylim(0,4)
    ax.tick_params(labelsize=6)
    s=3
    if len(input_df)>=100:
        s=2.5
    ax=sns.swarmplot(x="irGS",y="Missense_Mutation_log10",order=[1,0],data=sns_df,
                     hue="Responder",palette=["k","red"],s=s)
    ax.legend([])
    ax.set_title(ref,fontsize=10)
    ax.set_xlabel("")#'TMB log10',fontsize=8)
    ax.set_ylabel("")
    ax.set_xticklabels(["irGS","Non-irGS"],fontsize=10)
    
    if i in [0,5,10]:
        ax.set_yticks([0,1,2,3,4])
        ax.set_yticklabels(["1","10","100","1000","10$^{4}$"], rotation=0, fontsize=8) 
    else:
        ax.set_yticklabels([])

plt.subplots_adjust(hspace=0.3,wspace=0.2)
#plt.savefig(path_to_res+"SciTra2017_MEL_OR_2dplot.png",dpi=300,bbox_inches="tight")

# %%
ct=pd.crosstab(df["Reference"],df["TGS"])
ct.loc[refs,cluster_order2]

# %% [markdown]
# # Per tumor type

# %%
Counter(df["CancerTypeR"])
# Out:
# Counter({'1_Melanoma': 335,
#          '3_Lung': 127,
#          '4_Bladder': 263,
#          '2_Head_neck': 118,
#          '5_Others': 95})

# %%
cat1="irGS"
value="Missense_Mutation_log10"

# %% [markdown]
# ## MEL

# %%
df1=df[df["CancerTypeR"]=="1_Melanoma"]

# %%
input_df=df1.copy()
flag="Responder"
cat1="irGS"
value="Missense_Mutation_log10"
ct=pd.crosstab(input_df[flag],input_df[cat1])
ct=ct.loc[:,[1,0]]
ct
# Out:
# irGS         1   0
# Responder
# 0.0        156  71
# 1.0         94  14

# %%
_,p=stats.fisher_exact(ct)
res=stats.chi2_contingency(ct,correction=False)
print("Fisher p= %.2e"%p)
print("Chi-square p= %.2e"%res[1])
# Out:
# Fisher p= 2.61e-04
# Chi-square p= 3.18e-04

# %%
ratios=[]
errors=[]
labels=[]
for col in ct.columns:
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,method="binom_test",alpha=0.05)
    
    ratios.append(ratio)
    errors.append(np.array(cil-ratio, cih-ratio))
    labels.append(col)
    
    print(str(count)+"/"+str(nobs))
# Out:
# 94/250
# 14/85

# %%
n=len(ratios)
left=range(n)
colors=["red","w"]
colors=[to_rgba(x,0.5) for x in colors]
fig=plt.figure(figsize=((1.3,2)))
ax=fig.add_subplot(111)
ax.bar(x=left,height=ratios,yerr=errors,
       tick_label=labels,color=colors,capsize=5,width=0.6,edgecolor="k",lw=0.5)
ax.tick_params(labelsize=6)

ax.set_xticklabels([], rotation=0, fontsize=8)
ax.set_ylim(0,0.6)
ax.legend([])


ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %%
fig=plt.figure(figsize=(2.5,3))
ax=fig.add_subplot(111)
sns.swarmplot(x=cat1,y=value,data=df1,
              s=3,ax=ax,hue=flag,hue_order=[0,1],
              palette=["k","red"],
             order=[1,0])
ax.set_ylabel("",fontsize=8)
ax.set_xlabel("")
ax.axhline(y=np.log10(cutoff1),c="dimgrey",lw=1,ls="dashed")
ax.axvline(x=0.5,c="dimgrey",lw=1,ls="dashed")
ax.tick_params(labelsize=6)
ax.set_xticklabels([])
ax.set_yticks([0,1,2,3,4])
ax.set_ylim(0,4.2)
ax.set_yticklabels(["1","10","100","1000","10$^{4}$"], rotation=0, fontsize=8)
ax.legend([])

   
p1=patches.Rectangle(xy=(-0.5,0),width=1,height=np.log10(cutoff1+1),ec="w",fc="red",alpha=0.2,
                     linewidth=0)
p2=patches.Rectangle(xy=(-0.5,np.log10(cutoff1+1)),width=1,height=4.2-np.log10(cutoff1+1),
                      ec="w",fc="k",alpha=0.2,
                     linewidth=0)
p3=patches.Rectangle(xy=(0.5,np.log10(cutoff1+1)),width=1,height=4.2-np.log10(cutoff1+1),
                      ec="w",fc="green",alpha=0.2,
                     linewidth=0)

ax.add_patch(p1)
ax.add_patch(p2)
ax.add_patch(p3)
# Out:
# /Users/takamatsushiro/.pyenv/versions/3.8.6/envs/default/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 6.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## HN

# %%
df1=df[df["CancerTypeR"]=="2_Head_neck"]
len(df1)
# Out:
# 118

# %%
input_df=df1.copy()
flag="Responder"
cat1="irGS"
value="Missense_Mutation_log10"
ct=pd.crosstab(input_df[flag],input_df[cat1])
ct=ct.loc[:,[1,0]]
ct
# Out:
# irGS        1   0
# Responder
# 0.0        42  54
# 1.0        13   9

# %%
_,p=stats.fisher_exact(ct)
res=stats.chi2_contingency(ct,correction=False)
print("Fisher p= %.2e"%p)
print("Chi-square p= %.2e"%res[1])
# Out:
# Fisher p= 2.39e-01
# Chi-square p= 1.93e-01

# %%
ratios=[]
errors=[]
labels=[]
for col in ct.columns:
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,method="binom_test",alpha=0.05)
    
    ratios.append(ratio)
    errors.append(np.array(cil-ratio, cih-ratio))
    labels.append(col)
    
    print(str(count)+"/"+str(nobs))
# Out:
# 13/55
# 9/63

# %%
n=len(ratios)
left=range(n)
colors=["red","w"]
colors=[to_rgba(x,0.5) for x in colors]
fig=plt.figure(figsize=((1.3,2)))
ax=fig.add_subplot(111)
ax.bar(x=left,height=ratios,yerr=errors,
       tick_label=labels,color=colors,capsize=5,width=0.6,edgecolor="k",lw=0.5)
ax.tick_params(labelsize=6)

ax.set_xticklabels([], rotation=0, fontsize=8)
ax.set_ylim(0,0.6)
ax.legend([])


ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %%
fig=plt.figure(figsize=(2.5,3))
ax=fig.add_subplot(111)
sns.swarmplot(x=cat1,y=value,data=df1,
              s=3,ax=ax,hue=flag,hue_order=[0,1],
              palette=["k","red"],
             order=[1,0])
ax.set_ylabel("",fontsize=8)
ax.set_xlabel("")
ax.axhline(y=np.log10(cutoff1),c="dimgrey",lw=1,ls="dashed")
ax.axvline(x=0.5,c="dimgrey",lw=1,ls="dashed")
ax.tick_params(labelsize=6)
ax.set_xticklabels([])
ax.set_yticks([0,1,2,3,4])
ax.set_ylim(0,4.2)
ax.set_yticklabels(["1","10","100","1000","10$^{4}$"], rotation=0, fontsize=8)
ax.legend([])

   
p1=patches.Rectangle(xy=(-0.5,0),width=1,height=np.log10(cutoff1+1),ec="w",fc="red",alpha=0.2,
                     linewidth=0)
p2=patches.Rectangle(xy=(-0.5,np.log10(cutoff1+1)),width=1,height=4.2-np.log10(cutoff1+1),
                      ec="w",fc="k",alpha=0.2,
                     linewidth=0)
p3=patches.Rectangle(xy=(0.5,np.log10(cutoff1+1)),width=1,height=4.2-np.log10(cutoff1+1),
                      ec="w",fc="green",alpha=0.2,
                     linewidth=0)

ax.add_patch(p1)
ax.add_patch(p2)
ax.add_patch(p3)

# %% [markdown]
# ## Lung

# %%
df1=df[df["CancerTypeR"]=="3_Lung"]

# %%
input_df=df1.copy()
flag="Responder"
cat1="irGS"
value="Missense_Mutation_log10"
ct=pd.crosstab(input_df[flag],input_df[cat1])
ct=ct.loc[:,[1,0]]
ct
# Out:
# irGS        1   0
# Responder
# 0.0        49  37
# 1.0        38   3

# %%
_,p=stats.fisher_exact(ct)
res=stats.chi2_contingency(ct,correction=False)
print("Fisher p= %.2e"%p)
print("Chi-square p= %.2e"%res[1])
# Out:
# Fisher p= 2.93e-05
# Chi-square p= 5.11e-05

# %%
ratios=[]
errors=[]
labels=[]
for col in ct.columns:
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,method="binom_test",alpha=0.05)
    
    ratios.append(ratio)
    errors.append(np.array(cil-ratio, cih-ratio))
    labels.append(col)
    
    print(str(count)+"/"+str(nobs))
# Out:
# 38/87
# 3/40

# %%
n=len(ratios)
left=range(n)
colors=["red","w"]
colors=[to_rgba(x,0.5) for x in colors]
fig=plt.figure(figsize=((1.3,2)))
ax=fig.add_subplot(111)
ax.bar(x=left,height=ratios,yerr=errors,
       tick_label=labels,color=colors,capsize=5,width=0.6,edgecolor="k",lw=0.5)
ax.tick_params(labelsize=6)

ax.set_xticklabels([], rotation=0, fontsize=8)
ax.set_ylim(0,0.6)
ax.legend([])


ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %%
fig=plt.figure(figsize=(2.5,3))
ax=fig.add_subplot(111)
sns.swarmplot(x=cat1,y=value,data=df1,
              s=3,ax=ax,hue=flag,hue_order=[0,1],
              palette=["k","red"],
             order=[1,0])
ax.set_ylabel("",fontsize=8)
ax.set_xlabel("")
ax.axhline(y=np.log10(cutoff1),c="dimgrey",lw=1,ls="dashed")
ax.axvline(x=0.5,c="dimgrey",lw=1,ls="dashed")
ax.tick_params(labelsize=6)
ax.set_xticklabels([])
ax.set_yticks([0,1,2,3,4])
ax.set_ylim(0,4.2)
ax.set_yticklabels(["1","10","100","1000","10$^{4}$"], rotation=0, fontsize=8)
ax.legend([])

   
p1=patches.Rectangle(xy=(-0.5,0),width=1,height=np.log10(cutoff1+1),ec="w",fc="red",alpha=0.2,
                     linewidth=0)
p2=patches.Rectangle(xy=(-0.5,np.log10(cutoff1+1)),width=1,height=4.2-np.log10(cutoff1+1),
                      ec="w",fc="k",alpha=0.2,
                     linewidth=0)
p3=patches.Rectangle(xy=(0.5,np.log10(cutoff1+1)),width=1,height=4.2-np.log10(cutoff1+1),
                      ec="w",fc="green",alpha=0.2,
                     linewidth=0)

ax.add_patch(p1)
ax.add_patch(p2)
ax.add_patch(p3)

# %% [markdown]
# ## BL

# %%
df1=df[df["CancerTypeR"]=="4_Bladder"]

# %%
input_df=df1.copy()
flag="Responder"
cat1="irGS"
value="Missense_Mutation_log10"
ct=pd.crosstab(input_df[flag],input_df[cat1])
ct=ct.loc[:,[1,0]]
ct
# Out:
# irGS         1   0
# Responder
# 0.0        146  47
# 1.0         65   5

# %%
_,p=stats.fisher_exact(ct)
res=stats.chi2_contingency(ct,correction=False)
print("Fisher p= %.2e"%p)
print("Chi-square p= %.2e"%res[1])
# Out:
# Fisher p= 1.45e-03
# Chi-square p= 1.96e-03

# %%
ratios=[]
errors=[]
labels=[]
for col in ct.columns:
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,method="binom_test",alpha=0.05)
    
    ratios.append(ratio)
    errors.append(np.array(cil-ratio, cih-ratio))
    labels.append(col)
    
    print(str(count)+"/"+str(nobs))
# Out:
# 65/211
# 5/52

# %%
n=len(ratios)
left=range(n)
colors=["red","w"]
colors=[to_rgba(x,0.5) for x in colors]
fig=plt.figure(figsize=((1.3,2)))
ax=fig.add_subplot(111)
ax.bar(x=left,height=ratios,yerr=errors,
       tick_label=labels,color=colors,capsize=5,width=0.6,edgecolor="k",lw=0.5)
ax.tick_params(labelsize=6)

ax.set_xticklabels([], rotation=0, fontsize=8)
ax.set_ylim(0,0.6)
ax.legend([])


ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %%
fig=plt.figure(figsize=(2.5,3))
ax=fig.add_subplot(111)
sns.swarmplot(x=cat1,y=value,data=df1,
              s=3,ax=ax,hue=flag,hue_order=[0,1],
              palette=["k","red"],
             order=[1,0])
ax.set_ylabel("",fontsize=8)
ax.set_xlabel("")
ax.axhline(y=np.log10(cutoff1),c="dimgrey",lw=1,ls="dashed")
ax.axvline(x=0.5,c="dimgrey",lw=1,ls="dashed")
ax.tick_params(labelsize=6)
ax.set_xticklabels([])
ax.set_yticks([0,1,2,3,4])
ax.set_ylim(0,4.2)
ax.set_yticklabels(["1","10","100","1000","10$^{4}$"], rotation=0, fontsize=8)
ax.legend([])

   
p1=patches.Rectangle(xy=(-0.5,0),width=1,height=np.log10(cutoff1+1),ec="w",fc="red",alpha=0.2,
                     linewidth=0)
p2=patches.Rectangle(xy=(-0.5,np.log10(cutoff1+1)),width=1,height=4.2-np.log10(cutoff1+1),
                      ec="w",fc="k",alpha=0.2,
                     linewidth=0)
p3=patches.Rectangle(xy=(0.5,np.log10(cutoff1+1)),width=1,height=4.2-np.log10(cutoff1+1),
                      ec="w",fc="green",alpha=0.2,
                     linewidth=0)

ax.add_patch(p1)
ax.add_patch(p2)
ax.add_patch(p3)

# %% [markdown]
# ## Others

# %%
df1=df[df["CancerTypeR"]=="5_Others"]

# %%
input_df=df1.copy()
flag="Responder"
cat1="irGS"
value="Missense_Mutation_log10"
ct=pd.crosstab(input_df[flag],input_df[cat1])
ct=ct.loc[:,[1,0]]
ct
# Out:
# irGS        1   0
# Responder
# 0.0        11  71
# 1.0         6   7

# %%
_,p=stats.fisher_exact(ct)
res=stats.chi2_contingency(ct,correction=False)
print("Fisher p= %.2e"%p)
print("Chi-square p= %.2e"%res[1])
# Out:
# Fisher p= 1.10e-02
# Chi-square p= 4.22e-03

# %%
ratios=[]
errors=[]
labels=[]
for col in ct.columns:
    count=ct.loc[1,col]
    nobs=np.sum( ct.loc[:,col])
    ratio=count/nobs
    cil,cih=proportion_confint(count,nobs,method="binom_test",alpha=0.05)
    
    ratios.append(ratio)
    errors.append(np.array(cil-ratio, cih-ratio))
    labels.append(col)
    
    print(str(count)+"/"+str(nobs))
# Out:
# 6/17
# 7/78

# %%
n=len(ratios)
left=range(n)
colors=["red","w"]
colors=[to_rgba(x,0.5) for x in colors]
fig=plt.figure(figsize=((1.3,2)))
ax=fig.add_subplot(111)
ax.bar(x=left,height=ratios,yerr=errors,
       tick_label=labels,color=colors,capsize=5,width=0.6,edgecolor="k",lw=0.5)
ax.tick_params(labelsize=6)

ax.set_xticklabels([], rotation=0, fontsize=8)
ax.set_ylim(0,0.6)
ax.legend([])


ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %%
fig=plt.figure(figsize=(2.5,3))
ax=fig.add_subplot(111)
sns.swarmplot(x=cat1,y=value,data=df1,
              s=3,ax=ax,hue=flag,hue_order=[0,1],
              palette=["k","red"],
             order=[1,0])
ax.set_ylabel("",fontsize=8)
ax.set_xlabel("")
ax.axhline(y=np.log10(cutoff1),c="dimgrey",lw=1,ls="dashed")
ax.axvline(x=0.5,c="dimgrey",lw=1,ls="dashed")
ax.tick_params(labelsize=6)
ax.set_xticklabels([])
ax.set_yticks([0,1,2,3,4])
ax.set_ylim(0,4.2)
ax.set_yticklabels(["1","10","100","1000","10$^{4}$"], rotation=0, fontsize=8)
ax.legend([])

   
p1=patches.Rectangle(xy=(-0.5,0),width=1,height=np.log10(cutoff1+1),ec="w",fc="red",alpha=0.2,
                     linewidth=0)
p2=patches.Rectangle(xy=(-0.5,np.log10(cutoff1+1)),width=1,height=4.2-np.log10(cutoff1+1),
                      ec="w",fc="k",alpha=0.2,
                     linewidth=0)
p3=patches.Rectangle(xy=(0.5,np.log10(cutoff1+1)),width=1,height=4.2-np.log10(cutoff1+1),
                      ec="w",fc="green",alpha=0.2,
                     linewidth=0)

ax.add_patch(p1)
ax.add_patch(p2)
ax.add_patch(p3)

# %%
# ROC curve, AUC, explore optimal threshold
from sklearn.metrics import roc_curve,roc_auc_score,auc
flag="Responder"
value="Missense_Mutation"
plt_df=df1.copy()

# plot ROC curve
plt_df=plt_df.loc[:,[flag,value]].dropna()
y_true=plt_df[flag]
y_score=plt_df[value]
fpr, tpr, thresholds = roc_curve(y_true, y_score)
auc=roc_auc_score(y_true, y_score)

fig=plt.figure(figsize=(2,2))
ax=fig.add_subplot(111)
ax.plot(fpr, tpr, marker='o',ms=0.5,c="k")
ax.set_xlabel('FPR: False positive rate',fontsize=8)
ax.set_ylabel('TPR: True positive rate',fontsize=8)
ax.plot(np.linspace(0,1), np.linspace(0,1), c="r",ls="dotted")
ax.tick_params(labelsize=6)

# Youden index
yd_idx = np.argmax( abs(tpr -fpr) )
yd_threshold = thresholds[yd_idx]
print("Youden index: TPR={:.2f},　FPR={:.2f},　Threshold={:.2f}".format(tpr[yd_idx],fpr[yd_idx],yd_threshold))

# plot with Threshold
arrow_dict = dict(color = "black",arrowstyle = "->")
ax.annotate("Threshold\n= {}".format(thresholds[yd_idx]),xy=(fpr[yd_idx],tpr[yd_idx]),
             size=10,xytext=(fpr[yd_idx]-0.3,tpr[yd_idx]+0.2), arrowprops = arrow_dict )

ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
# Out:
# Youden index: TPR=0.62,　FPR=0.12,　Threshold=97.00

# %%
cutoff1=yd_threshold
value="Missense_Mutation_log10"

# %%
fig=plt.figure(figsize=(3,3.5))
ax=fig.add_subplot(111)
sns.swarmplot(x=cat1,y=value,data=df1,
              s=2,ax=ax,hue=flag,hue_order=[0,1],
              palette=["k","red"],
             order=[1,0])
ax.set_ylabel("",fontsize=8)
ax.set_xlabel("")
ax.axhline(y=np.log10(cutoff1),c="dimgrey",lw=1,ls="dashed")
ax.axvline(x=0.5,c="dimgrey",lw=1,ls="dashed")
ax.tick_params(labelsize=6)
ax.set_xticklabels([])
ax.set_yticks([0,1,2,3,4])
ax.set_ylim(0,4.2)
ax.set_yticklabels(["1","10","100","1000","10$^{4}$"], rotation=0, fontsize=8)
ax.legend([])

   
p1=patches.Rectangle(xy=(-0.5,0),width=1,height=np.log10(cutoff1+1),ec="w",fc="red",alpha=0.2,
                     linewidth=0)
p2=patches.Rectangle(xy=(-0.5,np.log10(cutoff1+1)),width=1,height=4.2-np.log10(cutoff1+1),
                      ec="w",fc="k",alpha=0.2,
                     linewidth=0)
p3=patches.Rectangle(xy=(0.5,np.log10(cutoff1+1)),width=1,height=4.2-np.log10(cutoff1+1),
                      ec="w",fc="green",alpha=0.2,
                     linewidth=0)

ax.add_patch(p1)
ax.add_patch(p2)
ax.add_patch(p3)
